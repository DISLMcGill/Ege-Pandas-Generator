# %%
import pandas as pd

# %%
customer = pd.read_table("./customer.tbl", sep = "|",
                         header = None)
customer = customer.dropna(axis = "columns")

# %%
customer.columns = ['c_custkey', 'c_name', 'c_address', 'c_nationkey', 'c_phone', 'c_acctbal', 'c_mktsegment', 'c_comment']

# %%
customer = customer.head(100)
customer
# Out:
#     c_custkey              c_name                       c_address  \
# 0           1  Customer#000000001               IVhzIApeRb ot,c,E
# 1           2  Customer#000000002  XSTf4,NCwDVaWNe6tEgvwfmRchLXak
# 2           3  Customer#000000003                    MG9kdTD2WBHm
# 3           4  Customer#000000004                     XxVSJsLAGtn
# 4           5  Customer#000000005    KvpyuHCplrB84WgAiGV6sYpZq7Tj
# ..        ...                 ...                             ...
# 95         96  Customer#000000096                      vWLOrmXhRR
# 96         97  Customer#000000097           OApyejbhJG,0Iw3j rd1M
# 97         98  Customer#000000098              7yiheXNSpuEAwbswDW
# 98         99  Customer#000000099                szsrOiPtCHVS97Lt
# 99        100  Customer#000000100                  fptUABXcmkC5Wx
#
#     c_nationkey          c_phone  c_acctbal c_mktsegment  \
# 0            15  25-989-741-2988     711.56     BUILDING
# ...

# %%
# customer.to_csv("customer_1.csv", index=False)

# %%
lineitem = pd.read_table("./lineitem.tbl", sep = "|",
                         header = None)
lineitem = lineitem.dropna(axis = "columns")

# %%
lineitem.columns = ['l_orderkey',
'l_partkey',
'l_suppkey',
'l_linenumber',
'l_quantity',
'l_extendedprice',
'l_discount',
'l_tax',
'l_returnflag',
'l_linestatus',
'l_shipdate',
'l_commitdate',
'l_receiptdate',
'l_shipinstruct',
'l_shipmode',
'l_comment' 
]


#     'CONSTRAINT LINEITEM_FK1 FOREIGN KEY (L_ORDERKEY)  references ORDERS,
#     CONSTRAINT LINEITEM_FK2 FOREIGN KEY (L_PARTKEY,L_SUPPKEY) references PARTSUPP'

# %%
lineitem
# Out:
#          l_orderkey  l_partkey  l_suppkey  l_linenumber  l_quantity  \
# 0                 1     155190       7706             1          17
# 1                 1      67310       7311             2          36
# 2                 1      63700       3701             3           8
# 3                 1       2132       4633             4          28
# 4                 1      24027       1534             5          24
# ...             ...        ...        ...           ...         ...
# 6001210     5999975       7272       2273             1          32
# 6001211     5999975       6452       1453             2           7
# 6001212     5999975      37131       2138             3          18
# 6001213     6000000      32255       2256             1           5
# 6001214     6000000      96127       6128             2          28
#
#          l_extendedprice  l_discount  l_tax l_returnflag l_linestatus  \
# 0               21168.23        0.04   0.02            N            O
# ...

# %%
df= lineitem[(lineitem["SUPPKEY"] > 1000) | (lineitem["QUANTITY"] > 50) & (lineitem["DISCOUNT"] > 0.04)]

# %%
df
# Out:
#          ORDERKEY  PARTKEY  SUPPKEY  LINENUMBER  QUANTITY  EXTENDEDPRICE  \
# 0               1   155190     7706           1        17       21168.23
# 1               1    67310     7311           2        36       45983.16
# 2               1    63700     3701           3         8       13309.60
# 3               1     2132     4633           4        28       28955.64
# 4               1    24027     1534           5        24       22824.48
# ...           ...      ...      ...         ...       ...            ...
# 6001210   5999975     7272     2273           1        32       37736.64
# 6001211   5999975     6452     1453           2         7        9509.15
# 6001212   5999975    37131     2138           3        18       19226.34
# 6001213   6000000    32255     2256           1         5        5936.25
# 6001214   6000000    96127     6128           2        28       31447.36
#
#          DISCOUNT   TAX RETURNFLAG LINESTATUS    SHIPDATE  COMMITDATE  \
# ...

# %%
lineitem
# Out:
#          ORDERKEY  PARTKEY  SUPPKEY  LINENUMBER  QUANTITY  EXTENDEDPRICE  \
# 0               1   155190     7706           1        17       21168.23
# 1               1    67310     7311           2        36       45983.16
# 2               1    63700     3701           3         8       13309.60
# 3               1     2132     4633           4        28       28955.64
# 4               1    24027     1534           5        24       22824.48
# ...           ...      ...      ...         ...       ...            ...
# 6001210   5999975     7272     2273           1        32       37736.64
# 6001211   5999975     6452     1453           2         7        9509.15
# 6001212   5999975    37131     2138           3        18       19226.34
# 6001213   6000000    32255     2256           1         5        5936.25
# 6001214   6000000    96127     6128           2        28       31447.36
#
#          DISCOUNT   TAX RETURNFLAG LINESTATUS    SHIPDATE  COMMITDATE  \
# ...

# %%
lineitem = lineitem.head(200)

# %%
# lineitem.to_csv("lineitem_1.csv", index = False)

# %%
orders = pd.read_table("./orders.tbl", sep = "|",
                         header = None)
orders = orders.dropna(axis = "columns")

# %%
orders.columns = ["o_orderkey",
    "o_custkey",
    "o_orderstatus",
    "o_totalprice",
    "o_orderdate",
    "o_orderpriority",
    "o_clerk",
    "o_shippriority",
    "o_comment"]
# (O_CUSTKEY) references CUSTOMER

# %%
orders
# Out:
#          o_orderkey  o_custkey o_orderstatus  o_totalprice o_orderdate  \
# 0                 1      36901             O     173665.47  1996-01-02
# 1                 2      78002             O      46929.18  1996-12-01
# 2                 3     123314             F     193846.25  1993-10-14
# 3                 4     136777             O      32151.78  1995-10-11
# 4                 5      44485             F     144659.20  1994-07-30
# ...             ...        ...           ...           ...         ...
# 1499995     5999972     143594             O     114856.68  1996-05-02
# 1499996     5999973      32071             O      68906.56  1997-07-13
# 1499997     5999974      55448             F      92750.90  1993-07-28
# 1499998     5999975     113398             F      63216.65  1993-07-25
# 1499999     6000000     110063             O      37625.29  1996-08-31
#
#          o_orderpriority          o_clerk  o_shippriority  \
# ...

# %%
orders = orders.head(200)

# %%
# orders.to_csv("orders_1.csv", index = False)

# %%
partsupp = pd.read_table("./partsupp.tbl", sep = "|",
                         header = None)
partsupp = partsupp.dropna(axis = "columns")

# %%
partsupp.columns = ["ps_partkey", 
    "ps_suppkey",
    "ps_availqty",
    "ps_supplycost",
    "ps_comment"]  
# CONSTRAINT PARTSUPP_FK1 FOREIGN KEY (PS_SUPPKEY) references SUPPLIER,
#     CONSTRAINT PARTSUPP_FK2 FOREIGN KEY (PS_PARTKEY) references PART

# %%
partsupp
# Out:
#         ps_partkey  ps_suppkey  ps_availqty  ps_supplycost  \
# 0                1           2         3325         771.64
# 1                1        2502         8076         993.49
# 2                1        5002         3956         337.09
# 3                1        7502         4069         357.84
# 4                2           3         8895         378.49
# ...            ...         ...          ...            ...
# 799995      199999        7557         7784         259.56
# 799996      200000           1         3372          74.18
# 799997      200000        2520         8522         192.45
# 799998      200000        5039          605           3.91
# 799999      200000        7558         2583         996.65
#
#                                                ps_comment
# 0       , even theodolites. regular, final theodolites...
# 1       ven ideas. quickly even packages print. pendin...
# 2       after the fluffily ironic deposits? blithely s...
# ...

# %%
partsupp = partsupp.head(200)
# partsupp.to_csv("partsupp_1.csv", index = False)

# %%
supplier = pd.read_table("./supplier.tbl", sep = "|",
                         header = None)
supplier = supplier.dropna(axis = "columns")

# %%
supplier.columns = ["s_suppkey",
    "s_name",
    "s_address",
    "s_nationkey",
    "s_phone",
    "s_acctbal" ,
    "s_comment" ]

# %%
supplier
# Out:
#       s_suppkey              s_name                            s_address  \
# 0             1  Supplier#000000001   N kD4on9OM Ipw3,gf0JBoQDd7tgrzrddZ
# 1             2  Supplier#000000002                89eJ5ksX3ImxJQBvxObC,
# 2             3  Supplier#000000003    q1,G3Pj6OjIuUYfUoH18BFTKP5aU9bEV3
# 3             4  Supplier#000000004            Bk7ah4CK8SYQTepEmvMkkgMwg
# 4             5  Supplier#000000005                    Gcdm2rJRzl5qlTVzc
# ...         ...                 ...                                  ...
# 9995       9996  Supplier#000009996               a4eOd7SzN5RnrCwyAh5iey
# 9996       9997  Supplier#000009997                       Wc0lgaT,CWQYMS
# 9997       9998  Supplier#000009998           1RTcQaCJzbx7GAjIc,tajct,8K
# 9998       9999  Supplier#000009999                mX37oAzqsBPhN1LWdzV p
# 9999      10000  Supplier#000010000     aTGLEusCiL4F PDBdv665XBJhPyCOB0i
#
#       s_nationkey          s_phone  s_acctbal  \
# ...

# %%
supplier = supplier.head(200)
# supplier.to_csv("supplier_1.csv", index = False)

# %%
part = pd.read_table("./part.tbl", sep = "|",
                         header = None)
part = part.dropna(axis = "columns")
part
# Out:
#              0                                         1               2  \
# 0            1  goldenrod lavender spring chocolate lace  Manufacturer#1
# 1            2          blush thistle blue yellow saddle  Manufacturer#1
# 2            3       spring green yellow purple cornsilk  Manufacturer#4
# 3            4     cornflower chocolate smoke green pink  Manufacturer#3
# 4            5             forest brown coral puff cream  Manufacturer#3
# ...        ...                                       ...             ...
# 199995  199996           cream navajo saddle dodger navy  Manufacturer#4
# 199996  199997          peru maroon snow grey chartreuse  Manufacturer#4
# 199997  199998          pink wheat powder burlywood snow  Manufacturer#5
# 199998  199999          goldenrod drab brown salmon mint  Manufacturer#5
# 199999  200000            peach royal cornsilk sky sandy  Manufacturer#5
#
#                3                        4   5          6        7  \
# ...

# %%
part.columns = ["p_partkey",
    "p_name",       
    "p_mfgr",
    "p_brand",  
    "p_type",     
    "p_size",     
    "p_container",  
    "p_retailprice", 
    "p_comment" ]

# %%
part = part.head(200)
# part.to_csv("part_1.csv", index = False)

# %%
part
# Out:
#      p_partkey                                     p_name          p_mfgr  \
# 0            1   goldenrod lavender spring chocolate lace  Manufacturer#1
# 1            2           blush thistle blue yellow saddle  Manufacturer#1
# 2            3        spring green yellow purple cornsilk  Manufacturer#4
# 3            4      cornflower chocolate smoke green pink  Manufacturer#3
# 4            5              forest brown coral puff cream  Manufacturer#3
# ..         ...                                        ...             ...
# 195        196                 pale peru linen hot maroon  Manufacturer#3
# 196        197                 lawn lemon khaki rosy blue  Manufacturer#5
# 197        198  orange cornflower indian aquamarine white  Manufacturer#4
# 198        199             ivory slate lavender tan royal  Manufacturer#3
# 199        200               peach cornsilk navy rosy red  Manufacturer#5
#
#       p_brand                   p_type  p_size p_container  p_retailprice  \
# ...

# %%
nation = pd.read_table("./nation.tbl", sep = "|",
                         header = None)
nation = nation.dropna(axis = "columns")

# %%
nation.columns = ["n_nationkey",
    "n_name",
    "n_regionkey",
    "n_comment" ]

# %%
nation
# Out:
#     n_nationkey          n_name  n_regionkey  \
# 0             0         ALGERIA            0
# 1             1       ARGENTINA            1
# 2             2          BRAZIL            1
# 3             3          CANADA            1
# 4             4           EGYPT            4
# 5             5        ETHIOPIA            0
# 6             6          FRANCE            3
# 7             7         GERMANY            3
# 8             8           INDIA            2
# 9             9       INDONESIA            2
# 10           10            IRAN            4
# 11           11            IRAQ            4
# 12           12           JAPAN            2
# 13           13          JORDAN            4
# 14           14           KENYA            0
# 15           15         MOROCCO            0
# 16           16      MOZAMBIQUE            0
# 17           17            PERU            1
# 18           18           CHINA            2
# 19           19         ROMANIA            3
# ...

# %%
nation[nation['REGIONKEY'] > 0]

# %%
nation

nation.to_csv("nation_1.csv", index = False)

# %%
region = pd.read_table("./region.tbl", sep = "|",
                         header = None)
region = region.dropna(axis = "columns")

# %%
region.columns = [
"r_regionkey",
    "r_name",
    "r_comment",

]

# %%
region
# Out:
#    r_regionkey       r_name                                          r_comment
# 0            0       AFRICA  lar deposits. blithely final packages cajole. ...
# 1            1      AMERICA                    hs use ironic, even requests. s
# 2            2         ASIA                    ges. thinly even pinto beans ca
# 3            3       EUROPE      ly final courts cajole furiously final excuse
# 4            4  MIDDLE EAST  uickly special accounts cajole carefully blith...

# %%
# region.to_csv("region_1.csv", index = False)

# %%
df = pd.read_csv("customer.csv")

# %%
df

# %%
orders[(orders['TOTALPRICE'] > 50000.0) | (orders['SHIPPRIORITY'] == 0)][['STATUS','CUSTKEY','TOTALPRICE','ORDERPRIORITY','CLERK']].groupby(by=['STATUS']).agg('max')

# %%
orders

# %%
rs = customer[(customer['ACCTBAL'] > -917.75) | (customer['CUSTKEY'] > 1.0)][['CUSTKEY','C_NAME','PHONE','ACCTBAL','C_COMMENT']].merge(customer[(customer['ACCTBAL'] == 1666.02) | (customer['CUSTKEY'] == 25.75)][['CUSTKEY','ADDRESS','ACCTBAL','MKTSEGMENT','C_COMMENT']]on=CUSTKEY)

# %%
customer[(customer['ACCTBAL'] >= 9983.38) | (customer['CUSTKEY'] >= 100.0)][['ADDRESS','PHONE','ACCTBAL','MKTSEGMENT','C_COMMENT']].merge(customer[(customer['ACCTBAL'] > -917.75) | (customer['CUSTKEY'] > 1.0)][['C_NAME','ADDRESS','NATIONKEY','PHONE','MKTSEGMENT']],on='ADDRESS')

# %%
customer[(customer['ACCTBAL'] >= 100.0) | (customer['CUSTKEY'] >= 100.0)][['CUSTKEY','C_NAME','NATIONKEY','PHONE','C_COMMENT']].merge(orders[(orders['TOTALPRICE'] >= 1156.67) | (orders['SHIPPRIORITY'] >= 0.0)][['CUSTKEY','ORDERSTATUS','CLERK','SHIPPRIORITY']],on=['CUSTKEY'])

# %%
customer[(customer['ACCTBAL'] >= 4608.54) | (customer['CUSTKEY'] >= 50.5)]
[['C_NAME','NATIONKEY','PHONE','ACCTBAL','C_COMMENT']].merge(supplier[(supplier['NATIONKEY'] < 24.0) | (supplier['ACCTBAL'] < 9915.24)][['SUPPKEY','ADDRESS','NATIONKEY']],on=['NATIONKEY'])

# %%
customer = pd.read_csv("./customer_1.csv")

# %%
customer
# Out:
#     c_custkey              c_name                       c_address  \
# 0           1  Customer#000000001               IVhzIApeRb ot,c,E
# 1           2  Customer#000000002  XSTf4,NCwDVaWNe6tEgvwfmRchLXak
# 2           3  Customer#000000003                    MG9kdTD2WBHm
# 3           4  Customer#000000004                     XxVSJsLAGtn
# 4           5  Customer#000000005    KvpyuHCplrB84WgAiGV6sYpZq7Tj
# ..        ...                 ...                             ...
# 95         96  Customer#000000096                      vWLOrmXhRR
# 96         97  Customer#000000097           OApyejbhJG,0Iw3j rd1M
# 97         98  Customer#000000098              7yiheXNSpuEAwbswDW
# 98         99  Customer#000000099                szsrOiPtCHVS97Lt
# 99        100  Customer#000000100                  fptUABXcmkC5Wx
#
#     c_nationkey          c_phone  c_acctbal c_mktsegment  \
# 0            15  25-989-741-2988     711.56     BUILDING
# ...

# %%
supplier = pd.read_csv("./supplier_1.csv")

# %%
customer.merge(supplier, left_on = "c_nationkey", right_on = "s_nationkey")
# Out:
#      c_custkey              c_name                  c_address  c_nationkey  \
# 0            1  Customer#000000001          IVhzIApeRb ot,c,E           15
# 1            1  Customer#000000001          IVhzIApeRb ot,c,E           15
# 2            1  Customer#000000001          IVhzIApeRb ot,c,E           15
# 3            1  Customer#000000001          IVhzIApeRb ot,c,E           15
# 4            1  Customer#000000001          IVhzIApeRb ot,c,E           15
# ..         ...                 ...                        ...          ...
# 759         89  Customer#000000089  dtR, y9JQWUO6FoJExyp8whOU           14
# 760         89  Customer#000000089  dtR, y9JQWUO6FoJExyp8whOU           14
# 761         89  Customer#000000089  dtR, y9JQWUO6FoJExyp8whOU           14
# 762         89  Customer#000000089  dtR, y9JQWUO6FoJExyp8whOU           14
# 763         89  Customer#000000089  dtR, y9JQWUO6FoJExyp8whOU           14
#
#              c_phone  c_acctbal c_mktsegment  \
# ...

# %%
customer = pd.read_csv("./customer_1.csv")

# %%
customer
# Out:
#     c_custkey              c_name                       c_address  \
# 0           1  Customer#000000001               IVhzIApeRb ot,c,E
# 1           2  Customer#000000002  XSTf4,NCwDVaWNe6tEgvwfmRchLXak
# 2           3  Customer#000000003                    MG9kdTD2WBHm
# 3           4  Customer#000000004                     XxVSJsLAGtn
# 4           5  Customer#000000005    KvpyuHCplrB84WgAiGV6sYpZq7Tj
# ..        ...                 ...                             ...
# 95         96  Customer#000000096                      vWLOrmXhRR
# 96         97  Customer#000000097           OApyejbhJG,0Iw3j rd1M
# 97         98  Customer#000000098              7yiheXNSpuEAwbswDW
# 98         99  Customer#000000099                szsrOiPtCHVS97Lt
# 99        100  Customer#000000100                  fptUABXcmkC5Wx
#
#     c_nationkey          c_phone  c_acctbal c_mktsegment  \
# 0            15  25-989-741-2988     711.56     BUILDING
# ...

# %%
supplier = pd.read_csv("./supplier_1.csv")

# %%
customer.merge(supplier, left_on = "C_NATIONKEY", right_on = "S_NATIONKEY")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/fv/kj6xtlgj55v5rlh_8jvsw8vc0000gn/T/ipykernel_54980/3396854918.py in <module>
# ----> 1 customer.merge(supplier, left_on = "C_NATIONKEY", right_on = "S_NATIONKEY")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9188         from pandas.core.reshape.merge import merge
#    9189
# -> 9190         return merge(
#    9191             self,
#    9192             right,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
# ...

# %%
df0 = customer[(customer['c_acctbal'] > 12866) | (customer['c_custkey'] > 151)][['c_custkey','c_phone','c_mktsegment','c_comment']] 
df1 = customer[(customer['c_acctbal'] > 2251) & (customer['c_custkey'] > 119)][['c_custkey','c_name','c_mktsegment','c_comment']] 
df2 = customer[(customer['c_acctbal'] <= 4213) & (customer['c_custkey'] <= 19)][['c_custkey','c_address','c_phone','c_comment']] 
df3 = customer[(customer['c_acctbal'] <= 3594) & (customer['c_custkey'] <= 119)][['c_name','c_address','c_phone','c_acctbal','c_mktsegment']] 
df4 = customer[(customer['c_acctbal'] <= 9419) | (customer['c_custkey'] <= 122)][['c_name','c_address','c_nationkey','c_acctbal']] 
df5 = customer[(customer['c_acctbal'] == 6774) & (customer['c_custkey'] == 126)][['c_name','c_address','c_nationkey','c_acctbal','c_mktsegment','c_comment']] 
df6 = customer[(customer['c_acctbal'] >= 4647) | (customer['c_custkey'] >= 28)][['c_custkey','c_name','c_address','c_phone']] 
df7 = customer[(customer['c_acctbal'] >= 2097) & (customer['c_custkey'] >= 8)][['c_custkey','c_phone','c_acctbal','c_mktsegment']] 
df8 = customer[(customer['c_acctbal'] <= 8463) | (customer['c_custkey'] <= 71)][['c_custkey','c_name','c_address','c_nationkey','c_acctbal']] 
df9 = customer[(customer['c_acctbal'] <= 4213) & (customer['c_custkey'] <= 19)][['c_custkey','c_name','c_phone','c_acctbal','c_mktsegment','c_comment']] 
df10 = customer[(customer['c_acctbal'] < 6324) & (customer['c_custkey'] < 28)][['c_custkey','c_address','c_phone','c_acctbal','c_mktsegment','c_comment']] 
df11 = customer[(customer['c_acctbal'] < 14488) | (customer['c_custkey'] < 185)][['c_custkey','c_name','c_phone','c_acctbal','c_mktsegment']] 
df12 = customer[(customer['c_acctbal'] == 13317) & (customer['c_custkey'] == 129)][['c_nationkey','c_phone','c_acctbal','c_comment']] 
df13 = customer[(customer['c_acctbal'] > 8268) & (customer['c_custkey'] > 112)][['c_name','c_address','c_nationkey','c_acctbal','c_mktsegment']] 
df14 = customer[(customer['c_acctbal'] > 8268) & (customer['c_custkey'] > 112)][['c_custkey','c_name','c_address','c_nationkey','c_acctbal','c_comment']] 
df15 = customer[(customer['c_acctbal'] == 8169) | (customer['c_custkey'] == 28)][['c_name','c_nationkey','c_acctbal','c_comment']] 
df16 = customer[(customer['c_acctbal'] == 6774) & (customer['c_custkey'] == 126)][['c_custkey','c_nationkey','c_phone','c_comment']] 
df17 = customer[(customer['c_acctbal'] > 8268) & (customer['c_custkey'] > 112)][['c_custkey','c_address','c_acctbal','c_comment']] 
df18 = customer[(customer['c_acctbal'] < 6324) & (customer['c_custkey'] < 28)][['c_custkey','c_name','c_nationkey','c_mktsegment','c_comment']] 
df19 = customer[(customer['c_acctbal'] < 4376) & (customer['c_custkey'] < 125)][['c_custkey','c_name','c_address','c_acctbal','c_mktsegment']] 
df20 = customer[(customer['c_acctbal'] <= 13814) | (customer['c_custkey'] <= 158)][['c_name','c_address','c_nationkey','c_phone','c_comment']] 
df21 = customer[(customer['c_acctbal'] >= 8127) & (customer['c_custkey'] >= 100)][['c_custkey','c_address','c_nationkey','c_acctbal','c_comment']] 
df22 = customer[(customer['c_acctbal'] > 12866) & (customer['c_custkey'] > 151)][['c_name','c_address','c_nationkey','c_phone','c_acctbal','c_comment']] 
df23 = customer[(customer['c_acctbal'] == 6774) & (customer['c_custkey'] == 126)][['c_custkey','c_name','c_address','c_acctbal']] 
df24 = customer[(customer['c_acctbal'] > 12866) & (customer['c_custkey'] > 151)][['c_custkey','c_name','c_address','c_nationkey','c_comment']] 
df25 = customer[(customer['c_acctbal'] == 13317) & (customer['c_custkey'] == 129)][['c_custkey','c_address','c_nationkey','c_phone','c_acctbal','c_comment']] 
df26 = customer[(customer['c_acctbal'] <= 13814) | (customer['c_custkey'] <= 158)][['c_custkey','c_name','c_phone','c_acctbal']] 
df27 = customer[(customer['c_acctbal'] >= 8127) & (customer['c_custkey'] >= 100)][['c_name','c_phone','c_acctbal','c_comment']] 
df28 = customer[(customer['c_acctbal'] > 6187) | (customer['c_custkey'] > 51)][['c_address','c_nationkey','c_acctbal','c_comment']] 
df29 = customer[(customer['c_acctbal'] <= 8389) | (customer['c_custkey'] <= 69)][['c_custkey','c_address','c_phone','c_acctbal']] 
df30 = customer[(customer['c_acctbal'] > 2967) & (customer['c_custkey'] > 18)][['c_custkey','c_phone','c_mktsegment','c_comment']] 
df31 = customer[(customer['c_acctbal'] >= 11383) | (customer['c_custkey'] >= 128)][['c_custkey','c_address','c_nationkey','c_phone','c_acctbal','c_comment']] 
df32 = customer[(customer['c_acctbal'] <= 7156) & (customer['c_custkey'] <= 73)][['c_custkey','c_name','c_address','c_comment']] 
df33 = customer[(customer['c_acctbal'] > 2967) & (customer['c_custkey'] > 18)][['c_name','c_address','c_nationkey','c_acctbal','c_comment']] 
df34 = customer[(customer['c_acctbal'] < 14488) | (customer['c_custkey'] < 185)][['c_name','c_address','c_acctbal','c_mktsegment','c_comment']] 
df35 = customer[(customer['c_acctbal'] < 11995) & (customer['c_custkey'] < 124)][['c_custkey','c_name','c_nationkey','c_phone','c_acctbal']] 
df36 = customer[(customer['c_acctbal'] < 11210) & (customer['c_custkey'] < 90)][['c_custkey','c_name','c_mktsegment','c_comment']] 
df37 = customer[(customer['c_acctbal'] == 13317) & (customer['c_custkey'] == 129)][['c_custkey','c_name','c_nationkey','c_phone','c_acctbal']] 
df38 = customer[(customer['c_acctbal'] >= 6225) | (customer['c_custkey'] >= 58)][['c_custkey','c_nationkey','c_acctbal','c_mktsegment']] 
df39 = customer[(customer['c_acctbal'] >= 3168) | (customer['c_custkey'] >= 43)][['c_custkey','c_address','c_nationkey','c_phone','c_acctbal','c_comment']] 
df40 = customer[(customer['c_acctbal'] < 11210) & (customer['c_custkey'] < 90)][['c_custkey','c_address','c_phone','c_acctbal']] 
df41 = customer[(customer['c_acctbal'] == 11530) | (customer['c_custkey'] == 93)][['c_custkey','c_name','c_address','c_acctbal','c_comment']] 
df42 = customer[(customer['c_acctbal'] < 4376) & (customer['c_custkey'] < 125)][['c_name','c_nationkey','c_acctbal','c_comment']] 
df43 = customer[(customer['c_acctbal'] >= 6225) | (customer['c_custkey'] >= 58)][['c_custkey','c_name','c_phone','c_acctbal','c_mktsegment']] 
df44 = customer[(customer['c_acctbal'] == 11530) | (customer['c_custkey'] == 93)][['c_name','c_address','c_nationkey','c_phone']] 
df45 = customer[(customer['c_acctbal'] < 11210) & (customer['c_custkey'] < 90)][['c_nationkey','c_phone','c_mktsegment','c_comment']] 
df46 = customer[(customer['c_acctbal'] <= 13814) | (customer['c_custkey'] <= 158)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']] 
df47 = customer[(customer['c_acctbal'] <= 8389) | (customer['c_custkey'] <= 69)][['c_custkey','c_address','c_nationkey','c_acctbal']] 
df48 = customer[(customer['c_acctbal'] < 14488) | (customer['c_custkey'] < 185)][['c_custkey','c_name','c_nationkey','c_mktsegment']] 
df49 = customer[(customer['c_acctbal'] >= 2097) | (customer['c_custkey'] >= 8)][['c_name','c_phone','c_mktsegment','c_comment']] 
df50 = customer[(customer['c_acctbal'] <= 10630) & (customer['c_custkey'] <= 73)][['c_custkey','c_name','c_address','c_phone','c_acctbal','c_comment']] 
df51 = customer[(customer['c_acctbal'] > 12866) | (customer['c_custkey'] > 151)][['c_name','c_phone','c_mktsegment','c_comment']] 
df52 = customer[(customer['c_acctbal'] <= 8463) | (customer['c_custkey'] <= 71)][['c_custkey','c_address','c_nationkey','c_phone','c_acctbal','c_mktsegment']] 
df53 = customer[(customer['c_acctbal'] == 8169) & (customer['c_custkey'] == 28)][['c_custkey','c_address','c_nationkey','c_phone','c_acctbal','c_comment']] 
df54 = customer[(customer['c_acctbal'] >= 3168) | (customer['c_custkey'] >= 43)][['c_address','c_nationkey','c_phone','c_acctbal']] 
df55 = customer[(customer['c_acctbal'] > 6187) | (customer['c_custkey'] > 51)][['c_custkey','c_acctbal','c_mktsegment','c_comment']] 
df56 = customer[(customer['c_acctbal'] == 13147) | (customer['c_custkey'] == 115)][['c_phone','c_acctbal','c_mktsegment','c_comment']] 
df57 = customer[(customer['c_acctbal'] >= 2097) | (customer['c_custkey'] >= 8)][['c_custkey','c_address','c_phone','c_acctbal','c_comment']] 
df58 = customer[(customer['c_acctbal'] >= 11383) | (customer['c_custkey'] >= 128)][['c_name','c_nationkey','c_phone','c_mktsegment','c_comment']] 
df59 = customer[(customer['c_acctbal'] <= 7156) & (customer['c_custkey'] <= 73)][['c_name','c_address','c_nationkey','c_mktsegment','c_comment']] 
df60 = customer[(customer['c_acctbal'] <= 7156) & (customer['c_custkey'] <= 73)][['c_custkey','c_name','c_nationkey','c_phone','c_acctbal']] 
df61 = customer[(customer['c_acctbal'] == 11530) | (customer['c_custkey'] == 93)][['c_custkey','c_name','c_nationkey','c_phone','c_mktsegment','c_comment']] 
df62 = customer[(customer['c_acctbal'] < 12844) & (customer['c_custkey'] < 94)][['c_custkey','c_address','c_phone','c_acctbal','c_comment']] 
df63 = customer[(customer['c_acctbal'] <= 4213) & (customer['c_custkey'] <= 19)][['c_custkey','c_address','c_mktsegment','c_comment']] 
df64 = customer[(customer['c_acctbal'] > 2967) & (customer['c_custkey'] > 18)][['c_custkey','c_name','c_address','c_nationkey','c_acctbal','c_mktsegment']] 
df65 = customer[(customer['c_acctbal'] == 8169) | (customer['c_custkey'] == 28)][['c_name','c_address','c_nationkey','c_acctbal','c_mktsegment']] 
df66 = customer[(customer['c_acctbal'] > 12866) | (customer['c_custkey'] > 151)][['c_name','c_address','c_phone','c_acctbal','c_mktsegment','c_comment']] 
df67 = customer[(customer['c_acctbal'] <= 13814) | (customer['c_custkey'] <= 158)][['c_custkey','c_phone','c_acctbal','c_mktsegment','c_comment']] 
df68 = customer[(customer['c_acctbal'] > 6187) | (customer['c_custkey'] > 51)][['c_custkey','c_name','c_address','c_nationkey','c_phone','c_mktsegment']] 
df69 = customer[(customer['c_acctbal'] == 6774) & (customer['c_custkey'] == 126)][['c_custkey','c_address','c_nationkey','c_acctbal','c_mktsegment']] 
df70 = customer[(customer['c_acctbal'] < 9603) | (customer['c_custkey'] < 73)][['c_name','c_address','c_mktsegment','c_comment']] 
df71 = customer[(customer['c_acctbal'] <= 4213) & (customer['c_custkey'] <= 19)][['c_name','c_nationkey','c_phone','c_mktsegment']] 
df72 = customer[(customer['c_acctbal'] > 2967) & (customer['c_custkey'] > 18)][['c_name','c_nationkey','c_mktsegment','c_comment']] 
df73 = customer[(customer['c_acctbal'] < 11210) & (customer['c_custkey'] < 90)][['c_name','c_nationkey','c_acctbal','c_mktsegment','c_comment']] 
df74 = customer[(customer['c_acctbal'] > 8366) & (customer['c_custkey'] > 70)][['c_custkey','c_phone','c_acctbal','c_comment']] 
df75 = customer[(customer['c_acctbal'] <= 13814) | (customer['c_custkey'] <= 158)][['c_address','c_acctbal','c_mktsegment','c_comment']] 
df76 = customer[(customer['c_acctbal'] > 2967) & (customer['c_custkey'] > 18)][['c_custkey','c_name','c_nationkey','c_phone']] 
df77 = customer[(customer['c_acctbal'] > 6187) | (customer['c_custkey'] > 51)][['c_custkey','c_address','c_phone','c_acctbal','c_mktsegment']] 
df78 = customer[(customer['c_acctbal'] >= 2097) & (customer['c_custkey'] >= 8)][['c_name','c_address','c_nationkey','c_acctbal','c_mktsegment']] 
df79 = customer[(customer['c_acctbal'] > 12866) & (customer['c_custkey'] > 151)][['c_custkey','c_name','c_address','c_nationkey','c_mktsegment']] 
df80 = customer[(customer['c_acctbal'] < 14488) | (customer['c_custkey'] < 185)][['c_custkey','c_address','c_acctbal','c_mktsegment']] 
df81 = customer[(customer['c_acctbal'] >= 5213) | (customer['c_custkey'] >= 64)][['c_name','c_address','c_nationkey','c_acctbal','c_mktsegment','c_comment']] 
df82 = customer[(customer['c_acctbal'] < 6324) & (customer['c_custkey'] < 28)][['c_custkey','c_address','c_nationkey','c_mktsegment','c_comment']] 
df83 = customer[(customer['c_acctbal'] < 12844) & (customer['c_custkey'] < 94)][['c_custkey','c_phone','c_mktsegment','c_comment']] 
df84 = customer[(customer['c_acctbal'] == 14975) & (customer['c_custkey'] == 95)][['c_custkey','c_name','c_address','c_nationkey','c_comment']] 
df85 = customer[(customer['c_acctbal'] >= 11383) | (customer['c_custkey'] >= 128)][['c_custkey','c_phone','c_acctbal','c_comment']] 
df86 = customer[(customer['c_acctbal'] <= 3594) & (customer['c_custkey'] <= 119)][['c_address','c_nationkey','c_acctbal','c_comment']] 
df87 = customer[(customer['c_acctbal'] == 11530) | (customer['c_custkey'] == 93)][['c_custkey','c_address','c_nationkey','c_acctbal','c_comment']] 
df88 = customer[(customer['c_acctbal'] >= 6225) | (customer['c_custkey'] >= 58)][['c_custkey','c_address','c_phone','c_comment']] 
df89 = customer[(customer['c_acctbal'] >= 4647) | (customer['c_custkey'] >= 28)][['c_custkey','c_address','c_phone','c_acctbal']] 
df90 = customer[(customer['c_acctbal'] >= 2097) & (customer['c_custkey'] >= 8)][['c_custkey','c_address','c_phone','c_acctbal','c_comment']] 
df91 = customer[(customer['c_acctbal'] <= 9419) | (customer['c_custkey'] <= 122)][['c_custkey','c_name','c_nationkey','c_mktsegment']] 
df92 = customer[(customer['c_acctbal'] > 7730) & (customer['c_custkey'] > 69)][['c_custkey','c_name','c_address','c_mktsegment']] 
df93 = customer[(customer['c_acctbal'] >= 1008) | (customer['c_custkey'] >= 113)][['c_custkey','c_name','c_address','c_nationkey']] 
df94 = customer[(customer['c_acctbal'] < 9603) | (customer['c_custkey'] < 73)][['c_nationkey','c_acctbal','c_mktsegment','c_comment']] 
df95 = customer[(customer['c_acctbal'] < 9603) | (customer['c_custkey'] < 73)][['c_custkey','c_name','c_address','c_acctbal','c_mktsegment','c_comment']] 
df96 = customer[(customer['c_acctbal'] < 7527) & (customer['c_custkey'] < 79)][['c_custkey','c_name','c_nationkey','c_phone','c_acctbal','c_comment']] 
df97 = customer[(customer['c_acctbal'] > 6187) | (customer['c_custkey'] > 51)][['c_custkey','c_name','c_address','c_mktsegment','c_comment']] 
df98 = customer[(customer['c_acctbal'] <= 7156) & (customer['c_custkey'] <= 73)][['c_name','c_address','c_nationkey','c_acctbal']] 
df99 = customer[(customer['c_acctbal'] < 7527) & (customer['c_custkey'] < 79)][['c_name','c_nationkey','c_phone','c_mktsegment']] 
df100 = customer[(customer['c_acctbal'] > 2849) & (customer['c_custkey'] > 133)][['c_custkey','c_address','c_nationkey','c_mktsegment']].groupby(by=['c_mktsegment']).agg('min',numeric_only=True) 
df101 = customer[(customer['c_acctbal'] > 6754) & (customer['c_custkey'] > 72)][['c_custkey','c_nationkey','c_phone','c_mktsegment','c_comment']].groupby(by=['c_comment']).agg('min',numeric_only=True) 
df102 = customer[(customer['c_acctbal'] < 5709) & (customer['c_custkey'] < 80)][['c_name','c_address','c_phone','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_phone']).agg('max',numeric_only=True) 
df103 = customer[(customer['c_acctbal'] <= 5546) | (customer['c_custkey'] <= 60)][['c_name','c_nationkey','c_phone','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_phone']).agg('max',numeric_only=True) 
df104 = customer[(customer['c_acctbal'] <= 9758) | (customer['c_custkey'] <= 98)][['c_custkey','c_name','c_address','c_nationkey','c_acctbal','c_mktsegment']].groupby(by=['c_acctbal']).agg('mean',numeric_only=True) 
df105 = customer[(customer['c_acctbal'] > 11119) | (customer['c_custkey'] > 123)][['c_custkey','c_address','c_nationkey','c_comment']].groupby(by=['c_address']).agg('mean',numeric_only=True) 
df106 = customer[(customer['c_acctbal'] < 10682) | (customer['c_custkey'] < 89)][['c_custkey','c_name','c_address','c_nationkey','c_phone','c_acctbal']].groupby(by=['c_custkey']).agg('mean',numeric_only=True) 
df107 = customer[(customer['c_acctbal'] < 4052) & (customer['c_custkey'] < 185)][['c_custkey','c_address','c_nationkey','c_phone','c_acctbal','c_mktsegment']].groupby(by=['c_custkey']).agg('min',numeric_only=True) 
df108 = customer[(customer['c_acctbal'] > 2849) & (customer['c_custkey'] > 133)][['c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].groupby(by=['c_mktsegment']).agg('max',numeric_only=True) 
df109 = customer[(customer['c_acctbal'] == 5902) | (customer['c_custkey'] == 192)][['c_custkey','c_name','c_address','c_nationkey','c_phone','c_comment']].groupby(by=['c_custkey']).agg('max',numeric_only=True) 
df110 = customer[(customer['c_acctbal'] > 3312) & (customer['c_custkey'] > 77)][['c_custkey','c_nationkey','c_phone','c_acctbal']].groupby(by=['c_custkey']).agg('mean',numeric_only=True) 
df111 = customer[(customer['c_acctbal'] <= 9871) | (customer['c_custkey'] <= 140)][['c_name','c_address','c_phone','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_name']).agg('max',numeric_only=True) 
df112 = customer[(customer['c_acctbal'] == 14860) | (customer['c_custkey'] == 175)][['c_name','c_phone','c_acctbal','c_mktsegment']].groupby(by=['c_mktsegment']).agg('max',numeric_only=True) 
df113 = customer[(customer['c_acctbal'] == 7764) | (customer['c_custkey'] == 82)][['c_name','c_address','c_nationkey','c_mktsegment']].groupby(by=['c_address']).agg('min',numeric_only=True) 
df114 = customer[(customer['c_acctbal'] < 13686) | (customer['c_custkey'] < 150)][['c_custkey','c_name','c_address','c_mktsegment','c_comment']].groupby(by=['c_address']).agg('max',numeric_only=True) 
df115 = customer[(customer['c_acctbal'] < 6581) & (customer['c_custkey'] < 107)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].groupby(by=['c_nationkey']).agg('min',numeric_only=True) 
df116 = customer[(customer['c_acctbal'] >= 504) & (customer['c_custkey'] >= 23)][['c_name','c_nationkey','c_phone','c_acctbal']].groupby(by=['c_name']).agg('max',numeric_only=True) 
df117 = customer[(customer['c_acctbal'] >= 11054) & (customer['c_custkey'] >= 113)][['c_custkey','c_address','c_nationkey','c_phone','c_acctbal','c_comment']].groupby(by=['c_phone']).agg('mean',numeric_only=True) 
df118 = customer[(customer['c_acctbal'] >= 4795) | (customer['c_custkey'] >= 63)][['c_custkey','c_name','c_address','c_nationkey','c_mktsegment']].groupby(by=['c_mktsegment']).agg('max',numeric_only=True) 
df119 = customer[(customer['c_acctbal'] == 7764) | (customer['c_custkey'] == 82)][['c_name','c_nationkey','c_phone','c_acctbal','c_mktsegment']].groupby(by=['c_mktsegment']).agg('min',numeric_only=True) 
df120 = customer[(customer['c_acctbal'] < 10682) | (customer['c_custkey'] < 89)][['c_custkey','c_name','c_address','c_nationkey','c_acctbal','c_comment']].groupby(by=['c_nationkey']).agg('min',numeric_only=True) 
df121 = customer[(customer['c_acctbal'] == 7764) | (customer['c_custkey'] == 82)][['c_name','c_address','c_nationkey','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_name']).agg('mean',numeric_only=True) 
df122 = customer[(customer['c_acctbal'] >= 4795) | (customer['c_custkey'] >= 63)][['c_custkey','c_address','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_custkey']).agg('max',numeric_only=True) 
df123 = customer[(customer['c_acctbal'] < 5709) | (customer['c_custkey'] < 80)][['c_name','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_comment']).agg('min',numeric_only=True) 
df124 = customer[(customer['c_acctbal'] >= 11054) & (customer['c_custkey'] >= 113)][['c_name','c_nationkey','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_acctbal']).agg('min',numeric_only=True) 
df125 = customer[(customer['c_acctbal'] >= 7696) & (customer['c_custkey'] >= 95)][['c_custkey','c_name','c_address','c_phone','c_acctbal','c_mktsegment']].groupby(by=['c_phone']).agg('min',numeric_only=True) 
df126 = customer[(customer['c_acctbal'] >= 11054) & (customer['c_custkey'] >= 113)][['c_custkey','c_nationkey','c_phone','c_comment']].groupby(by=['c_phone']).agg('mean',numeric_only=True) 
df127 = customer[(customer['c_acctbal'] >= 504) & (customer['c_custkey'] >= 23)][['c_address','c_nationkey','c_phone','c_acctbal','c_mktsegment']].groupby(by=['c_acctbal']).agg('min',numeric_only=True) 
df128 = customer[(customer['c_acctbal'] > 9621) & (customer['c_custkey'] > 114)][['c_custkey','c_nationkey','c_acctbal','c_mktsegment']].groupby(by=['c_mktsegment']).agg('max',numeric_only=True) 
df129 = customer[(customer['c_acctbal'] > 6874) | (customer['c_custkey'] > 92)][['c_nationkey','c_phone','c_mktsegment','c_comment']].groupby(by=['c_comment']).agg('min',numeric_only=True) 
df130 = customer[(customer['c_acctbal'] > 9621) & (customer['c_custkey'] > 114)][['c_custkey','c_nationkey','c_acctbal','c_mktsegment']].groupby(by=['c_custkey']).agg('max',numeric_only=True) 
df131 = customer[(customer['c_acctbal'] > 6754) & (customer['c_custkey'] > 72)][['c_custkey','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_acctbal']).agg('min',numeric_only=True) 
df132 = customer[(customer['c_acctbal'] < 13686) & (customer['c_custkey'] < 150)][['c_custkey','c_name','c_address','c_comment']].groupby(by=['c_address']).agg('min',numeric_only=True) 
df133 = customer[(customer['c_acctbal'] >= 11054) & (customer['c_custkey'] >= 113)][['c_custkey','c_address','c_nationkey','c_mktsegment','c_comment']].groupby(by=['c_custkey']).agg('max',numeric_only=True) 
df134 = customer[(customer['c_acctbal'] < 5709) & (customer['c_custkey'] < 80)][['c_custkey','c_address','c_phone','c_acctbal','c_mktsegment']].groupby(by=['c_acctbal']).agg('min',numeric_only=True) 
df135 = customer[(customer['c_acctbal'] > 7490) & (customer['c_custkey'] > 75)][['c_custkey','c_address','c_nationkey','c_acctbal','c_mktsegment']].groupby(by=['c_nationkey']).agg('max',numeric_only=True) 
df136 = customer[(customer['c_acctbal'] < 6581) & (customer['c_custkey'] < 107)][['c_custkey','c_name','c_phone','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_name']).agg('min',numeric_only=True) 
df137 = customer[(customer['c_acctbal'] >= 504) & (customer['c_custkey'] >= 23)][['c_custkey','c_address','c_nationkey','c_phone']].groupby(by=['c_phone']).agg('max',numeric_only=True) 
df138 = customer[(customer['c_acctbal'] > 2644) | (customer['c_custkey'] > 44)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment']].groupby(by=['c_nationkey']).agg('max',numeric_only=True) 
df139 = customer[(customer['c_acctbal'] == 7764) | (customer['c_custkey'] == 82)][['c_name','c_phone','c_acctbal','c_comment']].groupby(by=['c_custkey']).agg('max',numeric_only=True) 
df140 = customer[(customer['c_acctbal'] <= 5546) | (customer['c_custkey'] <= 60)][['c_custkey','c_name','c_address','c_phone','c_acctbal','c_mktsegment']].groupby(by=['c_mktsegment']).agg('mean',numeric_only=True) 
df141 = customer[(customer['c_acctbal'] == 14309) | (customer['c_custkey'] == 116)][['c_custkey','c_nationkey','c_phone','c_acctbal']].groupby(by=['c_nationkey']).agg('max',numeric_only=True) 
df142 = customer[(customer['c_acctbal'] < 5709) & (customer['c_custkey'] < 80)][['c_name','c_address','c_nationkey','c_acctbal']].groupby(by=['c_nationkey']).agg('mean',numeric_only=True) 
df143 = customer[(customer['c_acctbal'] <= 5546) & (customer['c_custkey'] <= 60)][['c_name','c_nationkey','c_phone','c_acctbal','c_comment']].groupby(by=['c_nationkey']).agg('min',numeric_only=True) 
df144 = customer[(customer['c_acctbal'] > 2644) | (customer['c_custkey'] > 44)][['c_custkey','c_name','c_address','c_nationkey','c_phone','c_mktsegment']].groupby(by=['c_address']).agg('mean',numeric_only=True) 
df145 = customer[(customer['c_acctbal'] < 13686) | (customer['c_custkey'] < 150)][['c_nationkey','c_phone','c_acctbal','c_mktsegment']].groupby(by=['c_mktsegment']).agg('mean',numeric_only=True) 
df146 = customer[(customer['c_acctbal'] >= 504) & (customer['c_custkey'] >= 23)][['c_custkey','c_name','c_address','c_nationkey','c_mktsegment']].groupby(by=['c_custkey']).agg('mean',numeric_only=True) 
df147 = customer[(customer['c_acctbal'] >= 11054) & (customer['c_custkey'] >= 113)][['c_custkey','c_address','c_nationkey','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_comment']).agg('max',numeric_only=True) 
df148 = customer[(customer['c_acctbal'] >= 11054) & (customer['c_custkey'] >= 113)][['c_custkey','c_address','c_nationkey','c_acctbal','c_mktsegment']].groupby(by=['c_nationkey']).agg('mean',numeric_only=True) 
df149 = customer[(customer['c_acctbal'] <= 9758) | (customer['c_custkey'] <= 98)][['c_name','c_nationkey','c_acctbal','c_comment']].groupby(by=['c_name']).agg('mean',numeric_only=True) 
df150 = customer[(customer['c_acctbal'] >= 504) | (customer['c_custkey'] >= 23)][['c_name','c_address','c_nationkey','c_phone','c_acctbal']].groupby(by=['c_name']).agg('max',numeric_only=True) 
df151 = customer[(customer['c_acctbal'] < 5709) & (customer['c_custkey'] < 80)][['c_custkey','c_name','c_nationkey','c_phone','c_acctbal']].groupby(by=['c_name']).agg('mean',numeric_only=True) 
df152 = customer[(customer['c_acctbal'] > 7490) & (customer['c_custkey'] > 75)][['c_custkey','c_name','c_address','c_phone','c_acctbal','c_comment']].groupby(by=['c_comment']).agg('max',numeric_only=True) 
df153 = customer[(customer['c_acctbal'] < 10682) | (customer['c_custkey'] < 89)][['c_nationkey','c_phone','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_comment']).agg('min',numeric_only=True) 
df154 = customer[(customer['c_acctbal'] < 5709) | (customer['c_custkey'] < 80)][['c_custkey','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_acctbal']).agg('min',numeric_only=True) 
df155 = customer[(customer['c_acctbal'] > 3312) & (customer['c_custkey'] > 77)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].groupby(by=['c_mktsegment']).agg('mean',numeric_only=True) 
df156 = customer[(customer['c_acctbal'] <= 11822) | (customer['c_custkey'] <= 136)][['c_custkey','c_address','c_nationkey','c_phone','c_acctbal','c_comment']].groupby(by=['c_nationkey']).agg('min',numeric_only=True) 
df157 = customer[(customer['c_acctbal'] >= 504) | (customer['c_custkey'] >= 23)][['c_custkey','c_address','c_phone','c_comment']].groupby(by=['c_custkey']).agg('min',numeric_only=True) 
df158 = customer[(customer['c_acctbal'] > 6874) | (customer['c_custkey'] > 92)][['c_custkey','c_address','c_nationkey','c_acctbal','c_comment']].groupby(by=['c_nationkey']).agg('mean',numeric_only=True) 
df159 = customer[(customer['c_acctbal'] <= 5546) & (customer['c_custkey'] <= 60)][['c_custkey','c_name','c_phone','c_comment']].groupby(by=['c_comment']).agg('max',numeric_only=True) 
df160 = customer[(customer['c_acctbal'] <= 5011) & (customer['c_custkey'] <= 89)][['c_custkey','c_nationkey','c_phone','c_acctbal','c_mktsegment']].groupby(by=['c_nationkey']).agg('mean',numeric_only=True) 
df161 = customer[(customer['c_acctbal'] < 13686) | (customer['c_custkey'] < 150)][['c_custkey','c_phone','c_acctbal','c_comment']].groupby(by=['c_phone']).agg('max',numeric_only=True) 
df162 = customer[(customer['c_acctbal'] <= 9758) | (customer['c_custkey'] <= 98)][['c_custkey','c_address','c_nationkey','c_acctbal']].groupby(by=['c_custkey']).agg('max',numeric_only=True) 
df163 = customer[(customer['c_acctbal'] <= 11822) & (customer['c_custkey'] <= 136)][['c_custkey','c_nationkey','c_acctbal','c_mktsegment']].groupby(by=['c_nationkey']).agg('min',numeric_only=True) 
df164 = customer[(customer['c_acctbal'] >= 5961) & (customer['c_custkey'] >= 61)][['c_name','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_mktsegment']).agg('min',numeric_only=True) 
df165 = customer[(customer['c_acctbal'] == 11182) | (customer['c_custkey'] == 117)][['c_custkey','c_phone','c_acctbal','c_mktsegment']].groupby(by=['c_custkey']).agg('max',numeric_only=True) 
df166 = customer[(customer['c_acctbal'] <= 11822) & (customer['c_custkey'] <= 136)][['c_custkey','c_name','c_address','c_nationkey']].groupby(by=['c_address']).agg('max',numeric_only=True) 
df167 = customer[(customer['c_acctbal'] < 4052) & (customer['c_custkey'] < 185)][['c_custkey','c_address','c_phone','c_acctbal','c_mktsegment']].groupby(by=['c_acctbal']).agg('max',numeric_only=True) 
df168 = customer[(customer['c_acctbal'] >= 504) | (customer['c_custkey'] >= 23)][['c_custkey','c_name','c_nationkey','c_phone','c_acctbal']].groupby(by=['c_custkey']).agg('min',numeric_only=True) 
df169 = customer[(customer['c_acctbal'] >= 5270) | (customer['c_custkey'] >= 47)][['c_name','c_address','c_nationkey','c_comment']].groupby(by=['c_address']).agg('mean',numeric_only=True) 
df170 = customer[(customer['c_acctbal'] >= 4795) | (customer['c_custkey'] >= 63)][['c_name','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_mktsegment']).agg('min',numeric_only=True) 
df171 = customer[(customer['c_acctbal'] > 11119) | (customer['c_custkey'] > 123)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment']].groupby(by=['c_custkey']).agg('mean',numeric_only=True) 
df172 = customer[(customer['c_acctbal'] <= 9758) | (customer['c_custkey'] <= 98)][['c_address','c_nationkey','c_phone','c_acctbal','c_comment']].groupby(by=['c_acctbal']).agg('max',numeric_only=True) 
df173 = customer[(customer['c_acctbal'] <= 8455) | (customer['c_custkey'] <= 82)][['c_custkey','c_address','c_nationkey','c_phone','c_acctbal','c_mktsegment']].groupby(by=['c_phone']).agg('min',numeric_only=True) 
df174 = customer[(customer['c_acctbal'] == 7764) | (customer['c_custkey'] == 82)][['c_custkey','c_address','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_acctbal']).agg('mean',numeric_only=True) 
df175 = customer[(customer['c_acctbal'] >= 5270) | (customer['c_custkey'] >= 47)][['c_custkey','c_name','c_address','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True) 
df176 = customer[(customer['c_acctbal'] <= 8455) | (customer['c_custkey'] <= 82)][['c_name','c_phone','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_name']).agg('min',numeric_only=True) 
df177 = customer[(customer['c_acctbal'] == 7764) | (customer['c_custkey'] == 82)][['c_custkey','c_name','c_nationkey','c_acctbal','c_comment']].groupby(by=['c_phone']).agg('min',numeric_only=True) 
df178 = customer[(customer['c_acctbal'] == 7764) | (customer['c_custkey'] == 82)][['c_custkey','c_name','c_nationkey','c_phone','c_acctbal','c_mktsegment']].groupby(by=['c_address']).agg('mean',numeric_only=True) 
df179 = customer[(customer['c_acctbal'] > 3312) & (customer['c_custkey'] > 77)][['c_custkey','c_address','c_nationkey','c_acctbal','c_comment']].groupby(by=['c_comment']).agg('max',numeric_only=True) 
df180 = customer[(customer['c_acctbal'] == 7764) | (customer['c_custkey'] == 82)][['c_custkey','c_name','c_phone','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_acctbal']).agg('max',numeric_only=True) 
df181 = customer[(customer['c_acctbal'] < 4052) & (customer['c_custkey'] < 185)][['c_custkey','c_address','c_phone','c_comment']].groupby(by=['c_phone']).agg('mean',numeric_only=True) 
df182 = customer[(customer['c_acctbal'] <= 3104) & (customer['c_custkey'] <= 161)][['c_nationkey','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_nationkey']).agg('max',numeric_only=True) 
df183 = customer[(customer['c_acctbal'] < 10830) & (customer['c_custkey'] < 116)][['c_custkey','c_address','c_nationkey','c_mktsegment','c_comment']].groupby(by=['c_custkey']).agg('mean',numeric_only=True) 
df184 = customer[(customer['c_acctbal'] < 5709) & (customer['c_custkey'] < 80)][['c_name','c_address','c_phone','c_acctbal']].groupby(by=['c_acctbal']).agg('min',numeric_only=True) 
df185 = customer[(customer['c_acctbal'] >= 504) & (customer['c_custkey'] >= 23)][['c_custkey','c_name','c_address','c_nationkey','c_acctbal','c_comment']].groupby(by=['c_acctbal']).agg('mean',numeric_only=True) 
df186 = customer[(customer['c_acctbal'] >= 11054) & (customer['c_custkey'] >= 113)][['c_custkey','c_name','c_nationkey','c_phone','c_acctbal']].groupby(by=['c_phone']).agg('min',numeric_only=True) 
df187 = customer[(customer['c_acctbal'] > 11119) | (customer['c_custkey'] > 123)][['c_address','c_nationkey','c_phone','c_mktsegment']].groupby(by=['c_address']).agg('max',numeric_only=True) 
df188 = customer[(customer['c_acctbal'] <= 5546) & (customer['c_custkey'] <= 60)][['c_name','c_address','c_phone','c_acctbal']].groupby(by=['c_acctbal']).agg('min',numeric_only=True) 
df189 = customer[(customer['c_acctbal'] >= 5270) | (customer['c_custkey'] >= 47)][['c_name','c_address','c_nationkey','c_phone','c_mktsegment']].groupby(by=['c_nationkey']).agg('max',numeric_only=True) 
df190 = customer[(customer['c_acctbal'] <= 11822) | (customer['c_custkey'] <= 136)][['c_custkey','c_name','c_address','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_mktsegment']).agg('mean',numeric_only=True) 
df191 = customer[(customer['c_acctbal'] < 5709) | (customer['c_custkey'] < 80)][['c_name','c_address','c_mktsegment','c_comment']].groupby(by=['c_mktsegment']).agg('mean',numeric_only=True) 
df192 = customer[(customer['c_acctbal'] == 7764) | (customer['c_custkey'] == 82)][['c_custkey','c_name','c_nationkey','c_phone','c_acctbal']].groupby(by=['c_name']).agg('min',numeric_only=True) 
df193 = customer[(customer['c_acctbal'] <= 9758) | (customer['c_custkey'] <= 98)][['c_custkey','c_name','c_phone','c_mktsegment']].groupby(by=['c_phone']).agg('max',numeric_only=True) 
df194 = customer[(customer['c_acctbal'] >= 7696) & (customer['c_custkey'] >= 95)][['c_name','c_address','c_nationkey','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_acctbal']).agg('min',numeric_only=True) 
df195 = customer[(customer['c_acctbal'] > 11119) | (customer['c_custkey'] > 123)][['c_nationkey','c_phone','c_mktsegment','c_comment']].groupby(by=['c_nationkey']).agg('max',numeric_only=True) 
df196 = customer[(customer['c_acctbal'] >= 504) | (customer['c_custkey'] >= 23)][['c_nationkey','c_phone','c_mktsegment','c_comment']].groupby(by=['c_phone']).agg('mean',numeric_only=True) 
df197 = customer[(customer['c_acctbal'] >= 504) | (customer['c_custkey'] >= 23)][['c_address','c_nationkey','c_phone','c_mktsegment']].groupby(by=['c_nationkey']).agg('mean',numeric_only=True) 
df198 = customer[(customer['c_acctbal'] > 6874) | (customer['c_custkey'] > 92)][['c_custkey','c_address','c_nationkey','c_acctbal','c_mktsegment','c_comment']].groupby(by=['c_mktsegment']).agg('mean',numeric_only=True) 
df199 = customer[(customer['c_acctbal'] > 7490) & (customer['c_custkey'] > 75)][['c_custkey','c_phone','c_acctbal','c_mktsegment']].groupby(by=['c_mktsegment']).agg('min',numeric_only=True) 
df200 = lineitem[(lineitem['l_suppkey'] >= 1647) | (lineitem['l_quantity'] >= 213)] 
df201 = lineitem[(lineitem['l_suppkey'] > 13891) | (lineitem['l_quantity'] > 65)] 
df202 = lineitem[(lineitem['l_suppkey'] == 6975) & (lineitem['l_quantity'] == 29)] 
df203 = lineitem[(lineitem['l_suppkey'] >= 11307) | (lineitem['l_quantity'] >= 53)] 
df204 = lineitem[(lineitem['l_suppkey'] >= 1085) | (lineitem['l_quantity'] >= 9)] 
df205 = lineitem[(lineitem['l_suppkey'] < 6810) | (lineitem['l_quantity'] < 28)] 
df206 = lineitem[(lineitem['l_suppkey'] >= 5595) & (lineitem['l_quantity'] >= 14)] 
df207 = lineitem[(lineitem['l_suppkey'] == 19756) | (lineitem['l_quantity'] == 79)] 
df208 = lineitem[(lineitem['l_suppkey'] <= 7487) | (lineitem['l_quantity'] <= 29)] 
df209 = lineitem[(lineitem['l_suppkey'] < 17456) & (lineitem['l_quantity'] < 77)] 
df210 = lineitem[(lineitem['l_suppkey'] <= 7613) | (lineitem['l_quantity'] <= 28)] 
df211 = lineitem[(lineitem['l_suppkey'] < 6810) & (lineitem['l_quantity'] < 28)] 
df212 = lineitem[(lineitem['l_suppkey'] >= 5914) & (lineitem['l_quantity'] >= 27)] 
df213 = lineitem[(lineitem['l_suppkey'] >= 1085) | (lineitem['l_quantity'] >= 9)] 
df214 = lineitem[(lineitem['l_suppkey'] <= 7863) & (lineitem['l_quantity'] <= 24)] 
df215 = lineitem[(lineitem['l_suppkey'] < 7896) & (lineitem['l_quantity'] < 38)] 
df216 = lineitem[(lineitem['l_suppkey'] >= 1085) | (lineitem['l_quantity'] >= 9)] 
df217 = lineitem[(lineitem['l_suppkey'] < 10459) | (lineitem['l_quantity'] < 26)] 
df218 = lineitem[(lineitem['l_suppkey'] > 6993) & (lineitem['l_quantity'] > 20)] 
df219 = lineitem[(lineitem['l_suppkey'] >= 8402) | (lineitem['l_quantity'] >= 51)] 
df220 = lineitem[(lineitem['l_suppkey'] > 10532) & (lineitem['l_quantity'] > 58)] 
df221 = lineitem[(lineitem['l_suppkey'] < 9025) | (lineitem['l_quantity'] < 36)] 
df222 = lineitem[(lineitem['l_suppkey'] == 10671) & (lineitem['l_quantity'] == 37)] 
df223 = lineitem[(lineitem['l_suppkey'] == 7225) | (lineitem['l_quantity'] == 245)] 
df224 = lineitem[(lineitem['l_suppkey'] == 13275) & (lineitem['l_quantity'] == 59)] 
df225 = lineitem[(lineitem['l_suppkey'] <= 16315) | (lineitem['l_quantity'] <= 66)] 
df226 = lineitem[(lineitem['l_suppkey'] > 2822) | (lineitem['l_quantity'] > 20)] 
df227 = lineitem[(lineitem['l_suppkey'] < 13548) | (lineitem['l_quantity'] < 73)] 
df228 = lineitem[(lineitem['l_suppkey'] == 9984) & (lineitem['l_quantity'] == 47)] 
df229 = lineitem[(lineitem['l_suppkey'] < 17456) & (lineitem['l_quantity'] < 77)] 
df230 = lineitem[(lineitem['l_suppkey'] == 11402) & (lineitem['l_quantity'] == 47)] 
df231 = lineitem[(lineitem['l_suppkey'] > 3192) & (lineitem['l_quantity'] > 220)] 
df232 = lineitem[(lineitem['l_suppkey'] == 15272) & (lineitem['l_quantity'] == 78)] 
df233 = lineitem[(lineitem['l_suppkey'] <= 13381) | (lineitem['l_quantity'] <= 67)] 
df234 = lineitem[(lineitem['l_suppkey'] <= 8365) | (lineitem['l_quantity'] <= 49)] 
df235 = lineitem[(lineitem['l_suppkey'] >= 11307) & (lineitem['l_quantity'] >= 53)] 
df236 = lineitem[(lineitem['l_suppkey'] < 11140) & (lineitem['l_quantity'] < 49)] 
df237 = lineitem[(lineitem['l_suppkey'] >= 4606) & (lineitem['l_quantity'] >= 20)] 
df238 = lineitem[(lineitem['l_suppkey'] <= 4633) | (lineitem['l_quantity'] <= 234)] 
df239 = lineitem[(lineitem['l_suppkey'] < 4860) | (lineitem['l_quantity'] < 244)] 
df240 = lineitem[(lineitem['l_suppkey'] > 13891) & (lineitem['l_quantity'] > 65)] 
df241 = lineitem[(lineitem['l_suppkey'] > 6961) | (lineitem['l_quantity'] > 27)] 
df242 = lineitem[(lineitem['l_suppkey'] > 6899) | (lineitem['l_quantity'] > 36)] 
df243 = lineitem[(lineitem['l_suppkey'] <= 4952) | (lineitem['l_quantity'] <= 22)] 
df244 = lineitem[(lineitem['l_suppkey'] > 2822) | (lineitem['l_quantity'] > 20)] 
df245 = lineitem[(lineitem['l_suppkey'] <= 4952) & (lineitem['l_quantity'] <= 22)] 
df246 = lineitem[(lineitem['l_suppkey'] >= 5044) & (lineitem['l_quantity'] >= 31)] 
df247 = lineitem[(lineitem['l_suppkey'] == 6975) | (lineitem['l_quantity'] == 29)] 
df248 = lineitem[(lineitem['l_suppkey'] <= 16315) & (lineitem['l_quantity'] <= 66)] 
df249 = lineitem[(lineitem['l_suppkey'] > 5444) & (lineitem['l_quantity'] > 22)] 
df250 = lineitem[(lineitem['l_suppkey'] <= 5674) & (lineitem['l_quantity'] <= 14) | (lineitem['l_discount'] <= 1.82)][['l_quantity','l_extendedprice','l_tax','l_returnflag','l_receiptdate','l_shipinstruct','l_shipmode']] 
df251 = lineitem[(lineitem['l_suppkey'] >= 489) | (lineitem['l_quantity'] >= 1) | (lineitem['l_discount'] >= 0.19)][['l_extendedprice','l_discount','l_returnflag','l_linestatus','l_receiptdate','l_shipinstruct','l_comment']] 
df252 = lineitem[(lineitem['l_suppkey'] < 9238) & (lineitem['l_quantity'] < 46) & (lineitem['l_discount'] < 2.48)][['l_orderkey','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipmode','l_comment']] 
df253 = lineitem[(lineitem['l_suppkey'] > 11385) & (lineitem['l_quantity'] > 57) & (lineitem['l_discount'] > 0.98)][['l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate','l_shipinstruct']] 
df254 = lineitem[(lineitem['l_suppkey'] < 8303) & (lineitem['l_quantity'] < 19) | (lineitem['l_discount'] < 2.35)][['l_orderkey','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']] 
df255 = lineitem[(lineitem['l_suppkey'] <= 4529) | (lineitem['l_quantity'] <= 216) | (lineitem['l_discount'] <= 201.88)][['l_partkey','l_quantity','l_discount','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_comment']] 
df256 = lineitem[(lineitem['l_suppkey'] > 13567) & (lineitem['l_quantity'] > 52) & (lineitem['l_discount'] > 0.79)][['l_orderkey','l_linenumber','l_extendedprice','l_discount','l_tax','l_shipdate','l_commitdate','l_shipinstruct']] 
df257 = lineitem[(lineitem['l_suppkey'] < 8303) & (lineitem['l_quantity'] < 19) | (lineitem['l_discount'] < 2.35)][['l_orderkey','l_partkey','l_linenumber','l_quantity','l_tax','l_linestatus','l_shipmode','l_comment']] 
df258 = lineitem[(lineitem['l_suppkey'] > 3343) | (lineitem['l_quantity'] > 10) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_suppkey','l_extendedprice','l_tax','l_linestatus','l_shipdate','l_receiptdate','l_comment']] 
df259 = lineitem[(lineitem['l_suppkey'] == 10135) | (lineitem['l_quantity'] == 59) & (lineitem['l_discount'] == 2.81)][['l_orderkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct']] 
df260 = lineitem[(lineitem['l_suppkey'] < 6131) & (lineitem['l_quantity'] < 230) & (lineitem['l_discount'] < 202.04)][['l_suppkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_shipinstruct']] 
df261 = lineitem[(lineitem['l_suppkey'] < 11405) | (lineitem['l_quantity'] < 67) | (lineitem['l_discount'] < 2.13)][['l_orderkey','l_suppkey','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_shipmode','l_comment']] 
df262 = lineitem[(lineitem['l_suppkey'] >= 9619) | (lineitem['l_quantity'] >= 43) | (lineitem['l_discount'] >= 0.37)][['l_quantity','l_extendedprice','l_tax','l_returnflag','l_commitdate','l_receiptdate','l_comment']] 
df263 = lineitem[(lineitem['l_suppkey'] <= 13756) | (lineitem['l_quantity'] <= 65) & (lineitem['l_discount'] <= 0.98)][['l_quantity','l_tax','l_returnflag','l_linestatus','l_shipinstruct','l_shipmode']] 
df264 = lineitem[(lineitem['l_suppkey'] >= 7367) & (lineitem['l_quantity'] >= 31) & (lineitem['l_discount'] >= 0.95)][['l_partkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_tax','l_shipinstruct','l_shipmode']] 
df265 = lineitem[(lineitem['l_suppkey'] < 14462) & (lineitem['l_quantity'] < 78) & (lineitem['l_discount'] < 0.99)][['l_orderkey','l_linenumber','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate']] 
df266 = lineitem[(lineitem['l_suppkey'] >= 489) & (lineitem['l_quantity'] >= 1) | (lineitem['l_discount'] >= 0.19)][['l_orderkey','l_linenumber','l_extendedprice','l_discount','l_tax','l_shipdate','l_commitdate','l_shipinstruct']] 
df267 = lineitem[(lineitem['l_suppkey'] == 9243) & (lineitem['l_quantity'] == 32) & (lineitem['l_discount'] == 2.89)][['l_orderkey','l_partkey','l_quantity','l_discount','l_returnflag','l_linestatus','l_receiptdate','l_shipmode']] 
df268 = lineitem[(lineitem['l_suppkey'] > 3343) | (lineitem['l_quantity'] > 10) | (lineitem['l_discount'] > 0.94)][['l_suppkey','l_extendedprice','l_discount','l_tax','l_shipdate','l_commitdate','l_shipinstruct','l_comment']] 
df269 = lineitem[(lineitem['l_suppkey'] < 11405) | (lineitem['l_quantity'] < 67) | (lineitem['l_discount'] < 2.13)][['l_orderkey','l_suppkey','l_tax','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_comment']] 
df270 = lineitem[(lineitem['l_suppkey'] > 3343) & (lineitem['l_quantity'] > 10) & (lineitem['l_discount'] > 0.94)][['l_orderkey','l_linenumber','l_extendedprice','l_discount','l_linestatus','l_shipinstruct','l_shipmode']] 
df271 = lineitem[(lineitem['l_suppkey'] <= 9705) | (lineitem['l_quantity'] <= 33) & (lineitem['l_discount'] <= 1.54)][['l_orderkey','l_suppkey','l_discount','l_returnflag','l_shipdate','l_receiptdate','l_shipinstruct','l_shipmode']] 
df272 = lineitem[(lineitem['l_suppkey'] >= 9619) | (lineitem['l_quantity'] >= 43) | (lineitem['l_discount'] >= 0.37)][['l_partkey','l_suppkey','l_extendedprice','l_discount','l_shipdate','l_receiptdate','l_comment']] 
df273 = lineitem[(lineitem['l_suppkey'] > 8809) & (lineitem['l_quantity'] > 42) & (lineitem['l_discount'] > 1.06)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_commitdate','l_receiptdate']] 
df274 = lineitem[(lineitem['l_suppkey'] < 14462) & (lineitem['l_quantity'] < 78) & (lineitem['l_discount'] < 0.99)][['l_quantity','l_extendedprice','l_tax','l_returnflag','l_commitdate','l_receiptdate','l_comment']] 
df275 = lineitem[(lineitem['l_suppkey'] < 9238) & (lineitem['l_quantity'] < 46) & (lineitem['l_discount'] < 2.48)][['l_orderkey','l_linenumber','l_discount','l_linestatus','l_shipdate','l_shipmode','l_comment']] 
df276 = lineitem[(lineitem['l_suppkey'] >= 3228) & (lineitem['l_quantity'] >= 20) & (lineitem['l_discount'] >= 0.4)][['l_partkey','l_linenumber','l_tax','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']] 
df277 = lineitem[(lineitem['l_suppkey'] <= 7984) | (lineitem['l_quantity'] <= 39) | (lineitem['l_discount'] <= 1.93)][['l_suppkey','l_discount','l_tax','l_returnflag','l_shipdate','l_receiptdate','l_comment']] 
df278 = lineitem[(lineitem['l_suppkey'] == 13196) & (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 2.91)][['l_linenumber','l_quantity','l_discount','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct']] 
df279 = lineitem[(lineitem['l_suppkey'] <= 4529) | (lineitem['l_quantity'] <= 216) | (lineitem['l_discount'] <= 201.88)][['l_orderkey','l_suppkey','l_tax','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_comment']] 
df280 = lineitem[(lineitem['l_suppkey'] >= 9619) | (lineitem['l_quantity'] >= 43) | (lineitem['l_discount'] >= 0.37)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_receiptdate','l_shipmode']] 
df281 = lineitem[(lineitem['l_suppkey'] < 8303) & (lineitem['l_quantity'] < 19) | (lineitem['l_discount'] < 2.35)][['l_orderkey','l_partkey','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']] 
df282 = lineitem[(lineitem['l_suppkey'] < 14462) & (lineitem['l_quantity'] < 78) & (lineitem['l_discount'] < 0.99)][['l_orderkey','l_quantity','l_extendedprice','l_linestatus','l_commitdate','l_receiptdate','l_shipmode','l_comment']] 
df283 = lineitem[(lineitem['l_suppkey'] < 9238) & (lineitem['l_quantity'] < 46) & (lineitem['l_discount'] < 2.48)][['l_partkey','l_suppkey','l_extendedprice','l_discount','l_linestatus','l_receiptdate','l_comment']] 
df284 = lineitem[(lineitem['l_suppkey'] < 9160) & (lineitem['l_quantity'] < 44) & (lineitem['l_discount'] < 1.45)][['l_partkey','l_linenumber','l_tax','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']] 
df285 = lineitem[(lineitem['l_suppkey'] <= 5674) & (lineitem['l_quantity'] <= 14) | (lineitem['l_discount'] <= 1.82)][['l_partkey','l_suppkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_shipinstruct','l_comment']] 
df286 = lineitem[(lineitem['l_suppkey'] >= 11139) | (lineitem['l_quantity'] >= 51) & (lineitem['l_discount'] >= 0.7)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_linestatus','l_shipdate','l_receiptdate']] 
df287 = lineitem[(lineitem['l_suppkey'] <= 5674) & (lineitem['l_quantity'] <= 14) & (lineitem['l_discount'] <= 1.82)][['l_quantity','l_extendedprice','l_tax','l_returnflag','l_commitdate','l_receiptdate','l_comment']] 
df288 = lineitem[(lineitem['l_suppkey'] == 16614) & (lineitem['l_quantity'] == 87) | (lineitem['l_discount'] == 2.91)][['l_partkey','l_linenumber','l_quantity','l_discount','l_shipdate','l_receiptdate','l_comment']] 
df289 = lineitem[(lineitem['l_suppkey'] == 11836) | (lineitem['l_quantity'] == 45) | (lineitem['l_discount'] == 1.79)][['l_orderkey','l_discount','l_tax','l_returnflag','l_linestatus','l_shipdate','l_commitdate']] 
df290 = lineitem[(lineitem['l_suppkey'] <= 12789) & (lineitem['l_quantity'] <= 70) | (lineitem['l_discount'] <= 1.99)][['l_linenumber','l_tax','l_returnflag','l_commitdate','l_receiptdate','l_shipmode','l_comment']] 
df291 = lineitem[(lineitem['l_suppkey'] < 14462) & (lineitem['l_quantity'] < 78) & (lineitem['l_discount'] < 0.99)][['l_orderkey','l_partkey','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']] 
df292 = lineitem[(lineitem['l_suppkey'] <= 5674) & (lineitem['l_quantity'] <= 14) | (lineitem['l_discount'] <= 1.82)][['l_partkey','l_linenumber','l_extendedprice','l_discount','l_tax','l_linestatus','l_commitdate','l_shipinstruct']] 
df293 = lineitem[(lineitem['l_suppkey'] >= 489) | (lineitem['l_quantity'] >= 1) | (lineitem['l_discount'] >= 0.19)][['l_partkey','l_linenumber','l_quantity','l_extendedprice','l_tax','l_commitdate','l_shipinstruct']] 
df294 = lineitem[(lineitem['l_suppkey'] <= 7062) | (lineitem['l_quantity'] <= 37) & (lineitem['l_discount'] <= 0.69)][['l_orderkey','l_tax','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_shipmode']] 
df295 = lineitem[(lineitem['l_suppkey'] == 6706) | (lineitem['l_quantity'] == 242) | (lineitem['l_discount'] == 202.88)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_receiptdate','l_shipmode']] 
df296 = lineitem[(lineitem['l_suppkey'] < 13795) & (lineitem['l_quantity'] < 80) & (lineitem['l_discount'] < 2.06)][['l_suppkey','l_linenumber','l_quantity','l_tax','l_shipdate','l_shipinstruct','l_shipmode']] 
df297 = lineitem[(lineitem['l_suppkey'] > 5410) | (lineitem['l_quantity'] > 32) & (lineitem['l_discount'] > 0.5)][['l_orderkey','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate','l_shipinstruct','l_shipmode']] 
df298 = lineitem[(lineitem['l_suppkey'] == 16614) & (lineitem['l_quantity'] == 87) | (lineitem['l_discount'] == 2.91)][['l_quantity','l_discount','l_linestatus','l_shipdate','l_receiptdate','l_comment']] 
df299 = lineitem[(lineitem['l_suppkey'] < 9238) & (lineitem['l_quantity'] < 46) & (lineitem['l_discount'] < 2.48)][['l_quantity','l_tax','l_returnflag','l_linestatus','l_shipinstruct','l_shipmode']] 
df300 = lineitem[(lineitem['l_suppkey'] >= 4736) & (lineitem['l_quantity'] >= 24) | (lineitem['l_discount'] >= 0.35)][['l_partkey','l_quantity','l_discount','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_comment']] 
df301 = lineitem[(lineitem['l_suppkey'] >= 9619) | (lineitem['l_quantity'] >= 43) | (lineitem['l_discount'] >= 0.37)][['l_quantity','l_tax','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_comment']] 
df302 = lineitem[(lineitem['l_suppkey'] <= 7984) | (lineitem['l_quantity'] <= 39) | (lineitem['l_discount'] <= 1.93)][['l_orderkey','l_suppkey','l_quantity','l_extendedprice','l_returnflag','l_shipinstruct','l_shipmode']] 
df303 = lineitem[(lineitem['l_suppkey'] >= 9619) | (lineitem['l_quantity'] >= 43) | (lineitem['l_discount'] >= 0.37)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_returnflag','l_comment']] 
df304 = lineitem[(lineitem['l_suppkey'] <= 12789) & (lineitem['l_quantity'] <= 70) | (lineitem['l_discount'] <= 1.99)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_commitdate','l_shipmode']] 
df305 = lineitem[(lineitem['l_suppkey'] > 8809) & (lineitem['l_quantity'] > 42) & (lineitem['l_discount'] > 1.06)][['l_quantity','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']] 
df306 = lineitem[(lineitem['l_suppkey'] > 5349) & (lineitem['l_quantity'] > 27) & (lineitem['l_discount'] > 1.38)][['l_partkey','l_linenumber','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']] 
df307 = lineitem[(lineitem['l_suppkey'] < 13795) & (lineitem['l_quantity'] < 80) & (lineitem['l_discount'] < 2.06)][['l_orderkey','l_linenumber','l_discount','l_tax','l_commitdate','l_receiptdate','l_comment']] 
df308 = lineitem[(lineitem['l_suppkey'] > 13567) & (lineitem['l_quantity'] > 52) | (lineitem['l_discount'] > 0.79)][['l_orderkey','l_linenumber','l_quantity','l_linestatus','l_commitdate','l_receiptdate']] 
df309 = lineitem[(lineitem['l_suppkey'] > 5349) & (lineitem['l_quantity'] > 27) & (lineitem['l_discount'] > 1.38)][['l_linenumber','l_quantity','l_discount','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct']] 
df310 = lineitem[(lineitem['l_suppkey'] < 11690) | (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.3)][['l_orderkey','l_partkey','l_discount','l_tax','l_linestatus','l_comment']] 
df311 = lineitem[(lineitem['l_suppkey'] >= 489) & (lineitem['l_quantity'] >= 1) | (lineitem['l_discount'] >= 0.19)][['l_orderkey','l_suppkey','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_shipmode','l_comment']] 
df312 = lineitem[(lineitem['l_suppkey'] > 13567) & (lineitem['l_quantity'] > 52) & (lineitem['l_discount'] > 0.79)][['l_orderkey','l_suppkey','l_returnflag','l_receiptdate','l_shipinstruct','l_comment']] 
df313 = lineitem[(lineitem['l_suppkey'] == 17147) | (lineitem['l_quantity'] == 80) & (lineitem['l_discount'] == 2.01)][['l_partkey','l_quantity','l_extendedprice','l_tax','l_linestatus','l_commitdate','l_receiptdate','l_comment']] 
df314 = lineitem[(lineitem['l_suppkey'] >= 2516) & (lineitem['l_quantity'] >= 204) & (lineitem['l_discount'] >= 200.93)][['l_discount','l_tax','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']] 
df315 = lineitem[(lineitem['l_suppkey'] >= 7367) & (lineitem['l_quantity'] >= 31) & (lineitem['l_discount'] >= 0.95)][['l_partkey','l_linenumber','l_quantity','l_discount','l_tax','l_returnflag','l_commitdate','l_comment']] 
df316 = lineitem[(lineitem['l_suppkey'] >= 9619) | (lineitem['l_quantity'] >= 43) | (lineitem['l_discount'] >= 0.37)][['l_suppkey','l_linenumber','l_returnflag','l_linestatus','l_receiptdate','l_shipinstruct','l_shipmode']] 
df317 = lineitem[(lineitem['l_suppkey'] >= 3228) & (lineitem['l_quantity'] >= 20) & (lineitem['l_discount'] >= 0.4)][['l_partkey','l_suppkey','l_quantity','l_discount','l_shipdate','l_shipmode','l_comment']] 
df318 = lineitem[(lineitem['l_suppkey'] == 9243) & (lineitem['l_quantity'] == 32) & (lineitem['l_discount'] == 2.89)][['l_orderkey','l_partkey','l_linenumber','l_extendedprice','l_commitdate','l_receiptdate']] 
df319 = lineitem[(lineitem['l_suppkey'] == 11836) | (lineitem['l_quantity'] == 45) | (lineitem['l_discount'] == 1.79)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_linestatus','l_shipdate','l_commitdate','l_receiptdate']] 
df320 = lineitem[(lineitem['l_suppkey'] <= 13756) | (lineitem['l_quantity'] <= 65) | (lineitem['l_discount'] <= 0.98)][['l_orderkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate']] 
df321 = lineitem[(lineitem['l_suppkey'] >= 489) | (lineitem['l_quantity'] >= 1) | (lineitem['l_discount'] >= 0.19)][['l_orderkey','l_linenumber','l_extendedprice','l_discount','l_linestatus','l_shipinstruct','l_shipmode']] 
df322 = lineitem[(lineitem['l_suppkey'] == 6706) | (lineitem['l_quantity'] == 242) | (lineitem['l_discount'] == 202.88)][['l_quantity','l_tax','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_comment']] 
df323 = lineitem[(lineitem['l_suppkey'] <= 9705) | (lineitem['l_quantity'] <= 33) & (lineitem['l_discount'] <= 1.54)][['l_suppkey','l_linenumber','l_quantity','l_extendedprice','l_returnflag','l_shipdate','l_receiptdate']] 
df324 = lineitem[(lineitem['l_suppkey'] >= 7367) & (lineitem['l_quantity'] >= 31) & (lineitem['l_discount'] >= 0.95)][['l_orderkey','l_linenumber','l_extendedprice','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct']] 
df325 = lineitem[(lineitem['l_suppkey'] <= 12789) & (lineitem['l_quantity'] <= 70) | (lineitem['l_discount'] <= 1.99)][['l_orderkey','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate','l_shipinstruct','l_shipmode']] 
df326 = lineitem[(lineitem['l_suppkey'] > 13567) & (lineitem['l_quantity'] > 52) & (lineitem['l_discount'] > 0.79)][['l_orderkey','l_suppkey','l_discount','l_tax','l_receiptdate','l_shipinstruct','l_comment']] 
df327 = lineitem[(lineitem['l_suppkey'] >= 6690) & (lineitem['l_quantity'] >= 30) | (lineitem['l_discount'] >= 0.65)][['l_partkey','l_suppkey','l_extendedprice','l_discount','l_linestatus','l_receiptdate','l_comment']] 
df328 = lineitem[(lineitem['l_suppkey'] == 10135) | (lineitem['l_quantity'] == 59) & (lineitem['l_discount'] == 2.81)][['l_orderkey','l_suppkey','l_linenumber','l_tax','l_returnflag','l_shipdate','l_receiptdate']] 
df329 = lineitem[(lineitem['l_suppkey'] == 17147) | (lineitem['l_quantity'] == 80) & (lineitem['l_discount'] == 2.01)][['l_partkey','l_linenumber','l_discount','l_linestatus','l_shipdate','l_shipinstruct','l_shipmode']] 
df330 = lineitem[(lineitem['l_suppkey'] <= 5674) & (lineitem['l_quantity'] <= 14) | (lineitem['l_discount'] <= 1.82)][['l_orderkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct']] 
df331 = lineitem[(lineitem['l_suppkey'] == 9243) | (lineitem['l_quantity'] == 32) | (lineitem['l_discount'] == 2.89)][['l_suppkey','l_linenumber','l_tax','l_shipdate','l_commitdate','l_receiptdate','l_comment']] 
df332 = lineitem[(lineitem['l_suppkey'] > 13567) & (lineitem['l_quantity'] > 52) | (lineitem['l_discount'] > 0.79)][['l_partkey','l_extendedprice','l_tax','l_commitdate','l_receiptdate','l_shipinstruct']] 
df333 = lineitem[(lineitem['l_suppkey'] < 8303) & (lineitem['l_quantity'] < 19) | (lineitem['l_discount'] < 2.35)][['l_orderkey','l_suppkey','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_shipmode','l_comment']] 
df334 = lineitem[(lineitem['l_suppkey'] <= 9705) | (lineitem['l_quantity'] <= 33) & (lineitem['l_discount'] <= 1.54)][['l_orderkey','l_partkey','l_tax','l_linestatus','l_shipdate','l_commitdate','l_shipmode','l_comment']] 
df335 = lineitem[(lineitem['l_suppkey'] >= 11139) | (lineitem['l_quantity'] >= 51) & (lineitem['l_discount'] >= 0.7)][['l_orderkey','l_linenumber','l_extendedprice','l_discount','l_tax','l_commitdate']] 
df336 = lineitem[(lineitem['l_suppkey'] <= 9705) | (lineitem['l_quantity'] <= 33) & (lineitem['l_discount'] <= 1.54)][['l_orderkey','l_suppkey','l_linenumber','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_receiptdate']] 
df337 = lineitem[(lineitem['l_suppkey'] <= 5674) & (lineitem['l_quantity'] <= 14) & (lineitem['l_discount'] <= 1.82)][['l_suppkey','l_quantity','l_extendedprice','l_discount','l_tax','l_returnflag','l_shipdate','l_shipmode']] 
df338 = lineitem[(lineitem['l_suppkey'] >= 489) & (lineitem['l_quantity'] >= 1) | (lineitem['l_discount'] >= 0.19)][['l_orderkey','l_suppkey','l_quantity','l_discount','l_returnflag','l_receiptdate']] 
df339 = lineitem[(lineitem['l_suppkey'] <= 7062) | (lineitem['l_quantity'] <= 37) & (lineitem['l_discount'] <= 0.69)][['l_partkey','l_suppkey','l_quantity','l_discount','l_shipdate','l_shipmode','l_comment']] 
df340 = lineitem[(lineitem['l_suppkey'] == 6706) | (lineitem['l_quantity'] == 242) | (lineitem['l_discount'] == 202.88)][['l_partkey','l_extendedprice','l_discount','l_tax','l_linestatus','l_shipmode','l_comment']] 
df341 = lineitem[(lineitem['l_suppkey'] >= 3228) & (lineitem['l_quantity'] >= 20) & (lineitem['l_discount'] >= 0.4)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_returnflag','l_shipdate']] 
df342 = lineitem[(lineitem['l_suppkey'] >= 4736) & (lineitem['l_quantity'] >= 24) | (lineitem['l_discount'] >= 0.35)][['l_suppkey','l_quantity','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_shipmode']] 
df343 = lineitem[(lineitem['l_suppkey'] >= 489) & (lineitem['l_quantity'] >= 1) & (lineitem['l_discount'] >= 0.19)][['l_partkey','l_extendedprice','l_discount','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']] 
df344 = lineitem[(lineitem['l_suppkey'] > 4464) | (lineitem['l_quantity'] > 208) | (lineitem['l_discount'] > 201.63)][['l_partkey','l_linenumber','l_returnflag','l_commitdate','l_receiptdate','l_shipinstruct','l_shipmode']] 
df345 = lineitem[(lineitem['l_suppkey'] == 9243) | (lineitem['l_quantity'] == 32) | (lineitem['l_discount'] == 2.89)][['l_orderkey','l_partkey','l_linenumber','l_discount','l_tax','l_returnflag','l_linestatus']] 
df346 = lineitem[(lineitem['l_suppkey'] < 9160) & (lineitem['l_quantity'] < 44) & (lineitem['l_discount'] < 1.45)][['l_partkey','l_quantity','l_discount','l_tax','l_shipinstruct','l_comment']] 
df347 = lineitem[(lineitem['l_suppkey'] > 5349) & (lineitem['l_quantity'] > 27) & (lineitem['l_discount'] > 1.38)][['l_orderkey','l_linenumber','l_quantity','l_tax','l_receiptdate','l_shipinstruct']] 
df348 = lineitem[(lineitem['l_suppkey'] > 3343) & (lineitem['l_quantity'] > 10) & (lineitem['l_discount'] > 0.94)][['l_quantity','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']] 
df349 = lineitem[(lineitem['l_suppkey'] >= 489) & (lineitem['l_quantity'] >= 1) & (lineitem['l_discount'] >= 0.19)][['l_suppkey','l_linenumber','l_discount','l_commitdate','l_receiptdate','l_comment']] 
df350 = lineitem[(lineitem['l_suppkey'] > 910) & (lineitem['l_quantity'] > 14) & (lineitem['l_discount'] > 1.12)][['l_partkey','l_suppkey','l_quantity','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_receiptdate','l_comment']].groupby(by=['l_tax']).agg('max',numeric_only=True) 
df351 = lineitem[(lineitem['l_suppkey'] <= 2546) | (lineitem['l_quantity'] <= 15) & (lineitem['l_discount'] <= 1.6)][['l_orderkey','l_discount','l_tax','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipinstruct','l_shipmode']].groupby(by=['l_linestatus']).agg('max',numeric_only=True) 
df352 = lineitem[(lineitem['l_suppkey'] < 9123) | (lineitem['l_quantity'] < 27) & (lineitem['l_discount'] < 2.08)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_shipdate','l_shipinstruct','l_comment']].groupby(by=['l_linenumber']).agg('min',numeric_only=True) 
df353 = lineitem[(lineitem['l_suppkey'] <= 7665) | (lineitem['l_quantity'] <= 49) & (lineitem['l_discount'] <= 1.03)][['l_suppkey','l_linenumber','l_quantity','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_commitdate']).agg('max',numeric_only=True) 
df354 = lineitem[(lineitem['l_suppkey'] < 13662) & (lineitem['l_quantity'] < 64) | (lineitem['l_discount'] < 1.77)][['l_partkey','l_suppkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_comment']).agg('max',numeric_only=True) 
df355 = lineitem[(lineitem['l_suppkey'] > 11213) | (lineitem['l_quantity'] > 55) & (lineitem['l_discount'] > 0.73)][['l_linenumber','l_discount','l_returnflag','l_shipdate','l_commitdate','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_shipdate']).agg('max',numeric_only=True) 
df356 = lineitem[(lineitem['l_suppkey'] >= 606) | (lineitem['l_quantity'] >= 11) & (lineitem['l_discount'] >= 0.63)][['l_orderkey','l_suppkey','l_quantity','l_shipdate','l_commitdate','l_receiptdate','l_shipinstruct','l_shipmode']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True) 
df357 = lineitem[(lineitem['l_suppkey'] <= 4200) | (lineitem['l_quantity'] <= 237) & (lineitem['l_discount'] <= 201.63)][['l_partkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipinstruct','l_shipmode']].groupby(by=['l_receiptdate']).agg('max',numeric_only=True) 
df358 = lineitem[(lineitem['l_suppkey'] >= 4019) | (lineitem['l_quantity'] >= 26) | (lineitem['l_discount'] >= 0.69)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_returnflag','l_shipdate','l_shipinstruct','l_comment']].groupby(by=['l_orderkey']).agg('min',numeric_only=True) 
df359 = lineitem[(lineitem['l_suppkey'] >= 6576) | (lineitem['l_quantity'] >= 30) & (lineitem['l_discount'] >= 0.82)][['l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipmode','l_comment']].groupby(by=['l_comment']).agg('min',numeric_only=True) 
df360 = lineitem[(lineitem['l_suppkey'] <= 9202) | (lineitem['l_quantity'] <= 48) & (lineitem['l_discount'] <= 1.83)][['l_orderkey','l_suppkey','l_linenumber','l_discount','l_tax','l_linestatus','l_receiptdate','l_shipinstruct','l_comment']].groupby(by=['l_tax']).agg('max',numeric_only=True) 
df361 = lineitem[(lineitem['l_suppkey'] >= 910) | (lineitem['l_quantity'] >= 213) | (lineitem['l_discount'] >= 200.32)][['l_partkey','l_suppkey','l_linenumber','l_discount','l_returnflag','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('mean',numeric_only=True) 
df362 = lineitem[(lineitem['l_suppkey'] >= 4019) | (lineitem['l_quantity'] >= 26) | (lineitem['l_discount'] >= 0.69)][['l_partkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']].groupby(by=['l_comment']).agg('min',numeric_only=True) 
df363 = lineitem[(lineitem['l_suppkey'] == 10024) & (lineitem['l_quantity'] == 61) | (lineitem['l_discount'] == 1.83)][['l_partkey','l_quantity','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate','l_shipinstruct']].groupby(by=['l_shipinstruct']).agg('max',numeric_only=True) 
df364 = lineitem[(lineitem['l_suppkey'] <= 2546) | (lineitem['l_quantity'] <= 15) & (lineitem['l_discount'] <= 1.6)][['l_partkey','l_suppkey','l_discount','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True) 
df365 = lineitem[(lineitem['l_suppkey'] <= 2546) | (lineitem['l_quantity'] <= 15) & (lineitem['l_discount'] <= 1.6)][['l_partkey','l_linenumber','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']].groupby(by=['l_returnflag']).agg('max',numeric_only=True) 
df366 = lineitem[(lineitem['l_suppkey'] <= 11301) & (lineitem['l_quantity'] <= 55) | (lineitem['l_discount'] <= 1.22)][['l_partkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']].groupby(by=['l_commitdate']).agg('min',numeric_only=True) 
df367 = lineitem[(lineitem['l_suppkey'] >= 10691) | (lineitem['l_quantity'] >= 50) & (lineitem['l_discount'] >= 0.73)][['l_linenumber','l_extendedprice','l_returnflag','l_shipdate','l_commitdate','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True) 
df368 = lineitem[(lineitem['l_suppkey'] <= 9202) | (lineitem['l_quantity'] <= 48) & (lineitem['l_discount'] <= 1.83)][['l_orderkey','l_suppkey','l_quantity','l_extendedprice','l_returnflag','l_shipdate','l_receiptdate','l_shipinstruct']].groupby(by=['l_quantity']).agg('max',numeric_only=True) 
df369 = lineitem[(lineitem['l_suppkey'] < 10426) | (lineitem['l_quantity'] < 57) & (lineitem['l_discount'] < 2.02)][['l_orderkey','l_suppkey','l_quantity','l_extendedprice','l_returnflag','l_shipdate','l_receiptdate','l_shipinstruct']].groupby(by=['l_returnflag']).agg('mean',numeric_only=True) 
df370 = lineitem[(lineitem['l_suppkey'] > 910) & (lineitem['l_quantity'] > 14) & (lineitem['l_discount'] > 1.12)][['l_partkey','l_suppkey','l_extendedprice','l_tax','l_linestatus','l_commitdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_tax']).agg('min',numeric_only=True) 
df371 = lineitem[(lineitem['l_suppkey'] > 11213) | (lineitem['l_quantity'] > 55) & (lineitem['l_discount'] > 0.73)][['l_partkey','l_suppkey','l_extendedprice','l_tax','l_linestatus','l_commitdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_shipmode']).agg('mean',numeric_only=True) 
df372 = lineitem[(lineitem['l_suppkey'] >= 606) | (lineitem['l_quantity'] >= 11) | (lineitem['l_discount'] >= 0.63)][['l_partkey','l_linenumber','l_quantity','l_discount','l_tax','l_returnflag','l_commitdate','l_shipinstruct','l_shipmode']].groupby(by=['l_returnflag']).agg('max',numeric_only=True) 
df373 = lineitem[(lineitem['l_suppkey'] > 2751) & (lineitem['l_quantity'] > 225) | (lineitem['l_discount'] > 201.17)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_partkey']).agg('max',numeric_only=True) 
df374 = lineitem[(lineitem['l_suppkey'] > 5264) | (lineitem['l_quantity'] > 27) & (lineitem['l_discount'] > 1.2)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_returnflag','l_linestatus','l_shipdate','l_receiptdate','l_shipinstruct']].groupby(by=['l_returnflag']).agg('mean',numeric_only=True) 
df375 = lineitem[(lineitem['l_suppkey'] >= 910) | (lineitem['l_quantity'] >= 213) | (lineitem['l_discount'] >= 200.32)][['l_partkey','l_linenumber','l_quantity','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct']].groupby(by=['l_linestatus']).agg('max',numeric_only=True) 
df376 = lineitem[(lineitem['l_suppkey'] >= 3060) | (lineitem['l_quantity'] >= 26) | (lineitem['l_discount'] >= 0.47)][['l_orderkey','l_suppkey','l_quantity','l_discount','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True) 
df377 = lineitem[(lineitem['l_suppkey'] <= 7665) | (lineitem['l_quantity'] <= 49) & (lineitem['l_discount'] <= 1.03)][['l_partkey','l_linenumber','l_quantity','l_discount','l_tax','l_returnflag','l_commitdate','l_shipinstruct','l_shipmode']].groupby(by=['l_commitdate']).agg('max',numeric_only=True) 
df378 = lineitem[(lineitem['l_suppkey'] >= 4019) | (lineitem['l_quantity'] >= 26) | (lineitem['l_discount'] >= 0.69)][['l_orderkey','l_quantity','l_extendedprice','l_discount','l_tax','l_linestatus','l_receiptdate','l_shipinstruct','l_shipmode']].groupby(by=['l_linestatus']).agg('mean',numeric_only=True) 
df379 = lineitem[(lineitem['l_suppkey'] == 12953) & (lineitem['l_quantity'] == 64) & (lineitem['l_discount'] == 2.5)][['l_partkey','l_suppkey','l_extendedprice','l_discount','l_returnflag','l_commitdate','l_shipinstruct','l_comment']].groupby(by=['l_partkey']).agg('mean',numeric_only=True) 
df380 = lineitem[(lineitem['l_suppkey'] == 10347) & (lineitem['l_quantity'] == 39) | (lineitem['l_discount'] == 3.03)][['l_partkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_linestatus','l_commitdate','l_comment']].groupby(by=['l_discount']).agg('min',numeric_only=True) 
df381 = lineitem[(lineitem['l_suppkey'] > 4201) | (lineitem['l_quantity'] > 37) | (lineitem['l_discount'] > 1.22)][['l_partkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']].groupby(by=['l_linenumber']).agg('mean',numeric_only=True) 
df382 = lineitem[(lineitem['l_suppkey'] <= 7140) | (lineitem['l_quantity'] <= 27) & (lineitem['l_discount'] <= 1.83)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_shipinstruct','l_comment']].groupby(by=['l_tax']).agg('max',numeric_only=True) 
df383 = lineitem[(lineitem['l_suppkey'] == 3520) & (lineitem['l_quantity'] == 25) & (lineitem['l_discount'] == 2.92)][['l_partkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_linestatus']).agg('max',numeric_only=True) 
df384 = lineitem[(lineitem['l_suppkey'] >= 606) | (lineitem['l_quantity'] >= 11) | (lineitem['l_discount'] >= 0.63)][['l_linenumber','l_discount','l_returnflag','l_shipdate','l_commitdate','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_shipdate']).agg('max',numeric_only=True) 
df385 = lineitem[(lineitem['l_suppkey'] < 9123) | (lineitem['l_quantity'] < 27) & (lineitem['l_discount'] < 2.08)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_tax','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_linestatus']).agg('max',numeric_only=True) 
df386 = lineitem[(lineitem['l_suppkey'] > 7368) | (lineitem['l_quantity'] > 35) & (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_extendedprice','l_tax','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']].groupby(by=['l_shipmode']).agg('min',numeric_only=True) 
df387 = lineitem[(lineitem['l_suppkey'] < 14226) & (lineitem['l_quantity'] < 67) | (lineitem['l_discount'] < 2.04)][['l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_shipdate','l_shipmode']].groupby(by=['l_linenumber']).agg('min',numeric_only=True) 
df388 = lineitem[(lineitem['l_suppkey'] > 4201) | (lineitem['l_quantity'] > 37) | (lineitem['l_discount'] > 1.22)][['l_partkey','l_suppkey','l_linenumber','l_returnflag','l_shipdate','l_commitdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True) 
df389 = lineitem[(lineitem['l_suppkey'] <= 12307) & (lineitem['l_quantity'] <= 53) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_shipdate','l_commitdate']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True) 
df390 = lineitem[(lineitem['l_suppkey'] <= 2546) | (lineitem['l_quantity'] <= 15) & (lineitem['l_discount'] <= 1.6)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_discount','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_quantity']).agg('min',numeric_only=True) 
df391 = lineitem[(lineitem['l_suppkey'] == 3520) & (lineitem['l_quantity'] == 25) & (lineitem['l_discount'] == 2.92)][['l_orderkey','l_partkey','l_suppkey','l_returnflag','l_commitdate','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_comment']).agg('max',numeric_only=True) 
df392 = lineitem[(lineitem['l_suppkey'] < 14226) & (lineitem['l_quantity'] < 67) | (lineitem['l_discount'] < 2.04)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_tax','l_returnflag','l_commitdate','l_receiptdate','l_shipinstruct','l_shipmode']].groupby(by=['l_tax']).agg('mean',numeric_only=True) 
df393 = lineitem[(lineitem['l_suppkey'] <= 2546) | (lineitem['l_quantity'] <= 15) & (lineitem['l_discount'] <= 1.6)][['l_orderkey','l_partkey','l_linenumber','l_extendedprice','l_discount','l_tax','l_returnflag','l_linestatus','l_receiptdate','l_shipinstruct']].groupby(by=['l_returnflag']).agg('min',numeric_only=True) 
df394 = lineitem[(lineitem['l_suppkey'] >= 10691) & (lineitem['l_quantity'] >= 50) | (lineitem['l_discount'] >= 0.73)][['l_partkey','l_suppkey','l_quantity','l_tax','l_returnflag','l_linestatus','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_receiptdate']).agg('mean',numeric_only=True) 
df395 = lineitem[(lineitem['l_suppkey'] < 10426) | (lineitem['l_quantity'] < 57) & (lineitem['l_discount'] < 2.02)][['l_partkey','l_linenumber','l_quantity','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipinstruct']].groupby(by=['l_quantity']).agg('mean',numeric_only=True) 
df396 = lineitem[(lineitem['l_suppkey'] <= 7140) | (lineitem['l_quantity'] <= 27) & (lineitem['l_discount'] <= 1.83)][['l_partkey','l_suppkey','l_quantity','l_discount','l_commitdate','l_receiptdate','l_shipinstruct','l_shipmode']].groupby(by=['l_quantity']).agg('min',numeric_only=True) 
df397 = lineitem[(lineitem['l_suppkey'] >= 606) | (lineitem['l_quantity'] >= 11) & (lineitem['l_discount'] >= 0.63)][['l_partkey','l_linenumber','l_quantity','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True) 
df398 = lineitem[(lineitem['l_suppkey'] < 2625) | (lineitem['l_quantity'] < 21) & (lineitem['l_discount'] < 1.89)][['l_partkey','l_quantity','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate','l_shipinstruct']].groupby(by=['l_shipdate']).agg('mean',numeric_only=True) 
df399 = lineitem[(lineitem['l_suppkey'] < 5061) & (lineitem['l_quantity'] < 241) | (lineitem['l_discount'] < 202.23)][['l_orderkey','l_suppkey','l_extendedprice','l_tax','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipinstruct']].groupby(by=['l_returnflag']).agg('max',numeric_only=True) 
df400 = lineitem[(lineitem['l_suppkey'] >= 3060) | (lineitem['l_quantity'] >= 26) | (lineitem['l_discount'] >= 0.47)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_returnflag','l_linestatus','l_shipdate','l_receiptdate','l_shipinstruct']].groupby(by=['l_returnflag']).agg('min',numeric_only=True) 
df401 = lineitem[(lineitem['l_suppkey'] <= 6456) | (lineitem['l_quantity'] <= 42) & (lineitem['l_discount'] <= 1.49)][['l_partkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_returnflag','l_linestatus','l_receiptdate','l_shipmode']].groupby(by=['l_linenumber']).agg('min',numeric_only=True) 
df402 = lineitem[(lineitem['l_suppkey'] >= 606) | (lineitem['l_quantity'] >= 11) & (lineitem['l_discount'] >= 0.63)][['l_extendedprice','l_discount','l_tax','l_returnflag','l_linestatus','l_shipdate','l_shipmode','l_comment']].groupby(by=['l_discount']).agg('mean',numeric_only=True) 
df403 = lineitem[(lineitem['l_suppkey'] >= 3060) | (lineitem['l_quantity'] >= 26) | (lineitem['l_discount'] >= 0.47)][['l_partkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('min',numeric_only=True) 
df404 = lineitem[(lineitem['l_suppkey'] >= 606) | (lineitem['l_quantity'] >= 11) & (lineitem['l_discount'] >= 0.63)][['l_partkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_returnflag','l_linestatus','l_receiptdate','l_shipmode']].groupby(by=['l_quantity']).agg('max',numeric_only=True) 
df405 = lineitem[(lineitem['l_suppkey'] >= 10691) & (lineitem['l_quantity'] >= 50) | (lineitem['l_discount'] >= 0.73)][['l_partkey','l_discount','l_returnflag','l_linestatus','l_shipdate','l_receiptdate','l_shipinstruct','l_shipmode']].groupby(by=['l_returnflag']).agg('min',numeric_only=True) 
df406 = lineitem[(lineitem['l_suppkey'] >= 606) | (lineitem['l_quantity'] >= 11) | (lineitem['l_discount'] >= 0.63)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_linestatus']).agg('min',numeric_only=True) 
df407 = lineitem[(lineitem['l_suppkey'] >= 3060) | (lineitem['l_quantity'] >= 26) | (lineitem['l_discount'] >= 0.47)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_quantity','l_tax','l_commitdate','l_shipmode','l_comment']].groupby(by=['l_partkey']).agg('mean',numeric_only=True) 
df408 = lineitem[(lineitem['l_suppkey'] > 5264) | (lineitem['l_quantity'] > 27) & (lineitem['l_discount'] > 1.2)][['l_partkey','l_suppkey','l_linenumber','l_discount','l_shipdate','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_shipmode']).agg('mean',numeric_only=True) 
df409 = lineitem[(lineitem['l_suppkey'] >= 606) | (lineitem['l_quantity'] >= 11) & (lineitem['l_discount'] >= 0.63)][['l_orderkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_shipdate','l_shipinstruct','l_shipmode']].groupby(by=['l_linestatus']).agg('mean',numeric_only=True) 
df410 = lineitem[(lineitem['l_suppkey'] < 13662) & (lineitem['l_quantity'] < 64) | (lineitem['l_discount'] < 1.77)][['l_partkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_commitdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_shipmode']).agg('min',numeric_only=True) 
df411 = lineitem[(lineitem['l_suppkey'] >= 606) | (lineitem['l_quantity'] >= 11) & (lineitem['l_discount'] >= 0.63)][['l_partkey','l_suppkey','l_extendedprice','l_tax','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct']].groupby(by=['l_shipinstruct']).agg('min',numeric_only=True) 
df412 = lineitem[(lineitem['l_suppkey'] < 9082) | (lineitem['l_quantity'] < 52) & (lineitem['l_discount'] < 1.5)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_receiptdate','l_shipinstruct','l_shipmode']].groupby(by=['l_receiptdate']).agg('max',numeric_only=True) 
df413 = lineitem[(lineitem['l_suppkey'] >= 10298) | (lineitem['l_quantity'] >= 42) | (lineitem['l_discount'] >= 0.58)][['l_orderkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('mean',numeric_only=True) 
df414 = lineitem[(lineitem['l_suppkey'] <= 2546) | (lineitem['l_quantity'] <= 15) & (lineitem['l_discount'] <= 1.6)][['l_suppkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True) 
df415 = lineitem[(lineitem['l_suppkey'] > 7141) & (lineitem['l_quantity'] > 42) | (lineitem['l_discount'] > 0.41)][['l_suppkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True) 
df416 = lineitem[(lineitem['l_suppkey'] == 10347) & (lineitem['l_quantity'] == 39) | (lineitem['l_discount'] == 3.03)][['l_partkey','l_linenumber','l_extendedprice','l_tax','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']].groupby(by=['l_partkey']).agg('min',numeric_only=True) 
df417 = lineitem[(lineitem['l_suppkey'] > 11613) & (lineitem['l_quantity'] > 43) & (lineitem['l_discount'] > 0.74)][['l_partkey','l_linenumber','l_quantity','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_commitdate']].groupby(by=['l_partkey']).agg('min',numeric_only=True) 
df418 = lineitem[(lineitem['l_suppkey'] > 4201) | (lineitem['l_quantity'] > 37) | (lineitem['l_discount'] > 1.22)][['l_partkey','l_suppkey','l_quantity','l_tax','l_returnflag','l_linestatus','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True) 
df419 = lineitem[(lineitem['l_suppkey'] > 910) & (lineitem['l_quantity'] > 14) & (lineitem['l_discount'] > 1.12)][['l_suppkey','l_quantity','l_discount','l_returnflag','l_linestatus','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True) 
df420 = lineitem[(lineitem['l_suppkey'] < 9082) | (lineitem['l_quantity'] < 52) & (lineitem['l_discount'] < 1.5)][['l_suppkey','l_quantity','l_extendedprice','l_discount','l_tax','l_returnflag','l_linestatus','l_shipdate','l_shipinstruct','l_shipmode']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True) 
df421 = lineitem[(lineitem['l_suppkey'] > 5264) | (lineitem['l_quantity'] > 27) & (lineitem['l_discount'] > 1.2)][['l_orderkey','l_partkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_linenumber']).agg('mean',numeric_only=True) 
df422 = lineitem[(lineitem['l_suppkey'] <= 7665) | (lineitem['l_quantity'] <= 49) & (lineitem['l_discount'] <= 1.03)][['l_partkey','l_suppkey','l_discount','l_tax','l_returnflag','l_shipdate','l_receiptdate','l_comment']].groupby(by=['l_comment']).agg('min',numeric_only=True) 
df423 = lineitem[(lineitem['l_suppkey'] > 11213) | (lineitem['l_quantity'] > 55) & (lineitem['l_discount'] > 0.73)][['l_partkey','l_suppkey','l_linenumber','l_extendedprice','l_tax','l_linestatus','l_shipdate','l_comment']].groupby(by=['l_linestatus']).agg('mean',numeric_only=True) 
df424 = lineitem[(lineitem['l_suppkey'] < 2625) | (lineitem['l_quantity'] < 21) | (lineitem['l_discount'] < 1.89)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_returnflag','l_commitdate','l_shipmode']].groupby(by=['l_quantity']).agg('max',numeric_only=True) 
df425 = lineitem[(lineitem['l_suppkey'] > 2751) & (lineitem['l_quantity'] > 225) | (lineitem['l_discount'] > 201.17)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_shipinstruct','l_comment']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True) 
df426 = lineitem[(lineitem['l_suppkey'] < 13662) & (lineitem['l_quantity'] < 64) | (lineitem['l_discount'] < 1.77)][['l_partkey','l_suppkey','l_linenumber','l_discount','l_tax','l_linestatus','l_shipdate','l_receiptdate','l_comment']].groupby(by=['l_linenumber']).agg('min',numeric_only=True) 
df427 = lineitem[(lineitem['l_suppkey'] > 11613) & (lineitem['l_quantity'] > 43) & (lineitem['l_discount'] > 0.74)][['l_orderkey','l_quantity','l_extendedprice','l_discount','l_tax','l_linestatus','l_receiptdate','l_shipinstruct','l_shipmode']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True) 
df428 = lineitem[(lineitem['l_suppkey'] < 5061) & (lineitem['l_quantity'] < 241) | (lineitem['l_discount'] < 202.23)][['l_orderkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_comment']).agg('max',numeric_only=True) 
df429 = lineitem[(lineitem['l_suppkey'] < 2625) | (lineitem['l_quantity'] < 21) & (lineitem['l_discount'] < 1.89)][['l_orderkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_orderkey']).agg('min',numeric_only=True) 
df430 = lineitem[(lineitem['l_suppkey'] > 11213) | (lineitem['l_quantity'] > 55) & (lineitem['l_discount'] > 0.73)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_discount','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True) 
df431 = lineitem[(lineitem['l_suppkey'] < 9082) | (lineitem['l_quantity'] < 52) & (lineitem['l_discount'] < 1.5)][['l_partkey','l_quantity','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_shipmode']).agg('mean',numeric_only=True) 
df432 = lineitem[(lineitem['l_suppkey'] < 10426) | (lineitem['l_quantity'] < 57) & (lineitem['l_discount'] < 2.02)][['l_partkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipinstruct','l_shipmode']].groupby(by=['l_discount']).agg('max',numeric_only=True) 
df433 = lineitem[(lineitem['l_suppkey'] == 5908) | (lineitem['l_quantity'] == 245) | (lineitem['l_discount'] == 202.6)][['l_orderkey','l_extendedprice','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']].groupby(by=['l_orderkey']).agg('min',numeric_only=True) 
df434 = lineitem[(lineitem['l_suppkey'] < 5061) & (lineitem['l_quantity'] < 241) | (lineitem['l_discount'] < 202.23)][['l_extendedprice','l_tax','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']].groupby(by=['l_extendedprice']).agg('min',numeric_only=True) 
df435 = lineitem[(lineitem['l_suppkey'] == 10347) & (lineitem['l_quantity'] == 39) | (lineitem['l_discount'] == 3.03)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_discount','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipmode']).agg('min',numeric_only=True) 
df436 = lineitem[(lineitem['l_suppkey'] <= 7665) | (lineitem['l_quantity'] <= 49) & (lineitem['l_discount'] <= 1.03)][['l_orderkey','l_extendedprice','l_discount','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_comment']].groupby(by=['l_comment']).agg('max',numeric_only=True) 
df437 = lineitem[(lineitem['l_suppkey'] >= 4955) | (lineitem['l_quantity'] >= 35) | (lineitem['l_discount'] >= 0.39)][['l_partkey','l_suppkey','l_linenumber','l_discount','l_returnflag','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_shipinstruct']).agg('max',numeric_only=True) 
df438 = lineitem[(lineitem['l_suppkey'] == 16379) & (lineitem['l_quantity'] == 79) | (lineitem['l_discount'] == 2.07)][['l_orderkey','l_partkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_returnflag']).agg('mean',numeric_only=True) 
df439 = lineitem[(lineitem['l_suppkey'] <= 9202) | (lineitem['l_quantity'] <= 48) & (lineitem['l_discount'] <= 1.83)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_tax','l_commitdate','l_receiptdate','l_shipinstruct','l_shipmode']].groupby(by=['l_shipinstruct']).agg('min',numeric_only=True) 
df440 = lineitem[(lineitem['l_suppkey'] <= 2546) | (lineitem['l_quantity'] <= 15) & (lineitem['l_discount'] <= 1.6)][['l_partkey','l_linenumber','l_quantity','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipinstruct']].groupby(by=['l_discount']).agg('mean',numeric_only=True) 
df441 = lineitem[(lineitem['l_suppkey'] == 12953) & (lineitem['l_quantity'] == 64) & (lineitem['l_discount'] == 2.5)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_linestatus','l_commitdate','l_shipinstruct']].groupby(by=['l_linestatus']).agg('mean',numeric_only=True) 
df442 = lineitem[(lineitem['l_suppkey'] == 11016) & (lineitem['l_quantity'] == 57) & (lineitem['l_discount'] == 1.2)][['l_orderkey','l_partkey','l_linenumber','l_tax','l_returnflag','l_shipdate','l_receiptdate','l_shipinstruct','l_comment']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True) 
df443 = lineitem[(lineitem['l_suppkey'] >= 6576) | (lineitem['l_quantity'] >= 30) & (lineitem['l_discount'] >= 0.82)][['l_orderkey','l_partkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_shipdate','l_receiptdate','l_shipinstruct']].groupby(by=['l_returnflag']).agg('max',numeric_only=True) 
df444 = lineitem[(lineitem['l_suppkey'] <= 7665) | (lineitem['l_quantity'] <= 49) & (lineitem['l_discount'] <= 1.03)][['l_partkey','l_suppkey','l_linenumber','l_discount','l_tax','l_linestatus','l_shipdate','l_receiptdate','l_comment']].groupby(by=['l_shipdate']).agg('mean',numeric_only=True) 
df445 = lineitem[(lineitem['l_suppkey'] == 16379) & (lineitem['l_quantity'] == 79) | (lineitem['l_discount'] == 2.07)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('max',numeric_only=True) 
df446 = lineitem[(lineitem['l_suppkey'] <= 11301) & (lineitem['l_quantity'] <= 55) | (lineitem['l_discount'] <= 1.22)][['l_orderkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']].groupby(by=['l_commitdate']).agg('max',numeric_only=True) 
df447 = lineitem[(lineitem['l_suppkey'] == 10347) & (lineitem['l_quantity'] == 39) | (lineitem['l_discount'] == 3.03)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']].groupby(by=['l_orderkey']).agg('max',numeric_only=True) 
df448 = lineitem[(lineitem['l_suppkey'] >= 10691) | (lineitem['l_quantity'] >= 50) & (lineitem['l_discount'] >= 0.73)][['l_suppkey','l_linenumber','l_discount','l_tax','l_linestatus','l_shipdate','l_commitdate','l_receiptdate']].groupby(by=['l_linestatus']).agg('mean',numeric_only=True) 
df449 = lineitem[(lineitem['l_suppkey'] < 10426) | (lineitem['l_quantity'] < 57) & (lineitem['l_discount'] < 2.02)][['l_orderkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_shipdate','l_shipinstruct','l_shipmode']].groupby(by=['l_discount']).agg('max',numeric_only=True) 
df450 = nation[nation['n_regionkey'] <= 7][['n_nationkey','n_comment']] 
df451 = nation[nation['n_regionkey'] >= 0][['n_name','n_regionkey']] 
df452 = nation[nation['n_regionkey'] <= 1][['n_regionkey','n_comment']] 
df453 = nation[nation['n_regionkey'] == 3][['n_nationkey','n_name','n_regionkey','n_comment']] 
df454 = nation[nation['n_regionkey'] == 6][['n_nationkey','n_regionkey']] 
df455 = nation[nation['n_regionkey'] <= 5][['n_name','n_regionkey']] 
df456 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_regionkey','n_comment']] 
df457 = nation[nation['n_regionkey'] <= 7][['n_nationkey','n_name','n_regionkey','n_comment']] 
df458 = nation[nation['n_regionkey'] > 6][['n_name','n_regionkey','n_comment']] 
df459 = nation[nation['n_regionkey'] >= 3][['n_regionkey','n_comment']] 
df460 = nation[nation['n_regionkey'] > 1][['n_nationkey','n_name','n_regionkey','n_comment']] 
df461 = nation[nation['n_regionkey'] > 1][['n_nationkey','n_comment']] 
df462 = nation[nation['n_regionkey'] == 5][['n_nationkey','n_name','n_regionkey','n_comment']] 
df463 = nation[nation['n_regionkey'] < 2][['n_nationkey','n_comment']] 
df464 = nation[nation['n_regionkey'] > 4][['n_nationkey','n_regionkey','n_comment']] 
df465 = nation[nation['n_regionkey'] < 7][['n_name','n_regionkey','n_comment']] 
df466 = nation[nation['n_regionkey'] > 1][['n_nationkey','n_name']] 
df467 = nation[nation['n_regionkey'] > 4][['n_nationkey','n_name']] 
df468 = nation[nation['n_regionkey'] > 6][['n_name','n_comment']] 
df469 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_comment']] 
df470 = nation[nation['n_regionkey'] < 2][['n_nationkey','n_regionkey']] 
df471 = nation[nation['n_regionkey'] > 3][['n_name','n_regionkey']] 
df472 = nation[nation['n_regionkey'] <= 3][['n_nationkey','n_name']] 
df473 = nation[nation['n_regionkey'] > 1][['n_nationkey','n_regionkey']] 
df474 = nation[nation['n_regionkey'] <= 26][['n_name','n_regionkey','n_comment']] 
df475 = nation[nation['n_regionkey'] > 1][['n_nationkey','n_regionkey']] 
df476 = nation[nation['n_regionkey'] >= 0][['n_name','n_regionkey']] 
df477 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_regionkey']] 
df478 = nation[nation['n_regionkey'] == 4][['n_nationkey','n_name','n_regionkey','n_comment']] 
df479 = nation[nation['n_regionkey'] < 4][['n_nationkey','n_regionkey']] 
df480 = nation[nation['n_regionkey'] <= 2][['n_name','n_regionkey','n_comment']] 
df481 = nation[nation['n_regionkey'] == 3][['n_regionkey','n_comment']] 
df482 = nation[nation['n_regionkey'] == 3][['n_nationkey','n_name','n_regionkey','n_comment']] 
df483 = nation[nation['n_regionkey'] <= 2][['n_name','n_regionkey']] 
df484 = nation[nation['n_regionkey'] >= 1][['n_nationkey','n_regionkey']] 
df485 = nation[nation['n_regionkey'] >= 5][['n_nationkey','n_regionkey','n_comment']] 
df486 = nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name']] 
df487 = nation[nation['n_regionkey'] >= 5][['n_nationkey','n_name','n_regionkey']] 
df488 = nation[nation['n_regionkey'] >= 1][['n_nationkey','n_comment']] 
df489 = nation[nation['n_regionkey'] <= 2][['n_nationkey','n_regionkey']] 
df490 = nation[nation['n_regionkey'] == 3][['n_nationkey','n_name']] 
df491 = nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_regionkey','n_comment']] 
df492 = nation[nation['n_regionkey'] <= 7][['n_name','n_regionkey']] 
df493 = nation[nation['n_regionkey'] <= 4][['n_nationkey','n_regionkey','n_comment']] 
df494 = nation[nation['n_regionkey'] <= 3][['n_nationkey','n_name','n_regionkey']] 
df495 = nation[nation['n_regionkey'] < 5][['n_nationkey','n_comment']] 
df496 = nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey']] 
df497 = nation[nation['n_regionkey'] >= 3][['n_name','n_regionkey','n_comment']] 
df498 = nation[nation['n_regionkey'] < 2][['n_name','n_regionkey']] 
df499 = nation[nation['n_regionkey'] > 26][['n_name','n_comment']] 
df500 = nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_comment']] 
df501 = nation[nation['n_regionkey'] > 3][['n_nationkey','n_name']] 
df502 = nation[nation['n_regionkey'] <= 4][['n_nationkey','n_comment']] 
df503 = nation[nation['n_regionkey'] > 3][['n_regionkey','n_comment']] 
df504 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_regionkey']] 
df505 = nation[nation['n_regionkey'] <= 3][['n_name','n_regionkey']] 
df506 = nation[nation['n_regionkey'] < 26][['n_nationkey','n_name','n_regionkey','n_comment']] 
df507 = nation[nation['n_regionkey'] == 3][['n_nationkey','n_comment']] 
df508 = nation[nation['n_regionkey'] <= 7][['n_nationkey','n_name','n_regionkey']] 
df509 = nation[nation['n_regionkey'] == 27][['n_nationkey','n_name','n_comment']] 
df510 = nation[nation['n_regionkey'] > 6][['n_name','n_regionkey']] 
df511 = nation[nation['n_regionkey'] == 3][['n_nationkey','n_name']] 
df512 = nation[nation['n_regionkey'] <= 2][['n_regionkey','n_comment']] 
df513 = nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name']] 
df514 = nation[nation['n_regionkey'] <= 5][['n_nationkey','n_comment']] 
df515 = nation[nation['n_regionkey'] > 1][['n_name','n_regionkey','n_comment']] 
df516 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_comment']] 
df517 = nation[nation['n_regionkey'] <= 4][['n_nationkey','n_name','n_regionkey']] 
df518 = nation[nation['n_regionkey'] < 2][['n_nationkey','n_name']] 
df519 = nation[nation['n_regionkey'] >= 0][['n_name','n_comment']] 
df520 = nation[nation['n_regionkey'] <= 26][['n_nationkey','n_name']] 
df521 = nation[nation['n_regionkey'] <= 26][['n_regionkey','n_comment']] 
df522 = nation[nation['n_regionkey'] > 1][['n_regionkey','n_comment']] 
df523 = nation[nation['n_regionkey'] == 4][['n_nationkey','n_name']] 
df524 = nation[nation['n_regionkey'] == 3][['n_name','n_comment']] 
df525 = nation[nation['n_regionkey'] == 5][['n_nationkey','n_regionkey']] 
df526 = nation[nation['n_regionkey'] < 5][['n_nationkey','n_name','n_comment']] 
df527 = nation[nation['n_regionkey'] < 4][['n_nationkey','n_name','n_regionkey','n_comment']] 
df528 = nation[nation['n_regionkey'] < 2][['n_nationkey','n_comment']] 
df529 = nation[nation['n_regionkey'] < 7][['n_nationkey','n_name','n_regionkey']] 
df530 = nation[nation['n_regionkey'] > 26][['n_nationkey','n_name','n_comment']] 
df531 = nation[nation['n_regionkey'] < 7][['n_nationkey','n_name','n_comment']] 
df532 = nation[nation['n_regionkey'] > 3][['n_name','n_regionkey','n_comment']] 
df533 = nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey','n_comment']] 
df534 = nation[nation['n_regionkey'] >= 5][['n_nationkey','n_name','n_regionkey']] 
df535 = nation[nation['n_regionkey'] >= 0][['n_name','n_regionkey','n_comment']] 
df536 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey']] 
df537 = nation[nation['n_regionkey'] < 2][['n_nationkey','n_regionkey','n_comment']] 
df538 = nation[nation['n_regionkey'] > 3][['n_nationkey','n_name','n_regionkey','n_comment']] 
df539 = nation[nation['n_regionkey'] == 5][['n_nationkey','n_name','n_comment']] 
df540 = nation[nation['n_regionkey'] < 4][['n_name','n_regionkey','n_comment']] 
df541 = nation[nation['n_regionkey'] >= 25][['n_nationkey','n_regionkey','n_comment']] 
df542 = nation[nation['n_regionkey'] < 5][['n_nationkey','n_name']] 
df543 = nation[nation['n_regionkey'] < 7][['n_nationkey','n_comment']] 
df544 = nation[nation['n_regionkey'] <= 4][['n_nationkey','n_name','n_comment']] 
df545 = nation[nation['n_regionkey'] == 4][['n_nationkey','n_regionkey']] 
df546 = nation[nation['n_regionkey'] > 6][['n_regionkey','n_comment']] 
df547 = nation[nation['n_regionkey'] <= 2][['n_name','n_comment']] 
df548 = nation[nation['n_regionkey'] > 1][['n_name','n_comment']] 
df549 = nation[nation['n_regionkey'] == 6][['n_nationkey','n_comment']] 
df550 = region[region['r_regionkey'] <= 11] 
df551 = region[region['r_regionkey'] >= 7] 
df552 = region[region['r_regionkey'] < 6] 
df553 = region[region['r_regionkey'] > 3] 
df554 = region[region['r_regionkey'] < 13] 
df555 = region[region['r_regionkey'] > 5] 
df556 = region[region['r_regionkey'] == 9] 
df557 = region[region['r_regionkey'] < 9] 
df558 = region[region['r_regionkey'] < 4] 
df559 = region[region['r_regionkey'] > 2] 
df560 = region[region['r_regionkey'] == 5] 
df561 = region[region['r_regionkey'] == 15] 
df562 = region[region['r_regionkey'] <= 5] 
df563 = region[region['r_regionkey'] >= 5] 
df564 = region[region['r_regionkey'] >= 2] 
df565 = region[region['r_regionkey'] <= 8] 
df566 = region[region['r_regionkey'] >= 4] 
df567 = region[region['r_regionkey'] < 9] 
df568 = region[region['r_regionkey'] <= 4] 
df569 = region[region['r_regionkey'] > 2] 
df570 = region[region['r_regionkey'] > 5] 
df571 = region[region['r_regionkey'] == 10] 
df572 = region[region['r_regionkey'] < 5] 
df573 = region[region['r_regionkey'] >= 1] 
df574 = region[region['r_regionkey'] >= 4] 
df575 = region[region['r_regionkey'] > 7] 
df576 = region[region['r_regionkey'] >= 5] 
df577 = region[region['r_regionkey'] < 4] 
df578 = region[region['r_regionkey'] > 7] 
df579 = region[region['r_regionkey'] == 5] 
df580 = region[region['r_regionkey'] == 7] 
df581 = region[region['r_regionkey'] == 9] 
df582 = region[region['r_regionkey'] < 9] 
df583 = region[region['r_regionkey'] == 9] 
df584 = region[region['r_regionkey'] > 9] 
df585 = region[region['r_regionkey'] >= 5] 
df586 = region[region['r_regionkey'] <= 7] 
df587 = region[region['r_regionkey'] >= 2] 
df588 = region[region['r_regionkey'] <= 7] 
df589 = region[region['r_regionkey'] >= 2] 
df590 = region[region['r_regionkey'] <= 7] 
df591 = region[region['r_regionkey'] >= 4] 
df592 = region[region['r_regionkey'] > 5] 
df593 = region[region['r_regionkey'] < 9] 
df594 = region[region['r_regionkey'] <= 4] 
df595 = region[region['r_regionkey'] > 7] 
df596 = region[region['r_regionkey'] < 7] 
df597 = region[region['r_regionkey'] <= 7] 
df598 = region[region['r_regionkey'] <= 4] 
df599 = region[region['r_regionkey'] == 6] 
df600 = orders[(orders['o_totalprice'] == 422235.78) | (orders['o_shippriority'] == 0)][['o_custkey','o_totalprice','o_orderdate','o_clerk']] 
df601 = orders[(orders['o_totalprice'] < 405078.21) | (orders['o_shippriority'] < 0)][['o_totalprice','o_orderdate','o_comment']] 
df602 = orders[(orders['o_totalprice'] >= 230605.89) | (orders['o_shippriority'] >= 0)][['o_custkey','o_totalprice','o_clerk']] 
df603 = orders[(orders['o_totalprice'] > 319663.56) & (orders['o_shippriority'] > 0)][['o_orderstatus','o_orderpriority','o_shippriority','o_comment']] 
df604 = orders[(orders['o_totalprice'] <= 137894.77) & (orders['o_shippriority'] <= 0)][['o_orderdate','o_clerk','o_shippriority','o_comment']] 
df605 = orders[(orders['o_totalprice'] >= 99053.86) | (orders['o_shippriority'] >= 0)][['o_custkey','o_totalprice','o_orderdate','o_orderpriority']] 
df606 = orders[(orders['o_totalprice'] <= 167690.18) & (orders['o_shippriority'] <= 200)][['o_custkey','o_totalprice','o_comment']] 
df607 = orders[(orders['o_totalprice'] > 127042.35) & (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderdate','o_comment']] 
df608 = orders[(orders['o_totalprice'] < 218340.87) & (orders['o_shippriority'] < 0)][['o_orderkey','o_orderpriority','o_shippriority','o_comment']] 
df609 = orders[(orders['o_totalprice'] == 398392.6) & (orders['o_shippriority'] == 0)][['o_orderstatus','o_totalprice','o_orderdate','o_shippriority','o_comment']] 
df610 = orders[(orders['o_totalprice'] < 218340.87) | (orders['o_shippriority'] < 0)][['o_custkey','o_orderstatus','o_orderdate','o_clerk','o_shippriority']] 
df611 = orders[(orders['o_totalprice'] == 398392.6) & (orders['o_shippriority'] == 0)][['o_orderstatus','o_orderdate','o_clerk','o_comment']] 
df612 = orders[(orders['o_totalprice'] > 182086.78) & (orders['o_shippriority'] > 0)][['o_orderkey','o_totalprice','o_orderdate','o_shippriority']] 
df613 = orders[(orders['o_totalprice'] > 127042.35) & (orders['o_shippriority'] > 0)][['o_totalprice','o_orderdate','o_orderpriority','o_shippriority']] 
df614 = orders[(orders['o_totalprice'] == 317254.93) | (orders['o_shippriority'] == 0)][['o_clerk','o_shippriority','o_comment']] 
df615 = orders[(orders['o_totalprice'] < 218340.87) & (orders['o_shippriority'] < 0)][['o_orderdate','o_shippriority','o_comment']] 
df616 = orders[(orders['o_totalprice'] == 234678.14) | (orders['o_shippriority'] == 0)][['o_clerk','o_shippriority','o_comment']] 
df617 = orders[(orders['o_totalprice'] <= 243822.88) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderdate','o_orderpriority']] 
df618 = orders[(orders['o_totalprice'] <= 384595.22) & (orders['o_shippriority'] <= 0)][['o_totalprice','o_orderdate','o_shippriority']] 
df619 = orders[(orders['o_totalprice'] < 218340.87) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_totalprice','o_shippriority']] 
df620 = orders[(orders['o_totalprice'] >= 444394.68) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_totalprice','o_clerk','o_comment']] 
df621 = orders[(orders['o_totalprice'] <= 247911.76) & (orders['o_shippriority'] <= 0)][['o_custkey','o_orderstatus','o_shippriority','o_comment']] 
df622 = orders[(orders['o_totalprice'] < 397518.57) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderdate','o_orderpriority']] 
df623 = orders[(orders['o_totalprice'] >= 99053.86) | (orders['o_shippriority'] >= 0)][['o_custkey','o_orderstatus','o_shippriority','o_comment']] 
df624 = orders[(orders['o_totalprice'] < 405078.21) | (orders['o_shippriority'] < 0)][['o_custkey','o_totalprice','o_orderdate','o_orderpriority']] 
df625 = orders[(orders['o_totalprice'] == 398392.6) & (orders['o_shippriority'] == 0)][['o_custkey','o_totalprice','o_orderdate','o_orderpriority','o_comment']] 
df626 = orders[(orders['o_totalprice'] == 234678.14) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']] 
df627 = orders[(orders['o_totalprice'] > 124286.96) | (orders['o_shippriority'] > 0)][['o_totalprice','o_orderpriority','o_clerk','o_shippriority','o_comment']] 
df628 = orders[(orders['o_totalprice'] < 397518.57) | (orders['o_shippriority'] < 0)][['o_orderstatus','o_totalprice','o_clerk']] 
df629 = orders[(orders['o_totalprice'] >= 293093.03) | (orders['o_shippriority'] >= 0)][['o_totalprice','o_orderpriority','o_clerk']] 
df630 = orders[(orders['o_totalprice'] < 218340.87) & (orders['o_shippriority'] < 0)][['o_custkey','o_orderpriority','o_clerk','o_comment']] 
df631 = orders[(orders['o_totalprice'] <= 187052.72) | (orders['o_shippriority'] <= 0)][['o_custkey','o_totalprice','o_orderpriority','o_clerk','o_comment']] 
df632 = orders[(orders['o_totalprice'] < 554088.51) | (orders['o_shippriority'] < 0)][['o_orderdate','o_orderpriority','o_comment']] 
df633 = orders[(orders['o_totalprice'] <= 187052.72) & (orders['o_shippriority'] <= 0)][['o_custkey','o_totalprice','o_orderdate','o_orderpriority']] 
df634 = orders[(orders['o_totalprice'] <= 243822.88) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_clerk']] 
df635 = orders[(orders['o_totalprice'] > 295871.87) | (orders['o_shippriority'] > 0)][['o_custkey','o_totalprice','o_orderpriority','o_clerk','o_shippriority']] 
df636 = orders[(orders['o_totalprice'] <= 243822.88) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_orderdate','o_shippriority']] 
df637 = orders[(orders['o_totalprice'] > 127042.35) & (orders['o_shippriority'] > 0)][['o_custkey','o_orderstatus','o_totalprice','o_orderdate','o_shippriority']] 
df638 = orders[(orders['o_totalprice'] >= 57849.37) | (orders['o_shippriority'] >= 0)][['o_totalprice','o_clerk','o_comment']] 
df639 = orders[(orders['o_totalprice'] >= 57849.37) & (orders['o_shippriority'] >= 0)][['o_orderstatus','o_orderpriority','o_clerk']] 
df640 = orders[(orders['o_totalprice'] >= 86062.08) | (orders['o_shippriority'] >= 200)][['o_orderkey','o_orderdate','o_clerk','o_shippriority']] 
df641 = orders[(orders['o_totalprice'] <= 167690.18) & (orders['o_shippriority'] <= 200)][['o_orderstatus','o_orderdate','o_comment']] 
df642 = orders[(orders['o_totalprice'] <= 137894.77) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_clerk','o_comment']] 
df643 = orders[(orders['o_totalprice'] > 182086.78) & (orders['o_shippriority'] > 0)][['o_orderdate','o_orderpriority','o_shippriority','o_comment']] 
df644 = orders[(orders['o_totalprice'] >= 293093.03) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_shippriority']] 
df645 = orders[(orders['o_totalprice'] <= 187052.72) | (orders['o_shippriority'] <= 0)][['o_orderstatus','o_totalprice','o_orderpriority','o_clerk','o_comment']] 
df646 = orders[(orders['o_totalprice'] > 124286.96) | (orders['o_shippriority'] > 0)][['o_orderstatus','o_totalprice','o_shippriority']] 
df647 = orders[(orders['o_totalprice'] >= 444394.68) | (orders['o_shippriority'] >= 0)][['o_custkey','o_orderstatus','o_totalprice','o_orderdate']] 
df648 = orders[(orders['o_totalprice'] < 250726.25) | (orders['o_shippriority'] < 200)][['o_orderkey','o_custkey','o_orderpriority','o_clerk','o_comment']] 
df649 = orders[(orders['o_totalprice'] >= 444394.68) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderdate']] 
df650 = orders[(orders['o_totalprice'] < 554088.51) & (orders['o_shippriority'] < 0)][['o_custkey','o_orderstatus','o_clerk','o_comment']] 
df651 = orders[(orders['o_totalprice'] >= 293093.03) | (orders['o_shippriority'] >= 0)][['o_custkey','o_totalprice','o_comment']] 
df652 = orders[(orders['o_totalprice'] > 319663.56) & (orders['o_shippriority'] > 0)][['o_custkey','o_totalprice','o_orderpriority','o_clerk','o_comment']] 
df653 = orders[(orders['o_totalprice'] >= 153109.77) & (orders['o_shippriority'] >= 0)][['o_orderstatus','o_totalprice','o_orderpriority','o_shippriority','o_comment']] 
df654 = orders[(orders['o_totalprice'] < 308429.48) & (orders['o_shippriority'] < 0)][['o_orderkey','o_totalprice','o_orderdate','o_orderpriority','o_comment']] 
df655 = orders[(orders['o_totalprice'] < 293939.8) & (orders['o_shippriority'] < 0)][['o_custkey','o_orderstatus','o_totalprice','o_clerk']] 
df656 = orders[(orders['o_totalprice'] > 92512.75) | (orders['o_shippriority'] > 200)][['o_orderkey','o_totalprice','o_clerk','o_shippriority','o_comment']] 
df657 = orders[(orders['o_totalprice'] >= 153109.77) & (orders['o_shippriority'] >= 0)][['o_custkey','o_totalprice','o_orderdate','o_orderpriority']] 
df658 = orders[(orders['o_totalprice'] >= 99053.86) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk','o_shippriority']] 
df659 = orders[(orders['o_totalprice'] <= 376620.16) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk','o_comment']] 
df660 = orders[(orders['o_totalprice'] <= 549998.11) | (orders['o_shippriority'] <= 0)][['o_custkey','o_orderstatus','o_clerk']] 
df661 = orders[(orders['o_totalprice'] >= 444394.68) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_comment']] 
df662 = orders[(orders['o_totalprice'] < 293939.8) & (orders['o_shippriority'] < 0)][['o_custkey','o_orderstatus','o_orderdate','o_clerk']] 
df663 = orders[(orders['o_totalprice'] > 514342.08) | (orders['o_shippriority'] > 0)][['o_orderstatus','o_orderdate','o_orderpriority','o_shippriority','o_comment']] 
df664 = orders[(orders['o_totalprice'] >= 57849.37) & (orders['o_shippriority'] >= 0)][['o_orderstatus','o_totalprice','o_orderpriority','o_shippriority','o_comment']] 
df665 = orders[(orders['o_totalprice'] <= 137894.77) & (orders['o_shippriority'] <= 0)][['o_custkey','o_orderstatus','o_shippriority']] 
df666 = orders[(orders['o_totalprice'] > 127042.35) & (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus']] 
df667 = orders[(orders['o_totalprice'] >= 57849.37) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_comment']] 
df668 = orders[(orders['o_totalprice'] >= 444394.68) | (orders['o_shippriority'] >= 0)][['o_custkey','o_orderstatus','o_shippriority']] 
df669 = orders[(orders['o_totalprice'] <= 549998.11) | (orders['o_shippriority'] <= 0)][['o_orderstatus','o_clerk','o_shippriority','o_comment']] 
df670 = orders[(orders['o_totalprice'] <= 187052.72) & (orders['o_shippriority'] <= 0)][['o_custkey','o_totalprice','o_orderpriority','o_shippriority']] 
df671 = orders[(orders['o_totalprice'] > 92512.75) | (orders['o_shippriority'] > 200)][['o_orderkey','o_orderstatus','o_shippriority','o_comment']] 
df672 = orders[(orders['o_totalprice'] == 593019.22) | (orders['o_shippriority'] == 0)][['o_orderstatus','o_totalprice','o_clerk','o_shippriority']] 
df673 = orders[(orders['o_totalprice'] > 295871.87) | (orders['o_shippriority'] > 0)][['o_custkey','o_orderstatus','o_totalprice','o_comment']] 
df674 = orders[(orders['o_totalprice'] < 405078.21) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk']] 
df675 = orders[(orders['o_totalprice'] > 295871.87) | (orders['o_shippriority'] > 0)][['o_orderdate','o_clerk','o_shippriority','o_comment']] 
df676 = orders[(orders['o_totalprice'] == 307984.92) & (orders['o_shippriority'] == 200)][['o_totalprice','o_orderdate','o_shippriority']] 
df677 = orders[(orders['o_totalprice'] >= 153109.77) & (orders['o_shippriority'] >= 0)][['o_custkey','o_orderstatus','o_totalprice','o_orderpriority','o_clerk']] 
df678 = orders[(orders['o_totalprice'] <= 187052.72) | (orders['o_shippriority'] <= 0)][['o_custkey','o_orderstatus','o_totalprice']] 
df679 = orders[(orders['o_totalprice'] == 593019.22) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderpriority','o_comment']] 
df680 = orders[(orders['o_totalprice'] == 471191.41) & (orders['o_shippriority'] == 0)][['o_orderstatus','o_orderpriority','o_clerk','o_shippriority']] 
df681 = orders[(orders['o_totalprice'] == 307984.92) & (orders['o_shippriority'] == 200)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_shippriority']] 
df682 = orders[(orders['o_totalprice'] >= 57849.37) & (orders['o_shippriority'] >= 0)][['o_totalprice','o_orderdate','o_orderpriority','o_comment']] 
df683 = orders[(orders['o_totalprice'] < 554088.51) | (orders['o_shippriority'] < 0)][['o_totalprice','o_orderdate','o_orderpriority']] 
df684 = orders[(orders['o_totalprice'] <= 384595.22) & (orders['o_shippriority'] <= 0)][['o_custkey','o_orderstatus','o_totalprice','o_shippriority']] 
df685 = orders[(orders['o_totalprice'] < 308429.48) & (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderpriority','o_shippriority']] 
df686 = orders[(orders['o_totalprice'] >= 57849.37) & (orders['o_shippriority'] >= 0)][['o_totalprice','o_orderpriority','o_clerk']] 
df687 = orders[(orders['o_totalprice'] == 234678.14) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_orderdate','o_comment']] 
df688 = orders[(orders['o_totalprice'] == 398392.6) & (orders['o_shippriority'] == 0)][['o_custkey','o_orderstatus','o_totalprice','o_clerk']] 
df689 = orders[(orders['o_totalprice'] >= 57849.37) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_comment']] 
df690 = orders[(orders['o_totalprice'] > 182086.78) & (orders['o_shippriority'] > 0)][['o_totalprice','o_orderpriority','o_clerk','o_shippriority','o_comment']] 
df691 = orders[(orders['o_totalprice'] == 234678.14) | (orders['o_shippriority'] == 0)][['o_custkey','o_orderpriority','o_shippriority','o_comment']] 
df692 = orders[(orders['o_totalprice'] < 218340.87) & (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderpriority','o_clerk','o_comment']] 
df693 = orders[(orders['o_totalprice'] >= 444394.68) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_totalprice','o_orderdate','o_orderpriority','o_shippriority']] 
df694 = orders[(orders['o_totalprice'] <= 549998.11) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_clerk']] 
df695 = orders[(orders['o_totalprice'] == 422235.78) | (orders['o_shippriority'] == 0)][['o_custkey','o_orderstatus','o_clerk','o_shippriority','o_comment']] 
df696 = orders[(orders['o_totalprice'] <= 549998.11) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_clerk','o_comment']] 
df697 = orders[(orders['o_totalprice'] < 293939.8) & (orders['o_shippriority'] < 0)][['o_custkey','o_orderpriority','o_clerk','o_comment']] 
df698 = orders[(orders['o_totalprice'] >= 134525.34) & (orders['o_shippriority'] >= 0)][['o_custkey','o_totalprice','o_clerk']] 
df699 = orders[(orders['o_totalprice'] <= 549998.11) & (orders['o_shippriority'] <= 0)][['o_totalprice','o_orderpriority','o_clerk','o_shippriority','o_comment']] 
df700 = orders[(orders['o_totalprice'] >= 69483.51) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderdate','o_comment']].groupby(by=['o_orderkey']).agg('mean',numeric_only=True) 
df701 = orders[(orders['o_totalprice'] <= 174128.66) & (orders['o_shippriority'] <= 0)][['o_orderstatus','o_totalprice','o_orderdate','o_clerk','o_shippriority']].groupby(by=['o_clerk']).agg('mean',numeric_only=True) 
df702 = orders[(orders['o_totalprice'] >= 171124.62) | (orders['o_shippriority'] >= 0)][['o_custkey','o_orderstatus','o_totalprice','o_clerk','o_shippriority','o_comment']].groupby(by=['o_totalprice']).agg('mean',numeric_only=True) 
df703 = orders[(orders['o_totalprice'] < 317113.35) | (orders['o_shippriority'] < 0)][['o_custkey','o_orderstatus','o_totalprice','o_clerk','o_shippriority']].groupby(by=['o_clerk']).agg('min',numeric_only=True) 
df704 = orders[(orders['o_totalprice'] < 246789.17) & (orders['o_shippriority'] < 200)][['o_custkey','o_orderstatus','o_totalprice','o_clerk','o_shippriority','o_comment']].groupby(by=['o_totalprice']).agg('min',numeric_only=True) 
df705 = orders[(orders['o_totalprice'] > 445171.37) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderdate','o_shippriority','o_comment']].groupby(by=['o_orderkey']).agg('min',numeric_only=True) 
df706 = orders[(orders['o_totalprice'] == 439561.11) | (orders['o_shippriority'] == 0)][['o_orderkey','o_totalprice','o_orderdate','o_clerk','o_shippriority']].groupby(by=['o_shippriority']).agg('mean',numeric_only=True) 
df707 = orders[(orders['o_totalprice'] <= 263506.38) & (orders['o_shippriority'] <= 0)][['o_orderstatus','o_totalprice','o_orderdate','o_orderpriority','o_clerk']].groupby(by=['o_orderdate']).agg('max',numeric_only=True) 
df708 = orders[(orders['o_totalprice'] < 241406.33) & (orders['o_shippriority'] < 0)][['o_custkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True) 
df709 = orders[(orders['o_totalprice'] < 340916.31) | (orders['o_shippriority'] < 0)][['o_custkey','o_orderstatus','o_totalprice','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_clerk']).agg('min',numeric_only=True) 
df710 = orders[(orders['o_totalprice'] >= 69483.51) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderpriority','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('mean',numeric_only=True) 
df711 = orders[(orders['o_totalprice'] > 88850.44) | (orders['o_shippriority'] > 0)][['o_orderstatus','o_totalprice','o_orderdate','o_shippriority','o_comment']].groupby(by=['o_shippriority']).agg('min',numeric_only=True) 
df712 = orders[(orders['o_totalprice'] == 354852.91) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderpriority','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True) 
df713 = orders[(orders['o_totalprice'] >= 391206.91) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_shippriority']].groupby(by=['o_orderpriority']).agg('min',numeric_only=True) 
df714 = orders[(orders['o_totalprice'] >= 391206.91) & (orders['o_shippriority'] >= 0)][['o_custkey','o_orderstatus','o_orderdate','o_clerk','o_shippriority','o_comment']].groupby(by=['o_custkey']).agg('max',numeric_only=True) 
df715 = orders[(orders['o_totalprice'] <= 263506.38) & (orders['o_shippriority'] <= 0)][['o_custkey','o_orderstatus','o_orderdate','o_clerk','o_shippriority','o_comment']].groupby(by=['o_shippriority']).agg('mean',numeric_only=True) 
df716 = orders[(orders['o_totalprice'] < 367414.93) & (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderdate','o_clerk','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True) 
df717 = orders[(orders['o_totalprice'] > 88850.44) | (orders['o_shippriority'] > 0)][['o_custkey','o_orderstatus','o_orderdate','o_clerk','o_comment']].groupby(by=['o_orderstatus']).agg('max',numeric_only=True) 
df718 = orders[(orders['o_totalprice'] == 439561.11) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_orderdate','o_clerk','o_comment']].groupby(by=['o_clerk']).agg('min',numeric_only=True) 
df719 = orders[(orders['o_totalprice'] <= 194001.87) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderdate','o_orderpriority']].groupby(by=['o_orderdate']).agg('min',numeric_only=True) 
df720 = orders[(orders['o_totalprice'] >= 117687.01) & (orders['o_shippriority'] >= 0)][['o_orderstatus','o_orderdate','o_orderpriority','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('max',numeric_only=True) 
df721 = orders[(orders['o_totalprice'] <= 302784.5) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderpriority','o_shippriority']].groupby(by=['o_orderstatus']).agg('max',numeric_only=True) 
df722 = orders[(orders['o_totalprice'] >= 69483.51) & (orders['o_shippriority'] >= 0)][['o_orderstatus','o_totalprice','o_orderdate','o_clerk','o_comment']].groupby(by=['o_clerk']).agg('mean',numeric_only=True) 
df723 = orders[(orders['o_totalprice'] > 445171.37) & (orders['o_shippriority'] > 0)][['o_custkey','o_totalprice','o_orderpriority','o_comment']].groupby(by=['o_custkey']).agg('mean',numeric_only=True) 
df724 = orders[(orders['o_totalprice'] == 283518.04) & (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderpriority','o_shippriority']].groupby(by=['o_orderkey']).agg('min',numeric_only=True) 
df725 = orders[(orders['o_totalprice'] < 263026.51) & (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_comment']].groupby(by=['o_orderkey']).agg('min',numeric_only=True) 
df726 = orders[(orders['o_totalprice'] == 283518.04) & (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].groupby(by=['o_orderpriority']).agg('mean',numeric_only=True) 
df727 = orders[(orders['o_totalprice'] >= 130116.01) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_shippriority']).agg('mean',numeric_only=True) 
df728 = orders[(orders['o_totalprice'] == 283518.04) & (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderdate','o_shippriority','o_comment']].groupby(by=['o_shippriority']).agg('mean',numeric_only=True) 
df729 = orders[(orders['o_totalprice'] >= 171124.62) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_orderdate','o_shippriority']].groupby(by=['o_custkey']).agg('mean',numeric_only=True) 
df730 = orders[(orders['o_totalprice'] == 519176.88) & (orders['o_shippriority'] == 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_shippriority','o_comment']].groupby(by=['o_orderpriority']).agg('mean',numeric_only=True) 
df731 = orders[(orders['o_totalprice'] < 340916.31) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_clerk','o_shippriority']].groupby(by=['o_orderdate']).agg('mean',numeric_only=True) 
df732 = orders[(orders['o_totalprice'] < 340916.31) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True) 
df733 = orders[(orders['o_totalprice'] < 227921.15) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_clerk','o_comment']].groupby(by=['o_comment']).agg('mean',numeric_only=True) 
df734 = orders[(orders['o_totalprice'] > 141318.41) | (orders['o_shippriority'] > 200)][['o_custkey','o_totalprice','o_orderdate','o_orderpriority','o_clerk']].groupby(by=['o_orderdate']).agg('max',numeric_only=True) 
df735 = orders[(orders['o_totalprice'] <= 477011.62) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderpriority','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True) 
df736 = orders[(orders['o_totalprice'] <= 210341.43) & (orders['o_shippriority'] <= 0)][['o_orderstatus','o_totalprice','o_orderdate','o_orderpriority','o_shippriority']].groupby(by=['o_orderpriority']).agg('max',numeric_only=True) 
df737 = orders[(orders['o_totalprice'] >= 171124.62) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice']].groupby(by=['o_orderstatus']).agg('mean',numeric_only=True) 
df738 = orders[(orders['o_totalprice'] > 445171.37) & (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_shippriority']].groupby(by=['o_custkey']).agg('mean',numeric_only=True) 
df739 = orders[(orders['o_totalprice'] < 367414.93) & (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderpriority','o_comment']].groupby(by=['o_orderpriority']).agg('mean',numeric_only=True) 
df740 = orders[(orders['o_totalprice'] > 88850.44) | (orders['o_shippriority'] > 0)][['o_orderstatus','o_totalprice','o_orderdate','o_clerk','o_comment']].groupby(by=['o_clerk']).agg('max',numeric_only=True) 
df741 = orders[(orders['o_totalprice'] <= 174128.66) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_totalprice','o_clerk']].groupby(by=['o_orderkey']).agg('min',numeric_only=True) 
df742 = orders[(orders['o_totalprice'] > 191113.01) & (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('mean',numeric_only=True) 
df743 = orders[(orders['o_totalprice'] > 282915.12) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('mean',numeric_only=True) 
df744 = orders[(orders['o_totalprice'] > 137267.6) & (orders['o_shippriority'] > 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('max',numeric_only=True) 
df745 = orders[(orders['o_totalprice'] <= 174128.66) | (orders['o_shippriority'] <= 0)][['o_orderstatus','o_orderpriority','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('mean',numeric_only=True) 
df746 = orders[(orders['o_totalprice'] >= 391206.91) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority']].groupby(by=['o_custkey']).agg('min',numeric_only=True) 
df747 = orders[(orders['o_totalprice'] >= 130116.01) | (orders['o_shippriority'] >= 0)][['o_orderstatus','o_totalprice','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_orderpriority']).agg('mean',numeric_only=True) 
df748 = orders[(orders['o_totalprice'] > 445171.37) & (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_totalprice','o_orderpriority']].groupby(by=['o_custkey']).agg('mean',numeric_only=True) 
df749 = orders[(orders['o_totalprice'] <= 174128.66) & (orders['o_shippriority'] <= 0)][['o_custkey','o_totalprice','o_orderdate','o_orderpriority','o_clerk']].groupby(by=['o_orderdate']).agg('mean',numeric_only=True) 
df750 = orders[(orders['o_totalprice'] <= 210341.43) & (orders['o_shippriority'] <= 0)][['o_custkey','o_orderdate','o_orderpriority','o_clerk']].groupby(by=['o_orderpriority']).agg('min',numeric_only=True) 
df751 = orders[(orders['o_totalprice'] <= 210341.43) & (orders['o_shippriority'] <= 0)][['o_totalprice','o_clerk','o_shippriority','o_comment']].groupby(by=['o_shippriority']).agg('max',numeric_only=True) 
df752 = orders[(orders['o_totalprice'] == 392803.28) | (orders['o_shippriority'] == 0)][['o_custkey','o_orderstatus','o_totalprice','o_orderpriority','o_clerk','o_comment']].groupby(by=['o_clerk']).agg('max',numeric_only=True) 
df753 = orders[(orders['o_totalprice'] >= 197390.85) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderpriority','o_clerk']].groupby(by=['o_orderstatus']).agg('max',numeric_only=True) 
df754 = orders[(orders['o_totalprice'] > 88850.44) & (orders['o_shippriority'] > 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk','o_shippriority','o_comment']].groupby(by=['o_orderpriority']).agg('max',numeric_only=True) 
df755 = orders[(orders['o_totalprice'] > 88850.44) & (orders['o_shippriority'] > 0)][['o_custkey','o_orderdate','o_clerk','o_shippriority']].groupby(by=['o_clerk']).agg('max',numeric_only=True) 
df756 = orders[(orders['o_totalprice'] < 367414.93) & (orders['o_shippriority'] < 0)][['o_orderstatus','o_totalprice','o_orderdate','o_clerk','o_comment']].groupby(by=['o_clerk']).agg('min',numeric_only=True) 
df757 = orders[(orders['o_totalprice'] <= 477011.62) | (orders['o_shippriority'] <= 0)][['o_orderstatus','o_totalprice','o_orderdate','o_clerk','o_shippriority']].groupby(by=['o_clerk']).agg('max',numeric_only=True) 
df758 = orders[(orders['o_totalprice'] == 519176.88) & (orders['o_shippriority'] == 0)][['o_custkey','o_totalprice','o_orderdate','o_clerk','o_shippriority']].groupby(by=['o_clerk']).agg('mean',numeric_only=True) 
df759 = orders[(orders['o_totalprice'] < 501062.05) & (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_comment']].groupby(by=['o_orderkey']).agg('max',numeric_only=True) 
df760 = orders[(orders['o_totalprice'] < 246789.17) & (orders['o_shippriority'] < 200)][['o_custkey','o_totalprice','o_orderdate','o_clerk','o_shippriority']].groupby(by=['o_clerk']).agg('min',numeric_only=True) 
df761 = orders[(orders['o_totalprice'] <= 477011.62) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_totalprice','o_orderpriority','o_comment']].groupby(by=['o_custkey']).agg('min',numeric_only=True) 
df762 = orders[(orders['o_totalprice'] > 88850.44) | (orders['o_shippriority'] > 0)][['o_orderkey','o_totalprice','o_clerk','o_shippriority']].groupby(by=['o_shippriority']).agg('max',numeric_only=True) 
df763 = orders[(orders['o_totalprice'] == 439561.11) | (orders['o_shippriority'] == 0)][['o_orderstatus','o_totalprice','o_orderdate','o_orderpriority','o_clerk']].groupby(by=['o_orderdate']).agg('mean',numeric_only=True) 
df764 = orders[(orders['o_totalprice'] >= 280653.1) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_clerk','o_shippriority','o_comment']].groupby(by=['o_orderkey']).agg('mean',numeric_only=True) 
df765 = orders[(orders['o_totalprice'] == 283518.04) & (orders['o_shippriority'] == 0)][['o_orderstatus','o_orderdate','o_orderpriority','o_clerk','o_shippriority','o_comment']].groupby(by=['o_clerk']).agg('max',numeric_only=True) 
df766 = orders[(orders['o_totalprice'] <= 263506.38) & (orders['o_shippriority'] <= 0)][['o_custkey','o_totalprice','o_clerk','o_shippriority','o_comment']].groupby(by=['o_shippriority']).agg('mean',numeric_only=True) 
df767 = orders[(orders['o_totalprice'] > 88850.44) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_shippriority','o_comment']].groupby(by=['o_shippriority']).agg('max',numeric_only=True) 
df768 = orders[(orders['o_totalprice'] < 241406.33) & (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderpriority','o_comment']].groupby(by=['o_orderkey']).agg('max',numeric_only=True) 
df769 = orders[(orders['o_totalprice'] < 263026.51) & (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderpriority','o_shippriority']].groupby(by=['o_orderpriority']).agg('max',numeric_only=True) 
df770 = orders[(orders['o_totalprice'] > 141318.41) | (orders['o_shippriority'] > 200)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_comment']].groupby(by=['o_orderkey']).agg('min',numeric_only=True) 
df771 = orders[(orders['o_totalprice'] <= 174128.66) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True) 
df772 = orders[(orders['o_totalprice'] < 367414.93) & (orders['o_shippriority'] < 0)][['o_custkey','o_orderstatus','o_totalprice','o_orderdate','o_orderpriority']].groupby(by=['o_custkey']).agg('min',numeric_only=True) 
df773 = orders[(orders['o_totalprice'] > 282915.12) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderdate','o_clerk','o_comment']].groupby(by=['o_clerk']).agg('max',numeric_only=True) 
df774 = orders[(orders['o_totalprice'] >= 69483.51) & (orders['o_shippriority'] >= 0)][['o_custkey','o_totalprice','o_clerk','o_comment']].groupby(by=['o_custkey']).agg('max',numeric_only=True) 
df775 = orders[(orders['o_totalprice'] < 227921.15) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderdate','o_orderpriority','o_shippriority']].groupby(by=['o_orderpriority']).agg('max',numeric_only=True) 
df776 = orders[(orders['o_totalprice'] <= 302784.5) & (orders['o_shippriority'] <= 0)][['o_orderstatus','o_totalprice','o_orderpriority','o_clerk','o_comment']].groupby(by=['o_orderstatus']).agg('max',numeric_only=True) 
df777 = orders[(orders['o_totalprice'] < 263026.51) & (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderdate','o_orderpriority','o_shippriority']].groupby(by=['o_shippriority']).agg('mean',numeric_only=True) 
df778 = orders[(orders['o_totalprice'] == 318204.76) & (orders['o_shippriority'] == 200)][['o_custkey','o_orderstatus','o_totalprice','o_orderdate','o_comment']].groupby(by=['o_totalprice']).agg('min',numeric_only=True) 
df779 = orders[(orders['o_totalprice'] >= 197390.85) | (orders['o_shippriority'] >= 0)][['o_custkey','o_orderstatus','o_totalprice','o_clerk','o_comment']].groupby(by=['o_custkey']).agg('max',numeric_only=True) 
df780 = orders[(orders['o_totalprice'] == 248143.54) & (orders['o_shippriority'] == 0)][['o_orderkey','o_totalprice','o_shippriority','o_comment']].groupby(by=['o_shippriority']).agg('mean',numeric_only=True) 
df781 = orders[(orders['o_totalprice'] > 191113.01) & (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_totalprice','o_shippriority','o_comment']].groupby(by=['o_custkey']).agg('max',numeric_only=True) 
df782 = orders[(orders['o_totalprice'] == 248143.54) & (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].groupby(by=['o_orderpriority']).agg('max',numeric_only=True) 
df783 = orders[(orders['o_totalprice'] < 263026.51) & (orders['o_shippriority'] < 0)][['o_orderstatus','o_totalprice','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_clerk']).agg('max',numeric_only=True) 
df784 = orders[(orders['o_totalprice'] > 247783.17) | (orders['o_shippriority'] > 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk']].groupby(by=['o_orderkey']).agg('mean',numeric_only=True) 
df785 = orders[(orders['o_totalprice'] < 340916.31) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].groupby(by=['o_comment']).agg('max',numeric_only=True) 
df786 = orders[(orders['o_totalprice'] > 194852.79) & (orders['o_shippriority'] > 0)][['o_custkey','o_totalprice','o_orderdate','o_clerk','o_comment']].groupby(by=['o_totalprice']).agg('mean',numeric_only=True) 
df787 = orders[(orders['o_totalprice'] > 88850.44) & (orders['o_shippriority'] > 0)][['o_custkey','o_totalprice','o_orderdate','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_clerk']).agg('min',numeric_only=True) 
df788 = orders[(orders['o_totalprice'] <= 302784.5) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_orderpriority','o_shippriority','o_comment']].groupby(by=['o_totalprice']).agg('mean',numeric_only=True) 
df789 = orders[(orders['o_totalprice'] >= 69483.51) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_comment']].groupby(by=['o_comment']).agg('mean',numeric_only=True) 
df790 = orders[(orders['o_totalprice'] < 501062.05) & (orders['o_shippriority'] < 0)][['o_custkey','o_orderstatus','o_shippriority','o_comment']].groupby(by=['o_shippriority']).agg('mean',numeric_only=True) 
df791 = orders[(orders['o_totalprice'] < 263026.51) & (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk']].groupby(by=['o_clerk']).agg('mean',numeric_only=True) 
df792 = orders[(orders['o_totalprice'] >= 69483.51) | (orders['o_shippriority'] >= 0)][['o_custkey','o_orderstatus','o_totalprice','o_clerk','o_shippriority']].groupby(by=['o_totalprice']).agg('min',numeric_only=True) 
df793 = orders[(orders['o_totalprice'] == 354852.91) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_shippriority']].groupby(by=['o_orderkey']).agg('max',numeric_only=True) 
df794 = orders[(orders['o_totalprice'] > 194852.79) & (orders['o_shippriority'] > 0)][['o_custkey','o_orderstatus','o_totalprice','o_clerk','o_shippriority']].groupby(by=['o_shippriority']).agg('mean',numeric_only=True) 
df795 = orders[(orders['o_totalprice'] > 282915.12) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderdate','o_clerk','o_shippriority','o_comment']].groupby(by=['o_orderkey']).agg('mean',numeric_only=True) 
df796 = orders[(orders['o_totalprice'] == 318204.76) & (orders['o_shippriority'] == 200)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].groupby(by=['o_clerk']).agg('mean',numeric_only=True) 
df797 = orders[(orders['o_totalprice'] < 501062.05) & (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderdate','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('mean',numeric_only=True) 
df798 = orders[(orders['o_totalprice'] < 501062.05) & (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_orderpriority']).agg('max',numeric_only=True) 
df799 = orders[(orders['o_totalprice'] >= 67868.03) & (orders['o_shippriority'] >= 200)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderdate','o_comment']].groupby(by=['o_orderstatus']).agg('mean',numeric_only=True) 
df800 = supplier[(supplier['s_nationkey'] > 201) | (supplier['s_acctbal'] > 2001)][['s_suppkey','s_name','s_nationkey','s_phone']] 
df801 = supplier[(supplier['s_nationkey'] == 35) & (supplier['s_acctbal'] == 10423)][['s_suppkey','s_name','s_acctbal','s_comment']] 
df802 = supplier[(supplier['s_nationkey'] < 24) & (supplier['s_acctbal'] < 9340)][['s_acctbal','s_comment']] 
df803 = supplier[(supplier['s_nationkey'] < 215) | (supplier['s_acctbal'] < 4904)][['s_address','s_phone']] 
df804 = supplier[(supplier['s_nationkey'] <= 32) | (supplier['s_acctbal'] <= 16428)][['s_nationkey','s_comment']] 
df805 = supplier[(supplier['s_nationkey'] < 17) | (supplier['s_acctbal'] < 13567)][['s_phone','s_comment']] 
df806 = supplier[(supplier['s_nationkey'] >= 200) | (supplier['s_acctbal'] >= 1360)][['s_name','s_nationkey','s_comment']] 
df807 = supplier[(supplier['s_nationkey'] == 15) | (supplier['s_acctbal'] == 9587)][['s_suppkey','s_name','s_nationkey','s_acctbal']] 
df808 = supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 5449)][['s_suppkey','s_name','s_address','s_nationkey']] 
df809 = supplier[(supplier['s_nationkey'] < 215) | (supplier['s_acctbal'] < 4904)][['s_name','s_nationkey','s_phone','s_comment']] 
df810 = supplier[(supplier['s_nationkey'] == 215) | (supplier['s_acctbal'] == 8107)][['s_suppkey','s_nationkey','s_phone','s_comment']] 
df811 = supplier[(supplier['s_nationkey'] < 11) | (supplier['s_acctbal'] < 8421)][['s_address','s_nationkey','s_acctbal']] 
df812 = supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 4491)][['s_name','s_phone','s_acctbal','s_comment']] 
df813 = supplier[(supplier['s_nationkey'] == 15) | (supplier['s_acctbal'] == 9587)][['s_suppkey','s_nationkey','s_phone','s_comment']] 
df814 = supplier[(supplier['s_nationkey'] == 17) | (supplier['s_acctbal'] == 15834)][['s_address','s_nationkey','s_comment']] 
df815 = supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 16428)][['s_name','s_nationkey','s_phone','s_comment']] 
df816 = supplier[(supplier['s_nationkey'] == 17) | (supplier['s_acctbal'] == 15834)][['s_nationkey','s_phone','s_acctbal','s_comment']] 
df817 = supplier[(supplier['s_nationkey'] < 34) | (supplier['s_acctbal'] < 10312)][['s_acctbal','s_comment']] 
df818 = supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 16428)][['s_name','s_phone']] 
df819 = supplier[(supplier['s_nationkey'] >= 14) & (supplier['s_acctbal'] >= 2343)][['s_suppkey','s_name','s_comment']] 
df820 = supplier[(supplier['s_nationkey'] > 18) & (supplier['s_acctbal'] > 2638)][['s_suppkey','s_name','s_comment']] 
df821 = supplier[(supplier['s_nationkey'] >= 11) | (supplier['s_acctbal'] >= 6112)][['s_name','s_phone','s_acctbal']] 
df822 = supplier[(supplier['s_nationkey'] == 15) | (supplier['s_acctbal'] == 9587)][['s_name','s_phone','s_acctbal','s_comment']] 
df823 = supplier[(supplier['s_nationkey'] <= 32) | (supplier['s_acctbal'] <= 16428)][['s_phone','s_acctbal','s_comment']] 
df824 = supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 9803)][['s_name','s_address','s_phone','s_comment']] 
df825 = supplier[(supplier['s_nationkey'] > 11) & (supplier['s_acctbal'] > 8843)][['s_suppkey','s_address','s_acctbal','s_comment']] 
df826 = supplier[(supplier['s_nationkey'] >= 200) | (supplier['s_acctbal'] >= 1360)][['s_suppkey','s_comment']] 
df827 = supplier[(supplier['s_nationkey'] >= 11) | (supplier['s_acctbal'] >= 6112)][['s_phone','s_comment']] 
df828 = supplier[(supplier['s_nationkey'] >= 2) | (supplier['s_acctbal'] >= 1619)][['s_suppkey','s_nationkey','s_acctbal','s_comment']] 
df829 = supplier[(supplier['s_nationkey'] < 11) | (supplier['s_acctbal'] < 8421)][['s_phone','s_acctbal','s_comment']] 
df830 = supplier[(supplier['s_nationkey'] >= 25) | (supplier['s_acctbal'] >= 9132)][['s_suppkey','s_acctbal','s_comment']] 
df831 = supplier[(supplier['s_nationkey'] >= 2) | (supplier['s_acctbal'] >= 1619)][['s_name','s_nationkey','s_phone']] 
df832 = supplier[(supplier['s_nationkey'] < 17) | (supplier['s_acctbal'] < 13567)][['s_name','s_comment']] 
df833 = supplier[(supplier['s_nationkey'] > 25) | (supplier['s_acctbal'] > 11035)][['s_suppkey','s_address','s_nationkey','s_phone']] 
df834 = supplier[(supplier['s_nationkey'] >= 25) | (supplier['s_acctbal'] >= 9132)][['s_name','s_address','s_phone']] 
df835 = supplier[(supplier['s_nationkey'] >= 2) & (supplier['s_acctbal'] >= 1619)][['s_name','s_address']] 
df836 = supplier[(supplier['s_nationkey'] == 35) & (supplier['s_acctbal'] == 10423)][['s_suppkey','s_name','s_address','s_nationkey']] 
df837 = supplier[(supplier['s_nationkey'] == 17) | (supplier['s_acctbal'] == 15834)][['s_suppkey','s_phone','s_acctbal']] 
df838 = supplier[(supplier['s_nationkey'] <= 19) | (supplier['s_acctbal'] <= 8621)][['s_name','s_address','s_acctbal','s_comment']] 
df839 = supplier[(supplier['s_nationkey'] == 15) | (supplier['s_acctbal'] == 9587)][['s_address','s_phone']] 
df840 = supplier[(supplier['s_nationkey'] == 215) | (supplier['s_acctbal'] == 8107)][['s_suppkey','s_address','s_nationkey','s_acctbal']] 
df841 = supplier[(supplier['s_nationkey'] > 11) & (supplier['s_acctbal'] > 8843)][['s_name','s_nationkey','s_acctbal']] 
df842 = supplier[(supplier['s_nationkey'] > 11) & (supplier['s_acctbal'] > 8843)][['s_suppkey','s_phone','s_comment']] 
df843 = supplier[(supplier['s_nationkey'] < 34) | (supplier['s_acctbal'] < 10312)][['s_name','s_address','s_comment']] 
df844 = supplier[(supplier['s_nationkey'] <= 32) | (supplier['s_acctbal'] <= 16428)][['s_suppkey','s_name','s_address','s_acctbal']] 
df845 = supplier[(supplier['s_nationkey'] < 25) | (supplier['s_acctbal'] < 6176)][['s_name','s_address','s_acctbal','s_comment']] 
df846 = supplier[(supplier['s_nationkey'] == 27) | (supplier['s_acctbal'] == 10757)][['s_suppkey','s_name','s_address','s_phone']] 
df847 = supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 16428)][['s_name','s_address','s_acctbal']] 
df848 = supplier[(supplier['s_nationkey'] > 18) & (supplier['s_acctbal'] > 2638)][['s_suppkey','s_nationkey','s_acctbal','s_comment']] 
df849 = supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 4491)][['s_suppkey','s_nationkey','s_comment']] 
df850 = supplier[(supplier['s_nationkey'] < 34) | (supplier['s_acctbal'] < 10312)][['s_name','s_address','s_nationkey','s_phone']] 
df851 = supplier[(supplier['s_nationkey'] == 32) | (supplier['s_acctbal'] == 6803)][['s_address','s_nationkey']] 
df852 = supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 4085)][['s_suppkey','s_nationkey','s_phone','s_acctbal']] 
df853 = supplier[(supplier['s_nationkey'] > 19) & (supplier['s_acctbal'] > 5499)][['s_address','s_nationkey','s_phone','s_comment']] 
df854 = supplier[(supplier['s_nationkey'] >= 28) & (supplier['s_acctbal'] >= 11927)][['s_suppkey','s_address','s_phone','s_comment']] 
df855 = supplier[(supplier['s_nationkey'] == 17) | (supplier['s_acctbal'] == 15834)][['s_name','s_nationkey']] 
df856 = supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 7174)][['s_nationkey','s_acctbal']] 
df857 = supplier[(supplier['s_nationkey'] > 31) | (supplier['s_acctbal'] > 15039)][['s_acctbal','s_comment']] 
df858 = supplier[(supplier['s_nationkey'] == 32) | (supplier['s_acctbal'] == 6803)][['s_suppkey','s_name']] 
df859 = supplier[(supplier['s_nationkey'] == 27) | (supplier['s_acctbal'] == 10757)][['s_name','s_nationkey','s_phone','s_comment']] 
df860 = supplier[(supplier['s_nationkey'] == 15) | (supplier['s_acctbal'] == 9587)][['s_suppkey','s_comment']] 
df861 = supplier[(supplier['s_nationkey'] < 34) | (supplier['s_acctbal'] < 10312)][['s_address','s_phone','s_comment']] 
df862 = supplier[(supplier['s_nationkey'] >= 2) & (supplier['s_acctbal'] >= 1619)][['s_address','s_phone','s_comment']] 
df863 = supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 4085)][['s_suppkey','s_address','s_nationkey','s_acctbal']] 
df864 = supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 16428)][['s_suppkey','s_nationkey','s_comment']] 
df865 = supplier[(supplier['s_nationkey'] == 215) | (supplier['s_acctbal'] == 8107)][['s_name','s_address','s_nationkey','s_comment']] 
df866 = supplier[(supplier['s_nationkey'] == 32) | (supplier['s_acctbal'] == 6803)][['s_suppkey','s_phone']] 
df867 = supplier[(supplier['s_nationkey'] == 15) | (supplier['s_acctbal'] == 9587)][['s_suppkey','s_nationkey','s_phone','s_acctbal']] 
df868 = supplier[(supplier['s_nationkey'] >= 28) & (supplier['s_acctbal'] >= 11927)][['s_suppkey','s_nationkey','s_phone','s_acctbal']] 
df869 = supplier[(supplier['s_nationkey'] <= 208) & (supplier['s_acctbal'] <= 2374)][['s_address','s_nationkey','s_phone','s_comment']] 
df870 = supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 7174)][['s_suppkey','s_nationkey','s_acctbal']] 
df871 = supplier[(supplier['s_nationkey'] < 34) | (supplier['s_acctbal'] < 10312)][['s_nationkey','s_phone']] 
df872 = supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 7174)][['s_name','s_address','s_comment']] 
df873 = supplier[(supplier['s_nationkey'] > 18) & (supplier['s_acctbal'] > 2638)][['s_suppkey','s_acctbal','s_comment']] 
df874 = supplier[(supplier['s_nationkey'] >= 25) | (supplier['s_acctbal'] >= 9132)][['s_suppkey','s_address','s_acctbal']] 
df875 = supplier[(supplier['s_nationkey'] > 11) & (supplier['s_acctbal'] > 8843)][['s_name','s_acctbal','s_comment']] 
df876 = supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 4085)][['s_address','s_phone','s_acctbal','s_comment']] 
df877 = supplier[(supplier['s_nationkey'] >= 14) & (supplier['s_acctbal'] >= 2343)][['s_suppkey','s_acctbal']] 
df878 = supplier[(supplier['s_nationkey'] <= 32) | (supplier['s_acctbal'] <= 16428)][['s_suppkey','s_name','s_nationkey','s_phone']] 
df879 = supplier[(supplier['s_nationkey'] >= 28) | (supplier['s_acctbal'] >= 11927)][['s_name','s_phone','s_acctbal']] 
df880 = supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 15168)][['s_nationkey','s_phone']] 
df881 = supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 5449)][['s_address','s_nationkey','s_acctbal','s_comment']] 
df882 = supplier[(supplier['s_nationkey'] > 25) | (supplier['s_acctbal'] > 11035)][['s_suppkey','s_address','s_acctbal','s_comment']] 
df883 = supplier[(supplier['s_nationkey'] < 25) | (supplier['s_acctbal'] < 6176)][['s_suppkey','s_name','s_address','s_comment']] 
df884 = supplier[(supplier['s_nationkey'] < 215) | (supplier['s_acctbal'] < 4904)][['s_suppkey','s_comment']] 
df885 = supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 5449)][['s_name','s_phone','s_comment']] 
df886 = supplier[(supplier['s_nationkey'] > 18) & (supplier['s_acctbal'] > 2638)][['s_name','s_address','s_phone','s_comment']] 
df887 = supplier[(supplier['s_nationkey'] >= 200) | (supplier['s_acctbal'] >= 1360)][['s_suppkey','s_nationkey','s_phone']] 
df888 = supplier[(supplier['s_nationkey'] > 31) | (supplier['s_acctbal'] > 15039)][['s_nationkey','s_phone','s_comment']] 
df889 = supplier[(supplier['s_nationkey'] <= 15) & (supplier['s_acctbal'] <= 10936)][['s_name','s_address','s_nationkey','s_acctbal']] 
df890 = supplier[(supplier['s_nationkey'] >= 2) | (supplier['s_acctbal'] >= 1619)][['s_suppkey','s_nationkey','s_phone']] 
df891 = supplier[(supplier['s_nationkey'] > 31) | (supplier['s_acctbal'] > 15039)][['s_suppkey','s_address','s_phone','s_comment']] 
df892 = supplier[(supplier['s_nationkey'] < 34) | (supplier['s_acctbal'] < 17471)][['s_suppkey','s_name','s_address','s_acctbal']] 
df893 = supplier[(supplier['s_nationkey'] >= 2) & (supplier['s_acctbal'] >= 1619)][['s_suppkey','s_name','s_phone']] 
df894 = supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 15168)][['s_suppkey','s_address','s_acctbal']] 
df895 = supplier[(supplier['s_nationkey'] >= 11) | (supplier['s_acctbal'] >= 6112)][['s_suppkey','s_nationkey','s_phone','s_acctbal']] 
df896 = supplier[(supplier['s_nationkey'] == 15) | (supplier['s_acctbal'] == 9587)][['s_suppkey','s_name','s_address']] 
df897 = supplier[(supplier['s_nationkey'] >= 25) | (supplier['s_acctbal'] >= 9132)][['s_suppkey','s_nationkey','s_phone','s_acctbal']] 
df898 = supplier[(supplier['s_nationkey'] > 18) & (supplier['s_acctbal'] > 2638)][['s_suppkey','s_phone','s_acctbal']] 
df899 = supplier[(supplier['s_nationkey'] > 201) | (supplier['s_acctbal'] > 2001)][['s_address','s_nationkey']] 
df900 = supplier[(supplier['s_nationkey'] >= 19) & (supplier['s_acctbal'] >= 7456)] 
df901 = supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11004)] 
df902 = supplier[(supplier['s_nationkey'] <= 31) | (supplier['s_acctbal'] <= 13693)] 
df903 = supplier[(supplier['s_nationkey'] > 27) & (supplier['s_acctbal'] > 12209)] 
df904 = supplier[(supplier['s_nationkey'] < 208) & (supplier['s_acctbal'] < 8265)] 
df905 = supplier[(supplier['s_nationkey'] > 27) | (supplier['s_acctbal'] > 12209)] 
df906 = supplier[(supplier['s_nationkey'] < 33) | (supplier['s_acctbal'] < 14989)] 
df907 = supplier[(supplier['s_nationkey'] == 9) & (supplier['s_acctbal'] == 8929)] 
df908 = supplier[(supplier['s_nationkey'] == 30) | (supplier['s_acctbal'] == 15135)] 
df909 = supplier[(supplier['s_nationkey'] < 30) & (supplier['s_acctbal'] < 10928)] 
df910 = supplier[(supplier['s_nationkey'] < 33) & (supplier['s_acctbal'] < 14989)] 
df911 = supplier[(supplier['s_nationkey'] >= 16) & (supplier['s_acctbal'] >= 4958)] 
df912 = supplier[(supplier['s_nationkey'] >= 8) & (supplier['s_acctbal'] >= 1493)] 
df913 = supplier[(supplier['s_nationkey'] <= 14) | (supplier['s_acctbal'] <= 10032)] 
df914 = supplier[(supplier['s_nationkey'] >= 27) | (supplier['s_acctbal'] >= 10736)] 
df915 = supplier[(supplier['s_nationkey'] < 9) | (supplier['s_acctbal'] < 8807)] 
df916 = supplier[(supplier['s_nationkey'] < 9) | (supplier['s_acctbal'] < 8807)] 
df917 = supplier[(supplier['s_nationkey'] > 9) | (supplier['s_acctbal'] > 4720)] 
df918 = supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 13504)] 
df919 = supplier[(supplier['s_nationkey'] > 25) | (supplier['s_acctbal'] > 10796)] 
df920 = supplier[(supplier['s_nationkey'] < 27) & (supplier['s_acctbal'] < 14239)] 
df921 = supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11435)] 
df922 = supplier[(supplier['s_nationkey'] > 25) & (supplier['s_acctbal'] > 8728)] 
df923 = supplier[(supplier['s_nationkey'] >= 27) & (supplier['s_acctbal'] >= 10736)] 
df924 = supplier[(supplier['s_nationkey'] <= 6) | (supplier['s_acctbal'] <= 6215)] 
df925 = supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 13819)] 
df926 = supplier[(supplier['s_nationkey'] <= 6) | (supplier['s_acctbal'] <= 6215)] 
df927 = supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 7665)] 
df928 = supplier[(supplier['s_nationkey'] >= 8) | (supplier['s_acctbal'] >= 5863)] 
df929 = supplier[(supplier['s_nationkey'] == 33) & (supplier['s_acctbal'] == 15995)] 
df930 = supplier[(supplier['s_nationkey'] >= 21) & (supplier['s_acctbal'] >= 9519)] 
df931 = supplier[(supplier['s_nationkey'] < 14) & (supplier['s_acctbal'] < 9269)] 
df932 = supplier[(supplier['s_nationkey'] <= 23) & (supplier['s_acctbal'] <= 9288)] 
df933 = supplier[(supplier['s_nationkey'] > 204) & (supplier['s_acctbal'] > 4632)] 
df934 = supplier[(supplier['s_nationkey'] > 6) & (supplier['s_acctbal'] > 3351)] 
df935 = supplier[(supplier['s_nationkey'] == 41) & (supplier['s_acctbal'] == 16428)] 
df936 = supplier[(supplier['s_nationkey'] == 19) | (supplier['s_acctbal'] == 9826)] 
df937 = supplier[(supplier['s_nationkey'] <= 205) | (supplier['s_acctbal'] <= 6359)] 
df938 = supplier[(supplier['s_nationkey'] >= 202) | (supplier['s_acctbal'] >= 2606)] 
df939 = supplier[(supplier['s_nationkey'] == 27) & (supplier['s_acctbal'] == 11273)] 
df940 = supplier[(supplier['s_nationkey'] >= 4) | (supplier['s_acctbal'] >= 535)] 
df941 = supplier[(supplier['s_nationkey'] >= 4) | (supplier['s_acctbal'] >= 535)] 
df942 = supplier[(supplier['s_nationkey'] == 37) | (supplier['s_acctbal'] == 12786)] 
df943 = supplier[(supplier['s_nationkey'] >= 4) & (supplier['s_acctbal'] >= 535)] 
df944 = supplier[(supplier['s_nationkey'] <= 31) | (supplier['s_acctbal'] <= 13693)] 
df945 = supplier[(supplier['s_nationkey'] == 208) | (supplier['s_acctbal'] == 11163)] 
df946 = supplier[(supplier['s_nationkey'] > 6) & (supplier['s_acctbal'] > 3351)] 
df947 = supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 8850)] 
df948 = supplier[(supplier['s_nationkey'] > 23) | (supplier['s_acctbal'] > 7372)] 
df949 = supplier[(supplier['s_nationkey'] == 9) | (supplier['s_acctbal'] == 8929)] 
df950 = part[part['p_retailprice'] < 1156] 
df951 = part[part['p_retailprice'] <= 959] 
df952 = part[part['p_retailprice'] >= 933] 
df953 = part[part['p_retailprice'] == 1172] 
df954 = part[part['p_retailprice'] <= 1215] 
df955 = part[part['p_retailprice'] <= 1110] 
df956 = part[part['p_retailprice'] >= 1056] 
df957 = part[part['p_retailprice'] >= 93] 
df958 = part[part['p_retailprice'] <= 1215] 
df959 = part[part['p_retailprice'] > 938] 
df960 = part[part['p_retailprice'] > 1198] 
df961 = part[part['p_retailprice'] >= 1093] 
df962 = part[part['p_retailprice'] > 986] 
df963 = part[part['p_retailprice'] == 1158] 
df964 = part[part['p_retailprice'] > 127] 
df965 = part[part['p_retailprice'] > 1198] 
df966 = part[part['p_retailprice'] < 1236] 
df967 = part[part['p_retailprice'] >= 933] 
df968 = part[part['p_retailprice'] <= 1154] 
df969 = part[part['p_retailprice'] < 1039] 
df970 = part[part['p_retailprice'] < 1129] 
df971 = part[part['p_retailprice'] >= 933] 
df972 = part[part['p_retailprice'] <= 316] 
df973 = part[part['p_retailprice'] >= 1150] 
df974 = part[part['p_retailprice'] > 1097] 
df975 = part[part['p_retailprice'] == 1236] 
df976 = part[part['p_retailprice'] < 1236] 
df977 = part[part['p_retailprice'] == 1156] 
df978 = part[part['p_retailprice'] < 1155] 
df979 = part[part['p_retailprice'] >= 216] 
df980 = part[part['p_retailprice'] >= 1046] 
df981 = part[part['p_retailprice'] > 938] 
df982 = part[part['p_retailprice'] <= 959] 
df983 = part[part['p_retailprice'] == 979] 
df984 = part[part['p_retailprice'] >= 1150] 
df985 = part[part['p_retailprice'] > 1101] 
df986 = part[part['p_retailprice'] < 968] 
df987 = part[part['p_retailprice'] <= 145] 
df988 = part[part['p_retailprice'] > 264] 
df989 = part[part['p_retailprice'] < 339] 
df990 = part[part['p_retailprice'] == 1090] 
df991 = part[part['p_retailprice'] == 366] 
df992 = part[part['p_retailprice'] == 211] 
df993 = part[part['p_retailprice'] <= 1033] 
df994 = part[part['p_retailprice'] >= 986] 
df995 = part[part['p_retailprice'] == 979] 
df996 = part[part['p_retailprice'] > 1089] 
df997 = part[part['p_retailprice'] < 198] 
df998 = part[part['p_retailprice'] <= 1106] 
df999 = part[part['p_retailprice'] < 968] 
df1000 = partsupp[partsupp['ps_supplycost'] < 821] 
df1001 = partsupp[partsupp['ps_supplycost'] == 778] 
df1002 = partsupp[partsupp['ps_supplycost'] < 789] 
df1003 = partsupp[partsupp['ps_supplycost'] > 530] 
df1004 = partsupp[partsupp['ps_supplycost'] > 1212] 
df1005 = partsupp[partsupp['ps_supplycost'] <= 1388] 
df1006 = partsupp[partsupp['ps_supplycost'] == 813] 
df1007 = partsupp[partsupp['ps_supplycost'] == 1177] 
df1008 = partsupp[partsupp['ps_supplycost'] < 1393] 
df1009 = partsupp[partsupp['ps_supplycost'] < 1569] 
df1010 = partsupp[partsupp['ps_supplycost'] < 1037] 
df1011 = partsupp[partsupp['ps_supplycost'] < 789] 
df1012 = partsupp[partsupp['ps_supplycost'] <= 549] 
df1013 = partsupp[partsupp['ps_supplycost'] <= 1386] 
df1014 = partsupp[partsupp['ps_supplycost'] == 1399] 
df1015 = partsupp[partsupp['ps_supplycost'] >= 699] 
df1016 = partsupp[partsupp['ps_supplycost'] < 1169] 
df1017 = partsupp[partsupp['ps_supplycost'] <= 732] 
df1018 = partsupp[partsupp['ps_supplycost'] > 1212] 
df1019 = partsupp[partsupp['ps_supplycost'] == 813] 
df1020 = partsupp[partsupp['ps_supplycost'] > 805] 
df1021 = partsupp[partsupp['ps_supplycost'] == 1713] 
df1022 = partsupp[partsupp['ps_supplycost'] >= 537] 
df1023 = partsupp[partsupp['ps_supplycost'] <= 1129] 
df1024 = partsupp[partsupp['ps_supplycost'] > 725] 
df1025 = partsupp[partsupp['ps_supplycost'] >= 1049] 
df1026 = partsupp[partsupp['ps_supplycost'] > 530] 
df1027 = partsupp[partsupp['ps_supplycost'] < 616] 
df1028 = partsupp[partsupp['ps_supplycost'] <= 1388] 
df1029 = partsupp[partsupp['ps_supplycost'] >= 361] 
df1030 = partsupp[partsupp['ps_supplycost'] == 1069] 
df1031 = partsupp[partsupp['ps_supplycost'] == 823] 
df1032 = partsupp[partsupp['ps_supplycost'] >= 1017] 
df1033 = partsupp[partsupp['ps_supplycost'] > 1295] 
df1034 = partsupp[partsupp['ps_supplycost'] <= 1002] 
df1035 = partsupp[partsupp['ps_supplycost'] < 1059] 
df1036 = partsupp[partsupp['ps_supplycost'] <= 701] 
df1037 = partsupp[partsupp['ps_supplycost'] < 1569] 
df1038 = partsupp[partsupp['ps_supplycost'] >= 1049] 
df1039 = partsupp[partsupp['ps_supplycost'] >= 671] 
df1040 = partsupp[partsupp['ps_supplycost'] <= 732] 
df1041 = partsupp[partsupp['ps_supplycost'] >= 252] 
df1042 = partsupp[partsupp['ps_supplycost'] > 543] 
df1043 = partsupp[partsupp['ps_supplycost'] >= 252] 
df1044 = partsupp[partsupp['ps_supplycost'] == 1120] 
df1045 = partsupp[partsupp['ps_supplycost'] >= 252] 
df1046 = partsupp[partsupp['ps_supplycost'] > 563] 
df1047 = partsupp[partsupp['ps_supplycost'] <= 811] 
df1048 = partsupp[partsupp['ps_supplycost'] > 882] 
df1049 = partsupp[partsupp['ps_supplycost'] >= 260]

# %%
df0 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey') 
df1 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='ps_suppkey', right_on='s_suppkey') 
df2 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1003],left_on='ps_partkey', right_on='p_partkey') 
df3 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey') 
df4 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey') 
df5 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey') 
df6 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1063],left_on='ps_partkey', right_on='p_partkey') 
df7 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df8 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1059],left_on='ps_partkey', right_on='p_partkey') 
df9 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df10 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df11 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df12 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey') 
df13 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey') 
df14 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey') 
df15 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] > 132],left_on='ps_partkey', right_on='p_partkey') 
df16 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey') 
df17 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey') 
df18 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey') 
df19 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='ps_suppkey', right_on='s_suppkey') 
df20 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey') 
df21 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df22 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df23 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1175],left_on='ps_partkey', right_on='p_partkey') 
df24 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] >= 251],left_on='ps_partkey', right_on='p_partkey') 
df25 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey') 
df26 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df27 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey') 
df28 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df29 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1161],left_on='ps_partkey', right_on='p_partkey') 
df30 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey') 
df31 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey') 
df32 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1003],left_on='ps_partkey', right_on='p_partkey') 
df33 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey') 
df34 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] == 24) | (supplier['s_acctbal'] == 10802)],left_on='ps_suppkey', right_on='s_suppkey') 
df35 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df36 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey') 
df37 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df38 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey') 
df39 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey') 
df40 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df41 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df42 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1209],left_on='ps_partkey', right_on='p_partkey') 
df43 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1025],left_on='ps_partkey', right_on='p_partkey') 
df44 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey') 
df45 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 20) & (supplier['s_acctbal'] > 7359)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df46 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] == 14) | (supplier['s_acctbal'] == 8535)],left_on='ps_suppkey', right_on='s_suppkey') 
df47 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey') 
df48 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='ps_suppkey', right_on='s_suppkey') 
df49 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df50 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df51 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey') 
df52 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey') 
df53 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey') 
df54 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] >= 90],left_on='ps_partkey', right_on='p_partkey') 
df55 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey') 
df56 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1209],left_on='ps_partkey', right_on='p_partkey') 
df57 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df58 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df59 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] > 291],left_on='ps_partkey', right_on='p_partkey') 
df60 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df61 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1134],left_on='ps_partkey', right_on='p_partkey') 
df62 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey') 
df63 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1025],left_on='ps_partkey', right_on='p_partkey') 
df64 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df65 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey') 
df66 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey') 
df67 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey') 
df68 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df69 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1159],left_on='ps_partkey', right_on='p_partkey') 
df70 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='ps_suppkey', right_on='s_suppkey') 
df71 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey') 
df72 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df73 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey') 
df74 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df75 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey') 
df76 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey') 
df77 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1175],left_on='ps_partkey', right_on='p_partkey') 
df78 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df79 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df80 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey') 
df81 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 24) | (supplier['s_acctbal'] >= 13148)],left_on='ps_suppkey', right_on='s_suppkey') 
df82 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df83 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1115],left_on='ps_partkey', right_on='p_partkey') 
df84 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey') 
df85 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey') 
df86 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df87 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey') 
df88 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='ps_suppkey', right_on='s_suppkey') 
df89 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1105],left_on='ps_partkey', right_on='p_partkey') 
df90 = partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1040],left_on='ps_partkey', right_on='p_partkey') 
df91 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey') 
df92 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey') 
df93 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df94 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey') 
df95 = partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey') 
df96 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey') 
df97 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='ps_suppkey', right_on='s_suppkey') 
df98 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1003],left_on='ps_partkey', right_on='p_partkey') 
df99 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey') 
df100 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey') 
df101 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey') 
df102 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1063],left_on='ps_partkey', right_on='p_partkey') 
df103 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df104 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1059],left_on='ps_partkey', right_on='p_partkey') 
df105 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df106 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df107 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df108 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey') 
df109 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey') 
df110 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey') 
df111 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] > 132],left_on='ps_partkey', right_on='p_partkey') 
df112 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey') 
df113 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey') 
df114 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey') 
df115 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='ps_suppkey', right_on='s_suppkey') 
df116 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey') 
df117 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df118 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df119 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1175],left_on='ps_partkey', right_on='p_partkey') 
df120 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] >= 251],left_on='ps_partkey', right_on='p_partkey') 
df121 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey') 
df122 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df123 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey') 
df124 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df125 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1161],left_on='ps_partkey', right_on='p_partkey') 
df126 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey') 
df127 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey') 
df128 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1003],left_on='ps_partkey', right_on='p_partkey') 
df129 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey') 
df130 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] == 24) | (supplier['s_acctbal'] == 10802)],left_on='ps_suppkey', right_on='s_suppkey') 
df131 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df132 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey') 
df133 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df134 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey') 
df135 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey') 
df136 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df137 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df138 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1209],left_on='ps_partkey', right_on='p_partkey') 
df139 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1025],left_on='ps_partkey', right_on='p_partkey') 
df140 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey') 
df141 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] == 14) | (supplier['s_acctbal'] == 8535)],left_on='ps_suppkey', right_on='s_suppkey') 
df142 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey') 
df143 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='ps_suppkey', right_on='s_suppkey') 
df144 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df145 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df146 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey') 
df147 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey') 
df148 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey') 
df149 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] >= 90],left_on='ps_partkey', right_on='p_partkey') 
df150 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey') 
df151 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1209],left_on='ps_partkey', right_on='p_partkey') 
df152 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df153 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df154 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] > 291],left_on='ps_partkey', right_on='p_partkey') 
df155 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df156 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1134],left_on='ps_partkey', right_on='p_partkey') 
df157 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey') 
df158 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1025],left_on='ps_partkey', right_on='p_partkey') 
df159 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df160 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey') 
df161 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey') 
df162 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey') 
df163 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df164 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1159],left_on='ps_partkey', right_on='p_partkey') 
df165 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='ps_suppkey', right_on='s_suppkey') 
df166 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey') 
df167 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df168 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey') 
df169 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df170 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey') 
df171 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey') 
df172 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1175],left_on='ps_partkey', right_on='p_partkey') 
df173 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df174 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df175 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey') 
df176 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 24) | (supplier['s_acctbal'] >= 13148)],left_on='ps_suppkey', right_on='s_suppkey') 
df177 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df178 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1115],left_on='ps_partkey', right_on='p_partkey') 
df179 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey') 
df180 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey') 
df181 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df182 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey') 
df183 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='ps_suppkey', right_on='s_suppkey') 
df184 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1105],left_on='ps_partkey', right_on='p_partkey') 
df185 = partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1040],left_on='ps_partkey', right_on='p_partkey') 
df186 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey') 
df187 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey') 
df188 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df189 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey') 
df190 = partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey') 
df191 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df192 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df193 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df194 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)],left_on='o_orderkey', right_on='l_orderkey') 
df195 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df196 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)],left_on='o_orderkey', right_on='l_orderkey') 
df197 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey') 
df198 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)],left_on='o_orderkey', right_on='l_orderkey') 
df199 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 6231) & (lineitem['l_quantity'] < 223)],left_on='o_orderkey', right_on='l_orderkey') 
df200 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey') 
df201 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_quantity','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df202 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_quantity','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey') 
df203 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7950) & (lineitem['l_quantity'] <= 48)],left_on='o_orderkey', right_on='l_orderkey') 
df204 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 2366) | (lineitem['l_quantity'] >= 209)],left_on='o_orderkey', right_on='l_orderkey') 
df205 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 7553) & (lineitem['l_quantity'] >= 29) | (lineitem['l_discount'] >= 0.16)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df206 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_partkey','l_tax','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df207 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14355) | (lineitem['l_quantity'] < 53) & (lineitem['l_discount'] < 2.04)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df208 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey') 
df209 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df210 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_extendedprice','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df211 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6217) | (lineitem['l_quantity'] <= 46)],left_on='o_orderkey', right_on='l_orderkey') 
df212 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8840) & (lineitem['l_quantity'] < 56)],left_on='o_orderkey', right_on='l_orderkey') 
df213 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_tax','l_shipdate','l_commitdate','l_receiptdate']].groupby(by=['l_commitdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df214 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3298) & (lineitem['l_quantity'] >= 20) & (lineitem['l_discount'] >= 0.09)][['l_orderkey','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey') 
df215 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey') 
df216 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey') 
df217 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey') 
df218 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5578) & (lineitem['l_quantity'] > 21)],left_on='o_orderkey', right_on='l_orderkey') 
df219 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10453) & (lineitem['l_quantity'] < 32)],left_on='o_orderkey', right_on='l_orderkey') 
df220 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_partkey','l_linenumber','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_quantity']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df221 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_tax','l_linestatus','l_shipdate']],left_on='o_orderkey', right_on='l_orderkey') 
df222 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df223 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df224 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey') 
df225 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5114) | (lineitem['l_quantity'] < 228) | (lineitem['l_discount'] < 201.61)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df226 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8657) & (lineitem['l_quantity'] <= 29) & (lineitem['l_discount'] <= 1.14)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df227 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5348) | (lineitem['l_quantity'] > 43)],left_on='o_orderkey', right_on='l_orderkey') 
df228 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5053) & (lineitem['l_quantity'] >= 40)],left_on='o_orderkey', right_on='l_orderkey') 
df229 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) | (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df230 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8216) & (lineitem['l_quantity'] <= 24)],left_on='o_orderkey', right_on='l_orderkey') 
df231 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) & (lineitem['l_quantity'] < 35) | (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey') 
df232 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) | (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df233 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_shipmode','l_comment']].groupby(by=['l_shipmode']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df234 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df235 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey') 
df236 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey') 
df237 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_tax','l_linestatus','l_receiptdate']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df238 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 8881) & (lineitem['l_quantity'] >= 46)],left_on='o_orderkey', right_on='l_orderkey') 
df239 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14680) | (lineitem['l_quantity'] < 69)],left_on='o_orderkey', right_on='l_orderkey') 
df240 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) & (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_linenumber','l_discount','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_comment']].groupby(by=['l_shipdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df241 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 16632) | (lineitem['l_quantity'] < 75) | (lineitem['l_discount'] < 2.18)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey') 
df242 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_partkey','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df243 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_extendedprice','l_discount','l_linestatus','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df244 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 6816) & (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 1.14)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_shipdate','l_shipmode']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df245 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey') 
df246 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8259) & (lineitem['l_quantity'] < 57)],left_on='o_orderkey', right_on='l_orderkey') 
df247 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df248 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df249 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df250 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) & (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey') 
df251 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) & (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey') 
df252 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3878) | (lineitem['l_quantity'] > 38)],left_on='o_orderkey', right_on='l_orderkey') 
df253 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8614) | (lineitem['l_quantity'] < 49) & (lineitem['l_discount'] < 1.56)][['l_orderkey','l_partkey','l_linenumber','l_extendedprice','l_tax','l_linestatus']],left_on='o_orderkey', right_on='l_orderkey') 
df254 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4989) & (lineitem['l_quantity'] >= 36)],left_on='o_orderkey', right_on='l_orderkey') 
df255 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5297) & (lineitem['l_quantity'] >= 14) | (lineitem['l_discount'] >= 0.1)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_returnflag','l_linestatus','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df256 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) & (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_linenumber','l_quantity','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey') 
df257 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey') 
df258 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_partkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df259 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) | (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey') 
df260 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey') 
df261 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5884) & (lineitem['l_quantity'] <= 220)],left_on='o_orderkey', right_on='l_orderkey') 
df262 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) | (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_discount','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey') 
df263 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7547) & (lineitem['l_quantity'] < 48)],left_on='o_orderkey', right_on='l_orderkey') 
df264 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey') 
df265 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_returnflag','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df266 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df267 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df268 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5342) & (lineitem['l_quantity'] > 37)],left_on='o_orderkey', right_on='l_orderkey') 
df269 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12140) & (lineitem['l_quantity'] <= 65)],left_on='o_orderkey', right_on='l_orderkey') 
df270 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey') 
df271 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10302) | (lineitem['l_quantity'] < 40) | (lineitem['l_discount'] < 1.69)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipinstruct']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df272 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey') 
df273 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) & (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_returnflag','l_shipdate','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df274 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3813) & (lineitem['l_quantity'] <= 228) | (lineitem['l_discount'] <= 201.06)][['l_orderkey','l_partkey','l_suppkey','l_extendedprice','l_discount','l_shipdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey') 
df275 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5139) | (lineitem['l_quantity'] > 35) | (lineitem['l_discount'] > 1.13)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey') 
df276 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df277 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) | (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey') 
df278 = orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 9774) | (lineitem['l_quantity'] < 43) | (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey') 
df279 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df280 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df281 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df282 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df283 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 497048.47) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_orderdate']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df284 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df285 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_custkey','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df286 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 175118.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority']].groupby(by=['o_shippriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df287 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 281428.61) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df288 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df289 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df290 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 267744.16) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df291 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df292 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df293 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 92507.06) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df294 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 182691.78) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df295 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_orderpriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df296 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df297 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_totalprice','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df298 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_comment']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df299 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 394066.64) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df300 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df301 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df302 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df303 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 409119.08) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderdate']],left_on='l_orderkey', right_on='o_orderkey') 
df304 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 299260.59) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df305 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 155982.45) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df306 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df307 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df308 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df309 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 190341.58) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderdate','o_clerk','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df310 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 269278.52) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_totalprice','o_orderpriority','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df311 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df312 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 308518.61) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df313 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df314 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderdate','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df315 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice','o_clerk','o_comment']].groupby(by=['o_custkey']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df316 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df317 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 133060.14) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df318 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderdate','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df319 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 171953.74) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df320 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df321 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 36395.09) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('max',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df322 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df323 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df324 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df325 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df326 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df327 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df328 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df329 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df330 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df331 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df332 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df333 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 6231) & (lineitem['l_quantity'] < 223)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df334 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df335 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_quantity','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df336 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_quantity','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df337 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7950) & (lineitem['l_quantity'] <= 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df338 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 2366) | (lineitem['l_quantity'] >= 209)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df339 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 7553) & (lineitem['l_quantity'] >= 29) | (lineitem['l_discount'] >= 0.16)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df340 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_partkey','l_tax','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df341 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14355) | (lineitem['l_quantity'] < 53) & (lineitem['l_discount'] < 2.04)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df342 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df343 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df344 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_extendedprice','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df345 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6217) | (lineitem['l_quantity'] <= 46)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df346 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8840) & (lineitem['l_quantity'] < 56)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df347 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_tax','l_shipdate','l_commitdate','l_receiptdate']].groupby(by=['l_commitdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df348 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3298) & (lineitem['l_quantity'] >= 20) & (lineitem['l_discount'] >= 0.09)][['l_orderkey','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df349 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df350 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df351 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df352 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5578) & (lineitem['l_quantity'] > 21)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df353 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10453) & (lineitem['l_quantity'] < 32)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df354 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_partkey','l_linenumber','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_quantity']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df355 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_tax','l_linestatus','l_shipdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df356 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df357 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df358 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df359 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5114) | (lineitem['l_quantity'] < 228) | (lineitem['l_discount'] < 201.61)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df360 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8657) & (lineitem['l_quantity'] <= 29) & (lineitem['l_discount'] <= 1.14)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df361 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5348) | (lineitem['l_quantity'] > 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df362 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5053) & (lineitem['l_quantity'] >= 40)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df363 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) | (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df364 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8216) & (lineitem['l_quantity'] <= 24)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df365 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) & (lineitem['l_quantity'] < 35) | (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df366 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) | (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df367 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_shipmode','l_comment']].groupby(by=['l_shipmode']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df368 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df369 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df370 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df371 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_tax','l_linestatus','l_receiptdate']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df372 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 8881) & (lineitem['l_quantity'] >= 46)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df373 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14680) | (lineitem['l_quantity'] < 69)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df374 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) & (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_linenumber','l_discount','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_comment']].groupby(by=['l_shipdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df375 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 16632) | (lineitem['l_quantity'] < 75) | (lineitem['l_discount'] < 2.18)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df376 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_partkey','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df377 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_extendedprice','l_discount','l_linestatus','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df378 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 6816) & (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 1.14)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_shipdate','l_shipmode']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df379 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df380 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8259) & (lineitem['l_quantity'] < 57)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df381 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df382 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df383 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df384 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) & (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df385 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) & (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df386 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3878) | (lineitem['l_quantity'] > 38)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df387 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8614) | (lineitem['l_quantity'] < 49) & (lineitem['l_discount'] < 1.56)][['l_orderkey','l_partkey','l_linenumber','l_extendedprice','l_tax','l_linestatus']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df388 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4989) & (lineitem['l_quantity'] >= 36)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df389 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5297) & (lineitem['l_quantity'] >= 14) | (lineitem['l_discount'] >= 0.1)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_returnflag','l_linestatus','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df390 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) & (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_linenumber','l_quantity','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df391 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df392 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_partkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df393 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) | (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df394 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df395 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5884) & (lineitem['l_quantity'] <= 220)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df396 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) | (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_discount','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df397 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7547) & (lineitem['l_quantity'] < 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df398 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df399 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_returnflag','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df400 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df401 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df402 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5342) & (lineitem['l_quantity'] > 37)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df403 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12140) & (lineitem['l_quantity'] <= 65)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df404 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df405 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10302) | (lineitem['l_quantity'] < 40) | (lineitem['l_discount'] < 1.69)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipinstruct']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df406 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df407 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) & (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_returnflag','l_shipdate','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df408 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3813) & (lineitem['l_quantity'] <= 228) | (lineitem['l_discount'] <= 201.06)][['l_orderkey','l_partkey','l_suppkey','l_extendedprice','l_discount','l_shipdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df409 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5139) | (lineitem['l_quantity'] > 35) | (lineitem['l_discount'] > 1.13)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df410 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df411 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) | (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df412 = lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 9774) | (lineitem['l_quantity'] < 43) | (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df413 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df414 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df415 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df416 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df417 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 497048.47) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_orderdate']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df418 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df419 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_custkey','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df420 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 175118.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority']].groupby(by=['o_shippriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df421 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 281428.61) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df422 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df423 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df424 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 267744.16) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df425 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df426 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df427 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 92507.06) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df428 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 182691.78) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df429 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_orderpriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df430 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df431 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_totalprice','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df432 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_comment']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df433 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 394066.64) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df434 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df435 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df436 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df437 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 409119.08) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderdate']],left_on='l_orderkey', right_on='o_orderkey') 
df438 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 299260.59) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df439 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 155982.45) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df440 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df441 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df442 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df443 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 190341.58) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderdate','o_clerk','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df444 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 269278.52) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_totalprice','o_orderpriority','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df445 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df446 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 308518.61) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df447 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df448 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderdate','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df449 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice','o_clerk','o_comment']].groupby(by=['o_custkey']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df450 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df451 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 133060.14) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df452 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderdate','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df453 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 171953.74) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df454 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df455 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 36395.09) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('max',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df456 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df457 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df458 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df459 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df460 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df461 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df462 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df463 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df464 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df465 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df466 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df467 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 6231) & (lineitem['l_quantity'] < 223)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df468 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df469 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_quantity','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df470 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_quantity','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df471 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7950) & (lineitem['l_quantity'] <= 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df472 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 2366) | (lineitem['l_quantity'] >= 209)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df473 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 7553) & (lineitem['l_quantity'] >= 29) | (lineitem['l_discount'] >= 0.16)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df474 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_partkey','l_tax','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df475 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14355) | (lineitem['l_quantity'] < 53) & (lineitem['l_discount'] < 2.04)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df476 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df477 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df478 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_extendedprice','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df479 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6217) | (lineitem['l_quantity'] <= 46)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df480 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8840) & (lineitem['l_quantity'] < 56)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df481 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_tax','l_shipdate','l_commitdate','l_receiptdate']].groupby(by=['l_commitdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df482 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3298) & (lineitem['l_quantity'] >= 20) & (lineitem['l_discount'] >= 0.09)][['l_orderkey','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df483 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df484 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df485 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df486 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5578) & (lineitem['l_quantity'] > 21)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df487 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10453) & (lineitem['l_quantity'] < 32)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df488 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_partkey','l_linenumber','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_quantity']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df489 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_tax','l_linestatus','l_shipdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df490 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df491 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df492 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df493 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5114) | (lineitem['l_quantity'] < 228) | (lineitem['l_discount'] < 201.61)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df494 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8657) & (lineitem['l_quantity'] <= 29) & (lineitem['l_discount'] <= 1.14)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df495 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5348) | (lineitem['l_quantity'] > 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df496 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5053) & (lineitem['l_quantity'] >= 40)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df497 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) | (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df498 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8216) & (lineitem['l_quantity'] <= 24)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df499 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) & (lineitem['l_quantity'] < 35) | (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df500 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) | (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df501 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_shipmode','l_comment']].groupby(by=['l_shipmode']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df502 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df503 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df504 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df505 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_tax','l_linestatus','l_receiptdate']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df506 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 8881) & (lineitem['l_quantity'] >= 46)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df507 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14680) | (lineitem['l_quantity'] < 69)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df508 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) & (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_linenumber','l_discount','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_comment']].groupby(by=['l_shipdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df509 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 16632) | (lineitem['l_quantity'] < 75) | (lineitem['l_discount'] < 2.18)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df510 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_partkey','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df511 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_extendedprice','l_discount','l_linestatus','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df512 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 6816) & (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 1.14)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_shipdate','l_shipmode']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df513 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df514 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8259) & (lineitem['l_quantity'] < 57)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df515 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df516 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df517 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df518 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) & (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df519 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) & (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df520 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3878) | (lineitem['l_quantity'] > 38)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df521 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8614) | (lineitem['l_quantity'] < 49) & (lineitem['l_discount'] < 1.56)][['l_orderkey','l_partkey','l_linenumber','l_extendedprice','l_tax','l_linestatus']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df522 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4989) & (lineitem['l_quantity'] >= 36)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df523 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5297) & (lineitem['l_quantity'] >= 14) | (lineitem['l_discount'] >= 0.1)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_returnflag','l_linestatus','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df524 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) & (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_linenumber','l_quantity','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df525 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df526 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_partkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df527 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) | (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df528 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df529 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5884) & (lineitem['l_quantity'] <= 220)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df530 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) | (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_discount','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df531 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7547) & (lineitem['l_quantity'] < 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df532 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df533 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_returnflag','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df534 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df535 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df536 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5342) & (lineitem['l_quantity'] > 37)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df537 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12140) & (lineitem['l_quantity'] <= 65)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df538 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df539 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10302) | (lineitem['l_quantity'] < 40) | (lineitem['l_discount'] < 1.69)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipinstruct']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df540 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df541 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) & (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_returnflag','l_shipdate','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df542 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3813) & (lineitem['l_quantity'] <= 228) | (lineitem['l_discount'] <= 201.06)][['l_orderkey','l_partkey','l_suppkey','l_extendedprice','l_discount','l_shipdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df543 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5139) | (lineitem['l_quantity'] > 35) | (lineitem['l_discount'] > 1.13)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df544 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df545 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) | (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df546 = lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 9774) | (lineitem['l_quantity'] < 43) | (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df547 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df548 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df549 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df550 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df551 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 497048.47) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_orderdate']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df552 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df553 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_custkey','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df554 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 281428.61) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df555 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df556 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 267744.16) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df557 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df558 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df559 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 92507.06) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df560 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 182691.78) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df561 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_totalprice','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df562 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_comment']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df563 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df564 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df565 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] == 409119.08) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderdate']],left_on='l_orderkey', right_on='o_orderkey') 
df566 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 299260.59) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df567 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df568 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df569 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 190341.58) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderdate','o_clerk','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df570 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] == 269278.52) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_totalprice','o_orderpriority','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df571 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df572 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] < 308518.61) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df573 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df574 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderdate','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df575 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice','o_clerk','o_comment']].groupby(by=['o_custkey']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df576 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df577 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderdate','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df578 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 171953.74) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df579 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df580 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 36395.09) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('max',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df581 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df582 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df583 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df584 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df585 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df586 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df587 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df588 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df589 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df590 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df591 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 6231) & (lineitem['l_quantity'] < 223)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df592 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df593 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_quantity','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df594 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_quantity','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df595 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7950) & (lineitem['l_quantity'] <= 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df596 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 2366) | (lineitem['l_quantity'] >= 209)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df597 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14355) | (lineitem['l_quantity'] < 53) & (lineitem['l_discount'] < 2.04)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df598 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df599 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_extendedprice','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df600 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6217) | (lineitem['l_quantity'] <= 46)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df601 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8840) & (lineitem['l_quantity'] < 56)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df602 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3298) & (lineitem['l_quantity'] >= 20) & (lineitem['l_discount'] >= 0.09)][['l_orderkey','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df603 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df604 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df605 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df606 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5578) & (lineitem['l_quantity'] > 21)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df607 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10453) & (lineitem['l_quantity'] < 32)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df608 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_partkey','l_linenumber','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_quantity']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df609 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df610 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df611 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df612 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8657) & (lineitem['l_quantity'] <= 29) & (lineitem['l_discount'] <= 1.14)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df613 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5348) | (lineitem['l_quantity'] > 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df614 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) | (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df615 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8216) & (lineitem['l_quantity'] <= 24)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df616 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) & (lineitem['l_quantity'] < 35) | (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df617 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) | (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df618 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_tax','l_linestatus','l_receiptdate']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df619 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14680) | (lineitem['l_quantity'] < 69)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df620 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) & (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_linenumber','l_discount','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_comment']].groupby(by=['l_shipdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df621 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 16632) | (lineitem['l_quantity'] < 75) | (lineitem['l_discount'] < 2.18)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df622 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_partkey','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df623 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df624 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8259) & (lineitem['l_quantity'] < 57)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df625 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df626 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) & (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df627 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) & (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df628 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3878) | (lineitem['l_quantity'] > 38)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df629 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8614) | (lineitem['l_quantity'] < 49) & (lineitem['l_discount'] < 1.56)][['l_orderkey','l_partkey','l_linenumber','l_extendedprice','l_tax','l_linestatus']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df630 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5297) & (lineitem['l_quantity'] >= 14) | (lineitem['l_discount'] >= 0.1)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_returnflag','l_linestatus','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df631 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) & (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_linenumber','l_quantity','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df632 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df633 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_partkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df634 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) | (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df635 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df636 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5884) & (lineitem['l_quantity'] <= 220)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df637 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) | (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_discount','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df638 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7547) & (lineitem['l_quantity'] < 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df639 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df640 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df641 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df642 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12140) & (lineitem['l_quantity'] <= 65)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df643 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df644 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10302) | (lineitem['l_quantity'] < 40) | (lineitem['l_discount'] < 1.69)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipinstruct']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df645 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df646 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) & (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_returnflag','l_shipdate','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df647 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3813) & (lineitem['l_quantity'] <= 228) | (lineitem['l_discount'] <= 201.06)][['l_orderkey','l_partkey','l_suppkey','l_extendedprice','l_discount','l_shipdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df648 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5139) | (lineitem['l_quantity'] > 35) | (lineitem['l_discount'] > 1.13)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df649 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df650 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) | (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df651 = lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 9774) | (lineitem['l_quantity'] < 43) | (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df652 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df653 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df654 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey') 
df655 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey') 
df656 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df657 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df658 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df659 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df660 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df661 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df662 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df663 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df664 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df665 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df666 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 26][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df667 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df668 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df669 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df670 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey') 
df671 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df672 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df673 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df674 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 26][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df675 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df676 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df677 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df678 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df679 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df680 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df681 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df682 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df683 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df684 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df685 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df686 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey') 
df687 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 6][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df688 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df689 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df690 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df691 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df692 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df693 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df694 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df695 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df696 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df697 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey') 
df698 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey') 
df699 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df700 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df701 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df702 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df703 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df704 = customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df705 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='l_suppkey', right_on='s_suppkey') 
df706 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df707 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df708 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_address']],left_on='l_suppkey', right_on='s_suppkey') 
df709 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df710 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df711 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] <= 497048.47) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_orderdate']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df712 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey') 
df713 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey') 
df714 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df715 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df716 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df717 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df718 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey') 
df719 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey') 
df720 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_custkey','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df721 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey') 
df722 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='l_suppkey', right_on='s_suppkey') 
df723 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] >= 175118.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority']].groupby(by=['o_shippriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df724 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] <= 281428.61) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df725 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='l_suppkey', right_on='s_suppkey') 
df726 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='l_suppkey', right_on='s_suppkey') 
df727 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df728 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey') 
df729 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df730 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df731 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df732 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] <= 267744.16) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df733 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df734 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df735 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 92507.06) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df736 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] <= 182691.78) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df737 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey') 
df738 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df739 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_orderpriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df740 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df741 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey') 
df742 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey') 
df743 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_totalprice','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df744 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_comment']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df745 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='l_suppkey', right_on='s_suppkey') 
df746 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df747 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey') 
df748 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] == 394066.64) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df749 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df750 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df751 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey') 
df752 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df753 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey') 
df754 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df755 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df756 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey') 
df757 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='l_suppkey', right_on='s_suppkey') 
df758 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df759 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df760 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df761 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey') 
df762 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey') 
df763 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='l_suppkey', right_on='s_suppkey') 
df764 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df765 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df766 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df767 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey') 
df768 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] == 409119.08) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderdate']],left_on='l_orderkey', right_on='o_orderkey') 
df769 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 299260.59) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df770 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df771 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] < 155982.45) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df772 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey') 
df773 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df774 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df775 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey') 
df776 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df777 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] >= 190341.58) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderdate','o_clerk','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df778 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] == 269278.52) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_totalprice','o_orderpriority','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df779 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df780 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey') 
df781 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df782 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df783 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey') 
df784 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df785 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='l_suppkey', right_on='s_suppkey') 
df786 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='l_suppkey', right_on='s_suppkey') 
df787 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df788 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df789 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey') 
df790 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] < 308518.61) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df791 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df792 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df793 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderdate','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df794 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice','o_clerk','o_comment']].groupby(by=['o_custkey']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df795 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df796 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey') 
df797 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey') 
df798 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df799 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] <= 133060.14) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df800 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderdate','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df801 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] >= 171953.74) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df802 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey') 
df803 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df804 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] >= 36395.09) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('max',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df805 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df806 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='l_suppkey', right_on='s_suppkey') 
df807 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df808 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df809 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey') 
df810 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey') 
df811 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df812 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df813 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df814 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df815 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df816 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df817 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df818 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df819 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df820 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df821 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df822 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df823 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df824 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df825 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df826 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df827 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df828 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df829 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df830 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df831 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df832 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df833 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df834 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df835 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df836 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df837 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df838 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df839 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df840 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df841 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df842 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df843 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df844 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df845 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df846 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df847 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df848 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df849 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df850 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df851 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df852 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df853 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df854 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df855 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df856 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df857 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df858 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df859 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df860 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df861 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df862 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df863 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df864 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df865 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df866 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df867 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df868 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df869 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df870 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df871 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df872 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df873 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df874 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df875 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df876 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df877 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df878 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df879 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df880 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df881 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 6231) & (lineitem['l_quantity'] < 223)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df882 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df883 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_quantity','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df884 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_quantity','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df885 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7950) & (lineitem['l_quantity'] <= 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df886 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 2366) | (lineitem['l_quantity'] >= 209)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df887 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 7553) & (lineitem['l_quantity'] >= 29) | (lineitem['l_discount'] >= 0.16)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df888 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_partkey','l_tax','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df889 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14355) | (lineitem['l_quantity'] < 53) & (lineitem['l_discount'] < 2.04)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df890 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df891 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df892 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_extendedprice','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df893 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6217) | (lineitem['l_quantity'] <= 46)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df894 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8840) & (lineitem['l_quantity'] < 56)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df895 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_tax','l_shipdate','l_commitdate','l_receiptdate']].groupby(by=['l_commitdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df896 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3298) & (lineitem['l_quantity'] >= 20) & (lineitem['l_discount'] >= 0.09)][['l_orderkey','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df897 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df898 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df899 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df900 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5578) & (lineitem['l_quantity'] > 21)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df901 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10453) & (lineitem['l_quantity'] < 32)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df902 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_partkey','l_linenumber','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_quantity']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df903 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_tax','l_linestatus','l_shipdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df904 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df905 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df906 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df907 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5114) | (lineitem['l_quantity'] < 228) | (lineitem['l_discount'] < 201.61)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df908 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8657) & (lineitem['l_quantity'] <= 29) & (lineitem['l_discount'] <= 1.14)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df909 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5348) | (lineitem['l_quantity'] > 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df910 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5053) & (lineitem['l_quantity'] >= 40)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df911 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) | (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df912 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8216) & (lineitem['l_quantity'] <= 24)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df913 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) & (lineitem['l_quantity'] < 35) | (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df914 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) | (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df915 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_shipmode','l_comment']].groupby(by=['l_shipmode']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df916 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df917 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df918 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df919 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_tax','l_linestatus','l_receiptdate']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df920 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 8881) & (lineitem['l_quantity'] >= 46)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df921 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14680) | (lineitem['l_quantity'] < 69)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df922 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) & (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_linenumber','l_discount','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_comment']].groupby(by=['l_shipdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df923 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 16632) | (lineitem['l_quantity'] < 75) | (lineitem['l_discount'] < 2.18)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df924 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_partkey','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df925 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_extendedprice','l_discount','l_linestatus','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df926 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 6816) & (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 1.14)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_shipdate','l_shipmode']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df927 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df928 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8259) & (lineitem['l_quantity'] < 57)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df929 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df930 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df931 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df932 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) & (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df933 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) & (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df934 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3878) | (lineitem['l_quantity'] > 38)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df935 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8614) | (lineitem['l_quantity'] < 49) & (lineitem['l_discount'] < 1.56)][['l_orderkey','l_partkey','l_linenumber','l_extendedprice','l_tax','l_linestatus']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df936 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4989) & (lineitem['l_quantity'] >= 36)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df937 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5297) & (lineitem['l_quantity'] >= 14) | (lineitem['l_discount'] >= 0.1)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_returnflag','l_linestatus','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df938 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) & (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_linenumber','l_quantity','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df939 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df940 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_partkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df941 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) | (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df942 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df943 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5884) & (lineitem['l_quantity'] <= 220)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df944 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) | (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_discount','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df945 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7547) & (lineitem['l_quantity'] < 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df946 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df947 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_returnflag','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df948 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df949 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df950 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5342) & (lineitem['l_quantity'] > 37)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df951 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12140) & (lineitem['l_quantity'] <= 65)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df952 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df953 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10302) | (lineitem['l_quantity'] < 40) | (lineitem['l_discount'] < 1.69)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipinstruct']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df954 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df955 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) & (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_returnflag','l_shipdate','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df956 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3813) & (lineitem['l_quantity'] <= 228) | (lineitem['l_discount'] <= 201.06)][['l_orderkey','l_partkey','l_suppkey','l_extendedprice','l_discount','l_shipdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df957 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5139) | (lineitem['l_quantity'] > 35) | (lineitem['l_discount'] > 1.13)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df958 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df959 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) | (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df960 = lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 9774) | (lineitem['l_quantity'] < 43) | (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df961 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey') 
df962 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='ps_suppkey', right_on='s_suppkey') 
df963 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1003],left_on='ps_partkey', right_on='p_partkey') 
df964 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey') 
df965 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey') 
df966 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey') 
df967 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1063],left_on='ps_partkey', right_on='p_partkey') 
df968 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df969 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1059],left_on='ps_partkey', right_on='p_partkey') 
df970 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df971 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df972 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df973 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey') 
df974 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey') 
df975 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey') 
df976 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] > 132],left_on='ps_partkey', right_on='p_partkey') 
df977 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey') 
df978 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey') 
df979 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey') 
df980 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='ps_suppkey', right_on='s_suppkey') 
df981 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey') 
df982 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df983 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df984 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1175],left_on='ps_partkey', right_on='p_partkey') 
df985 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] >= 251],left_on='ps_partkey', right_on='p_partkey') 
df986 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey') 
df987 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df988 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey') 
df989 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df990 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1161],left_on='ps_partkey', right_on='p_partkey') 
df991 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey') 
df992 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey') 
df993 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1003],left_on='ps_partkey', right_on='p_partkey') 
df994 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey') 
df995 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] == 24) | (supplier['s_acctbal'] == 10802)],left_on='ps_suppkey', right_on='s_suppkey') 
df996 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df997 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey') 
df998 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df999 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey') 
df1000 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey') 
df1001 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df1002 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df1003 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1209],left_on='ps_partkey', right_on='p_partkey') 
df1004 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1025],left_on='ps_partkey', right_on='p_partkey') 
df1005 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey') 
df1006 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 20) & (supplier['s_acctbal'] > 7359)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df1007 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey') 
df1008 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='ps_suppkey', right_on='s_suppkey') 
df1009 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df1010 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df1011 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey') 
df1012 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey') 
df1013 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey') 
df1014 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] >= 90],left_on='ps_partkey', right_on='p_partkey') 
df1015 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey') 
df1016 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1209],left_on='ps_partkey', right_on='p_partkey') 
df1017 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df1018 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df1019 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] > 291],left_on='ps_partkey', right_on='p_partkey') 
df1020 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df1021 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1134],left_on='ps_partkey', right_on='p_partkey') 
df1022 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey') 
df1023 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1025],left_on='ps_partkey', right_on='p_partkey') 
df1024 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df1025 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey') 
df1026 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey') 
df1027 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey') 
df1028 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df1029 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1159],left_on='ps_partkey', right_on='p_partkey') 
df1030 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='ps_suppkey', right_on='s_suppkey') 
df1031 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey') 
df1032 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df1033 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey') 
df1034 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df1035 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey') 
df1036 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey') 
df1037 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1175],left_on='ps_partkey', right_on='p_partkey') 
df1038 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df1039 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey') 
df1040 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey') 
df1041 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 24) | (supplier['s_acctbal'] >= 13148)],left_on='ps_suppkey', right_on='s_suppkey') 
df1042 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df1043 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1115],left_on='ps_partkey', right_on='p_partkey') 
df1044 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey') 
df1045 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey') 
df1046 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey') 
df1047 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey') 
df1048 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='ps_suppkey', right_on='s_suppkey') 
df1049 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1105],left_on='ps_partkey', right_on='p_partkey') 
df1050 = partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1040],left_on='ps_partkey', right_on='p_partkey') 
df1051 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey') 
df1052 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey') 
df1053 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey') 
df1054 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey') 
df1055 = partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey') 
df1056 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1057 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1058 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1059 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1060 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1061 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1062 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1063 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1064 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1065 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1066 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1067 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1068 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1069 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1070 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1071 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1072 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1073 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1074 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1075 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1076 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1077 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1078 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1079 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1080 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1081 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1082 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1083 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1084 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1085 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1086 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1087 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1088 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1089 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1090 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1091 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1092 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1093 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1094 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1095 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1096 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1097 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1098 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1099 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1100 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1101 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1102 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1103 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1104 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1105 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1106 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1107 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1108 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1109 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1110 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1111 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1112 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1113 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1114 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1115 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1116 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1117 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1118 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1119 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1120 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1121 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1122 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1123 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1124 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1125 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1126 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1127 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1128 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1129 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1130 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1131 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1132 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1133 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1134 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1135 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1136 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1137 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1138 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1139 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1140 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1141 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1142 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1143 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1144 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1145 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1146 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1147 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1148 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1149 = partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey') 
df1150 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1151 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df1152 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1153 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1154 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 497048.47) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_orderdate']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1155 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df1156 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_custkey','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1157 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 175118.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority']].groupby(by=['o_shippriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1158 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 281428.61) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1159 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df1160 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1161 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 267744.16) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1162 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1163 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1164 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 92507.06) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1165 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 182691.78) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1166 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_orderpriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1167 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1168 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_totalprice','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1169 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_comment']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1170 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 394066.64) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1171 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1172 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1173 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1174 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 409119.08) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderdate']],left_on='l_orderkey', right_on='o_orderkey') 
df1175 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 299260.59) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1176 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 155982.45) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1177 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1178 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1179 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1180 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 190341.58) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderdate','o_clerk','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1181 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 269278.52) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_totalprice','o_orderpriority','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1182 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1183 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 308518.61) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1184 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df1185 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderdate','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1186 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice','o_clerk','o_comment']].groupby(by=['o_custkey']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1187 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1188 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 133060.14) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1189 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderdate','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1190 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 171953.74) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1191 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1192 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 36395.09) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('max',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1193 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df1194 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df1195 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df1196 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1197 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1198 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1199 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1200 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1201 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1202 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1203 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 6231) & (lineitem['l_quantity'] < 223)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1204 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1205 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_quantity','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1206 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_quantity','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1207 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7950) & (lineitem['l_quantity'] <= 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1208 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 2366) | (lineitem['l_quantity'] >= 209)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1209 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 7553) & (lineitem['l_quantity'] >= 29) | (lineitem['l_discount'] >= 0.16)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1210 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_partkey','l_tax','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1211 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14355) | (lineitem['l_quantity'] < 53) & (lineitem['l_discount'] < 2.04)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1212 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1213 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1214 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_extendedprice','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1215 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6217) | (lineitem['l_quantity'] <= 46)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1216 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8840) & (lineitem['l_quantity'] < 56)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1217 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_tax','l_shipdate','l_commitdate','l_receiptdate']].groupby(by=['l_commitdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1218 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3298) & (lineitem['l_quantity'] >= 20) & (lineitem['l_discount'] >= 0.09)][['l_orderkey','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1219 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1220 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1221 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1222 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5578) & (lineitem['l_quantity'] > 21)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1223 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10453) & (lineitem['l_quantity'] < 32)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1224 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_partkey','l_linenumber','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_quantity']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1225 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_tax','l_linestatus','l_shipdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1226 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1227 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1228 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1229 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5114) | (lineitem['l_quantity'] < 228) | (lineitem['l_discount'] < 201.61)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1230 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8657) & (lineitem['l_quantity'] <= 29) & (lineitem['l_discount'] <= 1.14)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1231 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5348) | (lineitem['l_quantity'] > 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1232 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5053) & (lineitem['l_quantity'] >= 40)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1233 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) | (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1234 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8216) & (lineitem['l_quantity'] <= 24)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1235 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) & (lineitem['l_quantity'] < 35) | (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1236 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) | (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1237 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_shipmode','l_comment']].groupby(by=['l_shipmode']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1238 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1239 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1240 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1241 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_tax','l_linestatus','l_receiptdate']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1242 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 8881) & (lineitem['l_quantity'] >= 46)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1243 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14680) | (lineitem['l_quantity'] < 69)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1244 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) & (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_linenumber','l_discount','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_comment']].groupby(by=['l_shipdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1245 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 16632) | (lineitem['l_quantity'] < 75) | (lineitem['l_discount'] < 2.18)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1246 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_partkey','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1247 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_extendedprice','l_discount','l_linestatus','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1248 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 6816) & (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 1.14)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_shipdate','l_shipmode']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1249 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1250 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8259) & (lineitem['l_quantity'] < 57)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1251 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1252 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1253 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1254 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) & (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1255 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) & (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1256 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3878) | (lineitem['l_quantity'] > 38)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1257 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8614) | (lineitem['l_quantity'] < 49) & (lineitem['l_discount'] < 1.56)][['l_orderkey','l_partkey','l_linenumber','l_extendedprice','l_tax','l_linestatus']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1258 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4989) & (lineitem['l_quantity'] >= 36)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1259 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5297) & (lineitem['l_quantity'] >= 14) | (lineitem['l_discount'] >= 0.1)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_returnflag','l_linestatus','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1260 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) & (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_linenumber','l_quantity','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1261 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1262 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_partkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1263 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) | (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1264 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1265 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5884) & (lineitem['l_quantity'] <= 220)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1266 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) | (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_discount','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1267 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7547) & (lineitem['l_quantity'] < 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1268 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1269 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_returnflag','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1270 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1271 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1272 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5342) & (lineitem['l_quantity'] > 37)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1273 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12140) & (lineitem['l_quantity'] <= 65)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1274 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1275 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10302) | (lineitem['l_quantity'] < 40) | (lineitem['l_discount'] < 1.69)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipinstruct']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1276 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1277 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) & (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_returnflag','l_shipdate','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1278 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3813) & (lineitem['l_quantity'] <= 228) | (lineitem['l_discount'] <= 201.06)][['l_orderkey','l_partkey','l_suppkey','l_extendedprice','l_discount','l_shipdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1279 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5139) | (lineitem['l_quantity'] > 35) | (lineitem['l_discount'] > 1.13)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1280 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1281 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) | (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1282 = lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 9774) | (lineitem['l_quantity'] < 43) | (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1283 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1284 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1285 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey') 
df1286 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey') 
df1287 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1288 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1289 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1290 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1291 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1292 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1293 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1294 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1295 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1296 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1297 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 26][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1298 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1299 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1300 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1301 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey') 
df1302 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1303 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1304 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1305 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 26][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1306 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1307 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1308 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1309 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1310 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1311 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1312 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1313 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1314 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1315 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1316 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1317 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey') 
df1318 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 6][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1319 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1320 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1321 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1322 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1323 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1324 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1325 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1326 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1327 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1328 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey') 
df1329 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey') 
df1330 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1331 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1332 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1333 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1334 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df1335 = customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df1336 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='l_suppkey', right_on='s_suppkey') 
df1337 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1338 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df1339 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_address']],left_on='l_suppkey', right_on='s_suppkey') 
df1340 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1341 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1342 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] <= 497048.47) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_orderdate']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1343 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey') 
df1344 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey') 
df1345 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df1346 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df1347 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df1348 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df1349 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey') 
df1350 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey') 
df1351 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_custkey','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1352 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey') 
df1353 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='l_suppkey', right_on='s_suppkey') 
df1354 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] >= 175118.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority']].groupby(by=['o_shippriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1355 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] <= 281428.61) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1356 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='l_suppkey', right_on='s_suppkey') 
df1357 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='l_suppkey', right_on='s_suppkey') 
df1358 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df1359 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey') 
df1360 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df1361 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df1362 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1363 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] <= 267744.16) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1364 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1365 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1366 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 92507.06) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1367 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] <= 182691.78) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1368 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey') 
df1369 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df1370 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_orderpriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1371 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1372 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey') 
df1373 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey') 
df1374 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_totalprice','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1375 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_comment']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1376 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='l_suppkey', right_on='s_suppkey') 
df1377 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df1378 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey') 
df1379 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] == 394066.64) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1380 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df1381 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1382 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey') 
df1383 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1384 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey') 
df1385 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df1386 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df1387 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey') 
df1388 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='l_suppkey', right_on='s_suppkey') 
df1389 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df1390 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df1391 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1392 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey') 
df1393 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey') 
df1394 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='l_suppkey', right_on='s_suppkey') 
df1395 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df1396 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df1397 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df1398 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey') 
df1399 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] == 409119.08) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderdate']],left_on='l_orderkey', right_on='o_orderkey') 
df1400 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 299260.59) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1401 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df1402 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] < 155982.45) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1403 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey') 
df1404 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1405 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1406 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey') 
df1407 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1408 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] >= 190341.58) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderdate','o_clerk','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1409 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] == 269278.52) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_totalprice','o_orderpriority','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1410 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df1411 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey') 
df1412 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df1413 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df1414 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey') 
df1415 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df1416 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='l_suppkey', right_on='s_suppkey') 
df1417 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='l_suppkey', right_on='s_suppkey') 
df1418 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df1419 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df1420 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey') 
df1421 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] < 308518.61) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1422 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df1423 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df1424 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderdate','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1425 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice','o_clerk','o_comment']].groupby(by=['o_custkey']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1426 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1427 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey') 
df1428 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey') 
df1429 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df1430 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] <= 133060.14) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1431 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderdate','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1432 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] >= 171953.74) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1433 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey') 
df1434 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df1435 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] >= 36395.09) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('max',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df1436 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df1437 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='l_suppkey', right_on='s_suppkey') 
df1438 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df1439 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df1440 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey') 
df1441 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey') 
df1442 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df1443 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1444 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1445 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1446 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1447 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1448 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1449 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1450 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1451 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1452 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1453 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1454 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1455 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1456 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1457 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1458 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1459 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1460 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1461 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1462 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1463 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1464 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1465 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1466 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1467 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1468 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1469 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1470 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1471 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1472 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1473 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1474 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1475 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1476 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1477 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1478 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1479 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1480 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1481 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1482 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1483 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1484 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1485 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1486 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1487 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1488 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1489 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1490 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1491 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1492 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1493 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1494 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1495 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1496 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1497 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1498 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1499 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1500 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1501 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1502 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1503 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1504 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1505 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1506 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1507 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1508 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1509 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1510 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1511 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1512 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 6231) & (lineitem['l_quantity'] < 223)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1513 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1514 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_quantity','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1515 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_quantity','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1516 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7950) & (lineitem['l_quantity'] <= 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1517 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 2366) | (lineitem['l_quantity'] >= 209)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1518 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 7553) & (lineitem['l_quantity'] >= 29) | (lineitem['l_discount'] >= 0.16)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1519 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_partkey','l_tax','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1520 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14355) | (lineitem['l_quantity'] < 53) & (lineitem['l_discount'] < 2.04)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1521 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1522 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1523 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_extendedprice','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1524 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6217) | (lineitem['l_quantity'] <= 46)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1525 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8840) & (lineitem['l_quantity'] < 56)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1526 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_tax','l_shipdate','l_commitdate','l_receiptdate']].groupby(by=['l_commitdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1527 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3298) & (lineitem['l_quantity'] >= 20) & (lineitem['l_discount'] >= 0.09)][['l_orderkey','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1528 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1529 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1530 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1531 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5578) & (lineitem['l_quantity'] > 21)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1532 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10453) & (lineitem['l_quantity'] < 32)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1533 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_partkey','l_linenumber','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_quantity']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1534 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_tax','l_linestatus','l_shipdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1535 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1536 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1537 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1538 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5114) | (lineitem['l_quantity'] < 228) | (lineitem['l_discount'] < 201.61)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1539 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8657) & (lineitem['l_quantity'] <= 29) & (lineitem['l_discount'] <= 1.14)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1540 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5348) | (lineitem['l_quantity'] > 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1541 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5053) & (lineitem['l_quantity'] >= 40)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1542 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) | (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1543 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8216) & (lineitem['l_quantity'] <= 24)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1544 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) & (lineitem['l_quantity'] < 35) | (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1545 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) | (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1546 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_shipmode','l_comment']].groupby(by=['l_shipmode']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1547 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1548 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1549 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1550 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_tax','l_linestatus','l_receiptdate']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1551 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 8881) & (lineitem['l_quantity'] >= 46)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1552 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14680) | (lineitem['l_quantity'] < 69)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1553 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) & (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_linenumber','l_discount','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_comment']].groupby(by=['l_shipdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1554 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 16632) | (lineitem['l_quantity'] < 75) | (lineitem['l_discount'] < 2.18)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1555 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_partkey','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1556 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_extendedprice','l_discount','l_linestatus','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1557 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 6816) & (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 1.14)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_shipdate','l_shipmode']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1558 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1559 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8259) & (lineitem['l_quantity'] < 57)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1560 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1561 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1562 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1563 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) & (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1564 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) & (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1565 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3878) | (lineitem['l_quantity'] > 38)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1566 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8614) | (lineitem['l_quantity'] < 49) & (lineitem['l_discount'] < 1.56)][['l_orderkey','l_partkey','l_linenumber','l_extendedprice','l_tax','l_linestatus']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1567 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4989) & (lineitem['l_quantity'] >= 36)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1568 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5297) & (lineitem['l_quantity'] >= 14) | (lineitem['l_discount'] >= 0.1)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_returnflag','l_linestatus','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1569 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) & (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_linenumber','l_quantity','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1570 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1571 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_partkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1572 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) | (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1573 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1574 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5884) & (lineitem['l_quantity'] <= 220)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1575 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) | (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_discount','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1576 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7547) & (lineitem['l_quantity'] < 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1577 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1578 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_returnflag','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1579 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1580 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1581 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5342) & (lineitem['l_quantity'] > 37)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1582 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12140) & (lineitem['l_quantity'] <= 65)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1583 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1584 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10302) | (lineitem['l_quantity'] < 40) | (lineitem['l_discount'] < 1.69)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipinstruct']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1585 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1586 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) & (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_returnflag','l_shipdate','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1587 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3813) & (lineitem['l_quantity'] <= 228) | (lineitem['l_discount'] <= 201.06)][['l_orderkey','l_partkey','l_suppkey','l_extendedprice','l_discount','l_shipdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1588 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5139) | (lineitem['l_quantity'] > 35) | (lineitem['l_discount'] > 1.13)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1589 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1590 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) | (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1591 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 9774) | (lineitem['l_quantity'] < 43) | (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df1592 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1593 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1594 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1595 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1596 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1597 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1598 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1599 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1600 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1601 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1602 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1603 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1604 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1605 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1606 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1607 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1608 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1609 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1610 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1611 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1612 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1613 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1614 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1615 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1616 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1617 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1618 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1619 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1620 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1621 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1622 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1623 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1624 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1625 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1626 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1627 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1628 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1629 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1630 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1631 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1632 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1633 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1634 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1635 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1636 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1637 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1638 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1639 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1640 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1641 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1642 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1643 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1644 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1645 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1646 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1647 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1648 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1649 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1650 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1651 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1652 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1653 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1654 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1655 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1656 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1657 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1658 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1659 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1660 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1661 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1662 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1663 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1664 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1665 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1666 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1667 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1668 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1669 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1670 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1671 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1672 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1673 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1674 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1675 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1676 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1677 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1678 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1679 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1680 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1681 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1682 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1683 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1684 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1685 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1686 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1687 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1688 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1689 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1690 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1691 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1692 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1693 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1694 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1695 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1696 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1697 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1698 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1699 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1700 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1701 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1702 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1703 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1704 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1705 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1706 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1707 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1708 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1709 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1710 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1711 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1712 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1713 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1714 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1715 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1716 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1717 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1718 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1719 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1720 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1721 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1722 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1723 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1724 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1725 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1726 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1727 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1728 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1729 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1730 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1731 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1732 = lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df1733 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='n_nationkey', right_on='s_nationkey') 
df1734 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='n_nationkey', right_on='s_nationkey') 
df1735 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 5],left_on='n_regionkey', right_on='r_regionkey') 
df1736 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='n_nationkey', right_on='s_nationkey') 
df1737 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey') 
df1738 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='n_nationkey', right_on='s_nationkey') 
df1739 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 21) | (supplier['s_acctbal'] == 5674)][['s_name','s_address','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey') 
df1740 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 9],left_on='n_regionkey', right_on='r_regionkey') 
df1741 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='n_nationkey', right_on='s_nationkey') 
df1742 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='n_nationkey', right_on='s_nationkey') 
df1743 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='n_nationkey', right_on='s_nationkey') 
df1744 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey') 
df1745 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 7],left_on='n_regionkey', right_on='r_regionkey') 
df1746 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='n_nationkey', right_on='s_nationkey') 
df1747 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='n_nationkey', right_on='s_nationkey') 
df1748 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='n_nationkey', right_on='s_nationkey') 
df1749 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey') 
df1750 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 8],left_on='n_regionkey', right_on='r_regionkey') 
df1751 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='n_nationkey', right_on='s_nationkey') 
df1752 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_address','s_nationkey']],left_on='n_nationkey', right_on='s_nationkey') 
df1753 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 215) | (supplier['s_acctbal'] < 5418)][['s_name','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey') 
df1754 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_nationkey','s_phone','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey') 
df1755 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_address','s_nationkey','s_comment']],left_on='n_nationkey', right_on='s_nationkey') 
df1756 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='n_nationkey', right_on='s_nationkey') 
df1757 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='n_nationkey', right_on='s_nationkey') 
df1758 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='n_nationkey', right_on='s_nationkey') 
df1759 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey') 
df1760 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 4],left_on='n_regionkey', right_on='r_regionkey') 
df1761 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 24) | (supplier['s_acctbal'] == 10802)],left_on='n_nationkey', right_on='s_nationkey') 
df1762 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='n_nationkey', right_on='s_nationkey') 
df1763 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='n_nationkey', right_on='s_nationkey') 
df1764 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='n_nationkey', right_on='s_nationkey') 
df1765 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='n_nationkey', right_on='s_nationkey') 
df1766 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey') 
df1767 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='n_nationkey', right_on='s_nationkey') 
df1768 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 20) & (supplier['s_acctbal'] > 7359)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey') 
df1769 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 3],left_on='n_regionkey', right_on='r_regionkey') 
df1770 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey') 
df1771 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 21) | (supplier['s_acctbal'] == 11563)][['s_nationkey','s_phone','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey') 
df1772 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 3],left_on='n_regionkey', right_on='r_regionkey') 
df1773 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 14) | (supplier['s_acctbal'] == 8535)],left_on='n_nationkey', right_on='s_nationkey') 
df1774 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='n_nationkey', right_on='s_nationkey') 
df1775 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey') 
df1776 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey') 
df1777 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey') 
df1778 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 5],left_on='n_regionkey', right_on='r_regionkey') 
df1779 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='n_nationkey', right_on='s_nationkey') 
df1780 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 4],left_on='n_regionkey', right_on='r_regionkey') 
df1781 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 8],left_on='n_regionkey', right_on='r_regionkey') 
df1782 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='n_nationkey', right_on='s_nationkey') 
df1783 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey') 
df1784 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey') 
df1785 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey') 
df1786 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey') 
df1787 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='n_nationkey', right_on='s_nationkey') 
df1788 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey') 
df1789 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] > 3],left_on='n_regionkey', right_on='r_regionkey') 
df1790 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 13) | (supplier['s_acctbal'] > 4399)][['s_address','s_nationkey','s_phone','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey') 
df1791 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='n_nationkey', right_on='s_nationkey') 
df1792 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 5],left_on='n_regionkey', right_on='r_regionkey') 
df1793 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='n_nationkey', right_on='s_nationkey') 
df1794 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey') 
df1795 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey') 
df1796 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='n_nationkey', right_on='s_nationkey') 
df1797 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='n_nationkey', right_on='s_nationkey') 
df1798 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 8],left_on='n_regionkey', right_on='r_regionkey') 
df1799 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 21) | (supplier['s_acctbal'] == 11563)][['s_name','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey') 
df1800 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='n_nationkey', right_on='s_nationkey') 
df1801 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey') 
df1802 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 4],left_on='n_regionkey', right_on='r_regionkey') 
df1803 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='n_nationkey', right_on='s_nationkey') 
df1804 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='n_nationkey', right_on='s_nationkey') 
df1805 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='n_nationkey', right_on='s_nationkey') 
df1806 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 24) | (supplier['s_acctbal'] >= 13148)],left_on='n_nationkey', right_on='s_nationkey') 
df1807 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey') 
df1808 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey') 
df1809 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_name','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey') 
df1810 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_name','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey') 
df1811 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='n_nationkey', right_on='s_nationkey') 
df1812 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='n_nationkey', right_on='s_nationkey') 
df1813 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey') 
df1814 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 9],left_on='n_regionkey', right_on='r_regionkey') 
df1815 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey') 
df1816 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 4],left_on='n_regionkey', right_on='r_regionkey') 
df1817 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 8],left_on='n_regionkey', right_on='r_regionkey') 
df1818 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='n_nationkey', right_on='s_nationkey') 
df1819 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 6],left_on='n_regionkey', right_on='r_regionkey') 
df1820 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 24) | (supplier['s_acctbal'] > 8902)][['s_address','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey') 
df1821 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 3],left_on='n_regionkey', right_on='r_regionkey') 
df1822 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 5],left_on='n_regionkey', right_on='r_regionkey') 
df1823 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='n_nationkey', right_on='s_nationkey') 
df1824 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 21) | (supplier['s_acctbal'] == 5674)][['s_name','s_address','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey') 
df1825 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 15549)][['s_name','s_nationkey','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey') 
df1826 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey') 
df1827 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='n_nationkey', right_on='s_nationkey') 
df1828 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 212) | (supplier['s_acctbal'] <= 4085)][['s_name','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey') 
df1829 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='n_nationkey', right_on='s_nationkey') 
df1830 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1831 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1832 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1833 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1834 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1835 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1836 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1837 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1838 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1839 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1840 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1841 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1842 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1843 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1844 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1845 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] == 24) | (supplier['s_acctbal'] == 10802)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1846 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1847 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1848 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1849 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1850 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1851 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1852 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 20) & (supplier['s_acctbal'] > 7359)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1853 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] == 14) | (supplier['s_acctbal'] == 8535)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1854 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1855 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1856 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1857 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1858 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1859 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1860 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1861 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1862 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1863 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1864 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1865 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1866 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1867 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1868 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1869 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1870 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1871 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 24) | (supplier['s_acctbal'] >= 13148)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1872 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1873 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1874 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1875 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1876 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1877 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1878 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1879 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1880 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1881 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1882 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1883 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1884 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1885 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1886 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1887 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1888 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1889 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1890 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1891 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1892 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1893 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1894 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1895 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] == 24) | (supplier['s_acctbal'] == 10802)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1896 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1897 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1898 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1899 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1900 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1901 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1902 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] == 14) | (supplier['s_acctbal'] == 8535)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1903 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1904 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1905 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1906 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1907 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1908 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1909 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1910 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1911 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1912 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1913 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1914 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1915 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1916 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1917 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1918 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1919 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1920 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 24) | (supplier['s_acctbal'] >= 13148)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1921 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1922 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1923 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1924 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1925 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1926 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1927 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1928 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1929 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1930 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1931 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1932 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1933 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1934 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1935 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1936 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1937 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1938 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1939 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1940 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1941 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1942 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1943 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1944 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1945 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1946 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1947 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1948 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1949 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1950 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1951 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1952 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1953 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1954 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1955 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1956 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1957 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1958 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1959 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1960 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1961 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1962 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1963 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1964 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1965 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1966 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1967 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1968 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1969 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1970 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1971 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1972 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1973 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1974 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1975 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1976 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1977 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1978 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1979 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1980 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1981 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1982 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1983 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1984 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1985 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1986 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1987 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1988 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1989 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1990 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1991 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1992 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1993 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1994 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1995 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1996 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1997 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1998 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df1999 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2000 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2001 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2002 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2003 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2004 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2005 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2006 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2007 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2008 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2009 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2010 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2011 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2012 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2013 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2014 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2015 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2016 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2017 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2018 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2019 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2020 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2021 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2022 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2023 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2024 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] == 24) | (supplier['s_acctbal'] == 10802)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2025 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2026 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2027 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2028 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2029 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2030 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2031 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 20) & (supplier['s_acctbal'] > 7359)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2032 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2033 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2034 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2035 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2036 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2037 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2038 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2039 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2040 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2041 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2042 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2043 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2044 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2045 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2046 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2047 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2048 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2049 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 24) | (supplier['s_acctbal'] >= 13148)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2050 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2051 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2052 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2053 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2054 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2055 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2056 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2057 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2058 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2059 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2060 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2061 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2062 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2063 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2064 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2065 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2066 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2067 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2068 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2069 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2070 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2071 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2072 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2073 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2074 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2075 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2076 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2077 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2078 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2079 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2080 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2081 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2082 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2083 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2084 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2085 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2086 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2087 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2088 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2089 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2090 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2091 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2092 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2093 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2094 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2095 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2096 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2097 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2098 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2099 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2100 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2101 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2102 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2103 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2104 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2105 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2106 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2107 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2108 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2109 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2110 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2111 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2112 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2113 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2114 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2115 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2116 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2117 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2118 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2119 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2120 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2121 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2122 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2123 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2124 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2125 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2126 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2127 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2128 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2129 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2130 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2131 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2132 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2133 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2134 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2135 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2136 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2137 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2138 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2139 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2140 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2141 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2142 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2143 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2144 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2145 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2146 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2147 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2148 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2149 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2150 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2151 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2152 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2153 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2154 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2155 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2156 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2157 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2158 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2159 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2160 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2161 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2162 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2163 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2164 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2165 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2166 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2167 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2168 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2169 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2170 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2171 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2172 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2173 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2174 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2175 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2176 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2177 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2178 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2179 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2180 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2181 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2182 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2183 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2184 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2185 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2186 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2187 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2188 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2189 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2190 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2191 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2192 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2193 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2194 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2195 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2196 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2197 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2198 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2199 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2200 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2201 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2202 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2203 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2204 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2205 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2206 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2207 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2208 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2209 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2210 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2211 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2212 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2213 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2214 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2215 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2216 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2217 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2218 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2219 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2220 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2221 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2222 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2223 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2224 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2225 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2226 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2227 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2228 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2229 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2230 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2231 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2232 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2233 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2234 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2235 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2236 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2237 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2238 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2239 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2240 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2241 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2242 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2243 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2244 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2245 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2246 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2247 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2248 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2249 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2250 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2251 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2252 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2253 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2254 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2255 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2256 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2257 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2258 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2259 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2260 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2261 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2262 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2263 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2264 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2265 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2266 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2267 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2268 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2269 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2270 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2271 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2272 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2273 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2274 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2275 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2276 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2277 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2278 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2279 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2280 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2281 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2282 = nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey') 
df2283 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2284 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_name']],left_on='s_nationkey', right_on='n_nationkey') 
df2285 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_name']],left_on='s_nationkey', right_on='n_nationkey') 
df2286 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2287 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2288 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2289 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2290 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2291 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2292 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2293 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2294 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] < 614],left_on='s_suppkey', right_on='ps_suppkey') 
df2295 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 509],left_on='s_suppkey', right_on='ps_suppkey') 
df2296 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] < 697],left_on='s_suppkey', right_on='ps_suppkey') 
df2297 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2298 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2299 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 26][['n_nationkey','n_name','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2300 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] < 775],left_on='s_suppkey', right_on='ps_suppkey') 
df2301 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 1332],left_on='s_suppkey', right_on='ps_suppkey') 
df2302 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2303 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 273],left_on='s_suppkey', right_on='ps_suppkey') 
df2304 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] > 335],left_on='s_suppkey', right_on='ps_suppkey') 
df2305 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2306 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2307 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name']],left_on='s_nationkey', right_on='n_nationkey') 
df2308 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 853],left_on='s_suppkey', right_on='ps_suppkey') 
df2309 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] < 1279],left_on='s_suppkey', right_on='ps_suppkey') 
df2310 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2311 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 451],left_on='s_suppkey', right_on='ps_suppkey') 
df2312 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] < 614],left_on='s_suppkey', right_on='ps_suppkey') 
df2313 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2314 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 658],left_on='s_suppkey', right_on='ps_suppkey') 
df2315 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2316 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] < 1220],left_on='s_suppkey', right_on='ps_suppkey') 
df2317 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] > 570],left_on='s_suppkey', right_on='ps_suppkey') 
df2318 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 26][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2319 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 1052],left_on='s_suppkey', right_on='ps_suppkey') 
df2320 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2321 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2322 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2323 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2324 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2325 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149],left_on='s_suppkey', right_on='ps_suppkey') 
df2326 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2327 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2328 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2329 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2330 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2331 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2332 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 285],left_on='s_suppkey', right_on='ps_suppkey') 
df2333 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name']],left_on='s_nationkey', right_on='n_nationkey') 
df2334 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 6][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2335 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] > 395],left_on='s_suppkey', right_on='ps_suppkey') 
df2336 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149],left_on='s_suppkey', right_on='ps_suppkey') 
df2337 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2338 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2339 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2340 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] < 497],left_on='s_suppkey', right_on='ps_suppkey') 
df2341 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2342 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 739],left_on='s_suppkey', right_on='ps_suppkey') 
df2343 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] > 988],left_on='s_suppkey', right_on='ps_suppkey') 
df2344 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2345 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 451],left_on='s_suppkey', right_on='ps_suppkey') 
df2346 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] > 850],left_on='s_suppkey', right_on='ps_suppkey') 
df2347 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2348 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] < 1528],left_on='s_suppkey', right_on='ps_suppkey') 
df2349 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 1201],left_on='s_suppkey', right_on='ps_suppkey') 
df2350 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2351 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2352 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2353 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name']],left_on='s_nationkey', right_on='n_nationkey') 
df2354 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] < 1528],left_on='s_suppkey', right_on='ps_suppkey') 
df2355 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] < 862],left_on='s_suppkey', right_on='ps_suppkey') 
df2356 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] > 351],left_on='s_suppkey', right_on='ps_suppkey') 
df2357 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_name']],left_on='s_nationkey', right_on='n_nationkey') 
df2358 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] > 351],left_on='s_suppkey', right_on='ps_suppkey') 
df2359 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] > 0][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2360 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2361 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 1332],left_on='s_suppkey', right_on='ps_suppkey') 
df2362 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2363 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2364 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey') 
df2365 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey') 
df2366 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 727],left_on='s_suppkey', right_on='ps_suppkey') 
df2367 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 377],left_on='s_suppkey', right_on='ps_suppkey') 
df2368 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2369 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2370 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1003],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2371 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2372 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2373 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2374 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1063],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2375 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2376 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1059],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2377 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2378 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2379 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2380 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2381 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2382 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2383 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] > 132],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2384 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2385 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2386 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2387 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2388 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2389 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2390 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2391 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1175],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2392 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] >= 251],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2393 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2394 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2395 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2396 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2397 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1161],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2398 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2399 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2400 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1003],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2401 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2402 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] == 24) | (supplier['s_acctbal'] == 10802)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2403 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2404 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2405 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2406 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2407 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2408 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2409 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2410 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1209],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2411 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1025],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2412 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2413 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 20) & (supplier['s_acctbal'] > 7359)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2414 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] == 14) | (supplier['s_acctbal'] == 8535)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2415 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2416 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2417 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2418 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2419 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2420 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2421 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2422 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] >= 90],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2423 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2424 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1209],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2425 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2426 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2427 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] > 291],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2428 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2429 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1134],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2430 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2431 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1025],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2432 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2433 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2434 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2435 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2436 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2437 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1159],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2438 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2439 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2440 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2441 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2442 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2443 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2444 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2445 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1175],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2446 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2447 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2448 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2449 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 24) | (supplier['s_acctbal'] >= 13148)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2450 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2451 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1115],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2452 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2453 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2454 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2455 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2456 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2457 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1105],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2458 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1040],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2459 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2460 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2461 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2462 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2463 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2464 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2465 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1003],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2466 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2467 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2468 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2469 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1063],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2470 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2471 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1059],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2472 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2473 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2474 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2475 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2476 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2477 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2478 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] > 132],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2479 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2480 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2481 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2482 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2483 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2484 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2485 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2486 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1175],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2487 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] >= 251],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2488 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2489 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2490 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2491 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2492 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1161],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2493 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2494 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2495 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1003],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2496 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2497 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] == 24) | (supplier['s_acctbal'] == 10802)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2498 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2499 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2500 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2501 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2502 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2503 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2504 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2505 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1209],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2506 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1025],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2507 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2508 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] == 14) | (supplier['s_acctbal'] == 8535)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2509 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2510 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2511 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2512 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2513 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2514 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2515 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2516 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] >= 90],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2517 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2518 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1209],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2519 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2520 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2521 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] > 291],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2522 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2523 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1134],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2524 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2525 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1025],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2526 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2527 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2528 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2529 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2530 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2531 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1159],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2532 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2533 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2534 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2535 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2536 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2537 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2538 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2539 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1175],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2540 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2541 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2542 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2543 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 24) | (supplier['s_acctbal'] >= 13148)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2544 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2545 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1115],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2546 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2547 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2548 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2549 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2550 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2551 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] < 1105],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2552 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(part[part['p_retailprice'] <= 1040],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2553 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2554 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2555 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2556 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2557 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2558 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2559 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2560 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2561 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2562 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2563 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2564 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2565 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2566 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2567 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2568 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2569 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2570 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2571 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 26][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2572 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2573 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2574 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2575 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2576 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2577 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2578 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2579 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 26][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2580 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2581 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2582 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2583 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2584 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2585 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2586 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2587 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2588 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2589 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2590 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2591 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2592 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 6][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2593 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2594 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2595 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2596 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2597 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2598 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2599 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2600 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2601 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2602 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2603 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2604 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2605 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2606 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2607 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2608 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2609 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2610 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2611 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2612 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2613 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2614 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2615 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2616 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2617 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2618 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2619 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2620 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2621 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2622 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2623 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2624 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2625 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2626 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2627 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2628 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2629 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2630 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2631 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2632 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2633 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2634 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2635 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2636 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2637 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2638 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2639 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2640 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2641 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2642 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2643 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2644 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2645 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2646 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2647 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2648 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2649 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2650 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2651 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2652 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2653 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2654 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2655 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2656 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2657 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2658 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2659 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2660 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2661 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2662 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2663 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2664 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2665 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1003],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2666 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2667 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2668 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2669 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1063],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2670 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2671 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1059],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2672 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2673 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2674 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2675 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2676 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2677 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] > 132],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2678 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2679 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2680 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2681 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2682 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2683 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2684 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1175],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2685 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] >= 251],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2686 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2687 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2688 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2689 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2690 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1161],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2691 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2692 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2693 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1003],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2694 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2695 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] == 24) | (supplier['s_acctbal'] == 10802)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2696 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2697 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2698 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2699 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2700 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2701 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2702 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1209],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2703 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1025],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2704 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2705 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 20) & (supplier['s_acctbal'] > 7359)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2706 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2707 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2708 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2709 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2710 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2711 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2712 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2713 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] >= 90],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2714 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2715 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1209],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2716 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2717 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2718 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] > 291],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2719 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2720 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1134],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2721 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2722 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1025],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2723 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2724 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2725 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2726 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2727 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2728 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1159],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2729 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2730 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2731 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2732 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2733 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2734 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2735 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2736 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1175],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2737 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2738 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2739 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 24) | (supplier['s_acctbal'] >= 13148)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2740 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2741 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1115],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2742 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2743 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2744 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2745 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2746 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2747 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] < 1105],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2748 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(part[part['p_retailprice'] <= 1040],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2749 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2750 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2751 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2752 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2753 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2754 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2755 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2756 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2757 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2758 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2759 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2760 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2761 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2762 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2763 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2764 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2765 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2766 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2767 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 26][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2768 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2769 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2770 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2771 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2772 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2773 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2774 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2775 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 26][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2776 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2777 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2778 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2779 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2780 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2781 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2782 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2783 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2784 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2785 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2786 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2787 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2788 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 6][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2789 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2790 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2791 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] == 3][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2792 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2793 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2794 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2795 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2796 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2797 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2798 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2799 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2800 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2801 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 1][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2802 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2803 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2804 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2805 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2806 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2807 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2808 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2809 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2810 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2811 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2812 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2813 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2814 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2815 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2816 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2817 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2818 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2819 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2820 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2821 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2822 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2823 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2824 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2825 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2826 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2827 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2828 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2829 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2830 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2831 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2832 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2833 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2834 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2835 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2836 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2837 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2838 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2839 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2840 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2841 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2842 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2843 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2844 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2845 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2846 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2847 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2848 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2849 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2850 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2851 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2852 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2853 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2854 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2855 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2856 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2857 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2858 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='s_suppkey', right_on='ps_suppkey') 
df2859 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2860 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2861 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2862 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2863 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2864 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2865 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 21) | (supplier['s_acctbal'] == 5674)][['s_name','s_address','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2866 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 9],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2867 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2868 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2869 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2870 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2871 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 7],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2872 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2873 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2874 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2875 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2876 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2877 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2878 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_address','s_nationkey']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2879 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 215) | (supplier['s_acctbal'] < 5418)][['s_name','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2880 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_nationkey','s_phone','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2881 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_address','s_nationkey','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2882 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2883 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2884 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2885 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2886 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 4],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2887 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 24) | (supplier['s_acctbal'] == 10802)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2888 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2889 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2890 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2891 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2892 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2893 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2894 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 20) & (supplier['s_acctbal'] > 7359)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2895 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 3],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2896 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2897 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 21) | (supplier['s_acctbal'] == 11563)][['s_nationkey','s_phone','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2898 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 3],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2899 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 14) | (supplier['s_acctbal'] == 8535)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2900 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2901 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2902 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2903 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2904 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2905 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2906 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 4],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2907 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2908 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2909 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2910 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2911 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2912 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2913 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2914 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2915 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] > 3],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2916 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 13) | (supplier['s_acctbal'] > 4399)][['s_address','s_nationkey','s_phone','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2917 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2918 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2919 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2920 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2921 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2922 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2923 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2924 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2925 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 21) | (supplier['s_acctbal'] == 11563)][['s_name','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2926 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2927 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2928 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 4],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2929 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2930 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2931 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2932 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 24) | (supplier['s_acctbal'] >= 13148)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2933 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2934 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2935 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_name','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2936 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_name','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2937 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2938 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2939 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2940 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 9],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2941 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2942 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 4],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2943 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2944 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2945 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2946 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 24) | (supplier['s_acctbal'] > 8902)][['s_address','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2947 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 3],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2948 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2949 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2950 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 21) | (supplier['s_acctbal'] == 5674)][['s_name','s_address','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2951 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 15549)][['s_name','s_nationkey','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2952 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2953 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2954 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 212) | (supplier['s_acctbal'] <= 4085)][['s_name','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2955 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2956 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2957 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2958 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2959 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2960 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2961 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2962 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2963 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2964 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2965 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2966 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2967 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2968 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2969 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2970 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2971 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] == 24) | (supplier['s_acctbal'] == 10802)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2972 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2973 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2974 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2975 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2976 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2977 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2978 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 20) & (supplier['s_acctbal'] > 7359)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2979 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] == 14) | (supplier['s_acctbal'] == 8535)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2980 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2981 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2982 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2983 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2984 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2985 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2986 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2987 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2988 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2989 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2990 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2991 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2992 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2993 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2994 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2995 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2996 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2997 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 24) | (supplier['s_acctbal'] >= 13148)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2998 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df2999 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3000 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3001 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3002 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3003 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3004 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3005 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3006 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3007 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3008 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3009 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3010 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3011 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3012 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3013 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3014 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3015 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3016 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3017 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3018 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3019 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3020 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3021 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] == 24) | (supplier['s_acctbal'] == 10802)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3022 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3023 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3024 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3025 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3026 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3027 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3028 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] == 14) | (supplier['s_acctbal'] == 8535)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3029 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3030 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3031 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3032 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3033 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3034 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3035 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3036 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3037 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3038 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3039 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3040 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3041 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3042 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3043 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3044 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3045 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3046 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 24) | (supplier['s_acctbal'] >= 13148)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3047 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3048 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3049 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3050 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3051 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3052 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3053 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3054 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] <= 442].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3055 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3056 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3057 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3058 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3059 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3060 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3061 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3062 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3063 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3064 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3065 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3066 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3067 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3068 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3069 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3070 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3071 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3072 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3073 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3074 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3075 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3076 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3077 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3078 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3079 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3080 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3081 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3082 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3083 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3084 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3085 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3086 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3087 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3088 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3089 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3090 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3091 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3092 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3093 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3094 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3095 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3096 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3097 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3098 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3099 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3100 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3101 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3102 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3103 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3104 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3105 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3106 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3107 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3108 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3109 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3110 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3111 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3112 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3113 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3114 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3115 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3116 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3117 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3118 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3119 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3120 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3121 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3122 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3123 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3124 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3125 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3126 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3127 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3128 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3129 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3130 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3131 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3132 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3133 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3134 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3135 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3136 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3137 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3138 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3139 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3140 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3141 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3142 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3143 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3144 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3145 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3146 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3147 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3148 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3149 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3150 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] == 24) | (supplier['s_acctbal'] == 10802)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3151 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3152 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3153 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3154 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3155 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3156 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3157 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 20) & (supplier['s_acctbal'] > 7359)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3158 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3159 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3160 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3161 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3162 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3163 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3164 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3165 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3166 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3167 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3168 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3169 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3170 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3171 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3172 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3173 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3174 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3175 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 24) | (supplier['s_acctbal'] >= 13148)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3176 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3177 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3178 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3179 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3180 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3181 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3182 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3183 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3184 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3185 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3186 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3187 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3188 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3189 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3190 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3191 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3192 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3193 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3194 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3195 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3196 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3197 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3198 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3199 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3200 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3201 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3202 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3203 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3204 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3205 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3206 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3207 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3208 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3209 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3210 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3211 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3212 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3213 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3214 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3215 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3216 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3217 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3218 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3219 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3220 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3221 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3222 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3223 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3224 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3225 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3226 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3227 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3228 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3229 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3230 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3231 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3232 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3233 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3234 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3235 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3236 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3237 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3238 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3239 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3240 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3241 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3242 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3243 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3244 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3245 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3246 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3247 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3248 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3249 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3250 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3251 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3252 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3253 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3254 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3255 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3256 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3257 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3258 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3259 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3260 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3261 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3262 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3263 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3264 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3265 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3266 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3267 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3268 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3269 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3270 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3271 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3272 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3273 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3274 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3275 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3276 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3277 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3278 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3279 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3280 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3281 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3282 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3283 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3284 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3285 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3286 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3287 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3288 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3289 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3290 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3291 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3292 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3293 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3294 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3295 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3296 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3297 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3298 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3299 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3300 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3301 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3302 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3303 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3304 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3305 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3306 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3307 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3308 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3309 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3310 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3311 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3312 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3313 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3314 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3315 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3316 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3317 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3318 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3319 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3320 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3321 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3322 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3323 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3324 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3325 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3326 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3327 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3328 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3329 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3330 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3331 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3332 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3333 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3334 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3335 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3336 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3337 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3338 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3339 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3340 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3341 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3342 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3343 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3344 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3345 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3346 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3347 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3348 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3349 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3350 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3351 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3352 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3353 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3354 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3355 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3356 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3357 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3358 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3359 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3360 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3361 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3362 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3363 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3364 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3365 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3366 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3367 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3368 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3369 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3370 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3371 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3372 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3373 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3374 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3375 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3376 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3377 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3378 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3379 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3380 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3381 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3382 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3383 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3384 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3385 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3386 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3387 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3388 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3389 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3390 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3391 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3392 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3393 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3394 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3395 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3396 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3397 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3398 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3399 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3400 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3401 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3402 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3403 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3404 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3405 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3406 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3407 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3408 = supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey') 
df3409 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df3410 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df3411 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_address']],left_on='l_suppkey', right_on='s_suppkey') 
df3412 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df3413 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3414 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] <= 497048.47) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_orderdate']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3415 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey') 
df3416 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey') 
df3417 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df3418 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df3419 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df3420 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df3421 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey') 
df3422 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey') 
df3423 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_custkey','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df3424 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey') 
df3425 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='l_suppkey', right_on='s_suppkey') 
df3426 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] >= 175118.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority']].groupby(by=['o_shippriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3427 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] <= 281428.61) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3428 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='l_suppkey', right_on='s_suppkey') 
df3429 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='l_suppkey', right_on='s_suppkey') 
df3430 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df3431 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey') 
df3432 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df3433 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df3434 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3435 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] <= 267744.16) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df3436 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df3437 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df3438 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 92507.06) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df3439 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] <= 182691.78) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df3440 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey') 
df3441 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df3442 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_orderpriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3443 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df3444 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey') 
df3445 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey') 
df3446 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_totalprice','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df3447 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_comment']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3448 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='l_suppkey', right_on='s_suppkey') 
df3449 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df3450 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey') 
df3451 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] == 394066.64) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3452 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df3453 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df3454 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey') 
df3455 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df3456 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey') 
df3457 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df3458 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df3459 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey') 
df3460 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='l_suppkey', right_on='s_suppkey') 
df3461 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df3462 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df3463 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df3464 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey') 
df3465 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey') 
df3466 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='l_suppkey', right_on='s_suppkey') 
df3467 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df3468 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df3469 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df3470 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey') 
df3471 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] == 409119.08) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderdate']],left_on='l_orderkey', right_on='o_orderkey') 
df3472 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 299260.59) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df3473 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df3474 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] < 155982.45) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df3475 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey') 
df3476 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3477 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3478 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey') 
df3479 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df3480 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] >= 190341.58) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderdate','o_clerk','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df3481 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] == 269278.52) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_totalprice','o_orderpriority','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3482 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df3483 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey') 
df3484 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df3485 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df3486 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey') 
df3487 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df3488 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='l_suppkey', right_on='s_suppkey') 
df3489 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='l_suppkey', right_on='s_suppkey') 
df3490 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df3491 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey') 
df3492 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey') 
df3493 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] < 308518.61) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df3494 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df3495 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df3496 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderdate','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3497 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice','o_clerk','o_comment']].groupby(by=['o_custkey']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3498 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df3499 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey') 
df3500 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey') 
df3501 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey') 
df3502 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] <= 133060.14) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3503 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderdate','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3504 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] >= 171953.74) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df3505 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey') 
df3506 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df3507 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] >= 36395.09) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('max',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df3508 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df3509 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='l_suppkey', right_on='s_suppkey') 
df3510 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df3511 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey') 
df3512 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey') 
df3513 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey') 
df3514 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df3515 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3516 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3517 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3518 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3519 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3520 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3521 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3522 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3523 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3524 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3525 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3526 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3527 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3528 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3529 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3530 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3531 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3532 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3533 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3534 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3535 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3536 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3537 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3538 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3539 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3540 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3541 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3542 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3543 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3544 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3545 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3546 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3547 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3548 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3549 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3550 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3551 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3552 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3553 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3554 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3555 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3556 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3557 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3558 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3559 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3560 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3561 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3562 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3563 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3564 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3565 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3566 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3567 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3568 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3569 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3570 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3571 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3572 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3573 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3574 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3575 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3576 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3577 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3578 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3579 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3580 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3581 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3582 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3583 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3584 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 6231) & (lineitem['l_quantity'] < 223)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3585 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3586 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_quantity','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3587 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_quantity','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3588 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7950) & (lineitem['l_quantity'] <= 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3589 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 2366) | (lineitem['l_quantity'] >= 209)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3590 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 7553) & (lineitem['l_quantity'] >= 29) | (lineitem['l_discount'] >= 0.16)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3591 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_partkey','l_tax','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3592 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14355) | (lineitem['l_quantity'] < 53) & (lineitem['l_discount'] < 2.04)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3593 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3594 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3595 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_extendedprice','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3596 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6217) | (lineitem['l_quantity'] <= 46)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3597 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8840) & (lineitem['l_quantity'] < 56)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3598 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_tax','l_shipdate','l_commitdate','l_receiptdate']].groupby(by=['l_commitdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3599 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3298) & (lineitem['l_quantity'] >= 20) & (lineitem['l_discount'] >= 0.09)][['l_orderkey','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3600 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3601 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3602 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3603 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5578) & (lineitem['l_quantity'] > 21)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3604 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10453) & (lineitem['l_quantity'] < 32)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3605 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_partkey','l_linenumber','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_quantity']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3606 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_tax','l_linestatus','l_shipdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3607 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3608 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3609 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3610 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5114) | (lineitem['l_quantity'] < 228) | (lineitem['l_discount'] < 201.61)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3611 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8657) & (lineitem['l_quantity'] <= 29) & (lineitem['l_discount'] <= 1.14)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3612 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5348) | (lineitem['l_quantity'] > 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3613 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5053) & (lineitem['l_quantity'] >= 40)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3614 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) | (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3615 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8216) & (lineitem['l_quantity'] <= 24)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3616 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) & (lineitem['l_quantity'] < 35) | (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3617 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) | (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3618 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_shipmode','l_comment']].groupby(by=['l_shipmode']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3619 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3620 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3621 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3622 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_tax','l_linestatus','l_receiptdate']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3623 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 8881) & (lineitem['l_quantity'] >= 46)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3624 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14680) | (lineitem['l_quantity'] < 69)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3625 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) & (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_linenumber','l_discount','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_comment']].groupby(by=['l_shipdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3626 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 16632) | (lineitem['l_quantity'] < 75) | (lineitem['l_discount'] < 2.18)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3627 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_partkey','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3628 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_extendedprice','l_discount','l_linestatus','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3629 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 6816) & (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 1.14)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_shipdate','l_shipmode']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3630 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3631 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8259) & (lineitem['l_quantity'] < 57)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3632 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3633 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3634 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3635 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) & (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3636 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) & (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3637 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3878) | (lineitem['l_quantity'] > 38)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3638 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8614) | (lineitem['l_quantity'] < 49) & (lineitem['l_discount'] < 1.56)][['l_orderkey','l_partkey','l_linenumber','l_extendedprice','l_tax','l_linestatus']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3639 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4989) & (lineitem['l_quantity'] >= 36)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3640 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5297) & (lineitem['l_quantity'] >= 14) | (lineitem['l_discount'] >= 0.1)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_returnflag','l_linestatus','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3641 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) & (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_linenumber','l_quantity','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3642 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3643 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_partkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3644 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) | (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3645 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3646 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5884) & (lineitem['l_quantity'] <= 220)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3647 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) | (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_discount','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3648 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7547) & (lineitem['l_quantity'] < 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3649 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3650 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_returnflag','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3651 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3652 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3653 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5342) & (lineitem['l_quantity'] > 37)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3654 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12140) & (lineitem['l_quantity'] <= 65)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3655 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3656 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10302) | (lineitem['l_quantity'] < 40) | (lineitem['l_discount'] < 1.69)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipinstruct']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3657 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3658 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) & (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_returnflag','l_shipdate','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3659 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3813) & (lineitem['l_quantity'] <= 228) | (lineitem['l_discount'] <= 201.06)][['l_orderkey','l_partkey','l_suppkey','l_extendedprice','l_discount','l_shipdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3660 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5139) | (lineitem['l_quantity'] > 35) | (lineitem['l_discount'] > 1.13)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3661 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3662 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) | (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3663 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 9774) | (lineitem['l_quantity'] < 43) | (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df3664 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3665 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3666 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3667 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3668 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3669 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3670 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3671 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3672 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3673 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3674 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3675 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3676 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3677 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3678 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3679 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3680 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3681 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3682 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3683 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3684 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3685 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3686 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3687 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3688 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3689 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3690 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3691 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3692 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3693 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3694 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3695 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3696 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3697 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3698 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3699 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3700 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3701 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3702 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3703 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3704 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3705 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3706 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3707 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3708 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3709 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3710 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3711 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3712 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3713 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3714 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3715 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3716 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3717 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3718 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3719 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3720 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3721 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3722 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3723 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3724 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3725 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3726 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3727 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3728 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3729 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3730 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3731 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3732 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3733 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3734 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3735 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3736 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3737 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3738 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3739 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3740 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3741 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3742 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3743 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3744 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3745 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3746 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3747 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3748 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3749 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3750 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3751 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3752 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3753 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3754 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3755 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3756 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3757 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3758 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3759 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 23) & (supplier['s_acctbal'] < 8440)][['s_suppkey','s_name','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3760 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_name','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3761 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3762 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3763 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3764 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3765 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3766 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_name','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3767 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3768 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3769 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3770 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3771 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3772 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3773 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3774 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3775 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3776 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 14) & (supplier['s_acctbal'] <= 8564)][['s_suppkey','s_address','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3777 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3778 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3779 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 36) & (supplier['s_acctbal'] < 14096)][['s_suppkey','s_name','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3780 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3781 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3782 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3783 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_name']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3784 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 20) | (supplier['s_acctbal'] <= 8684)][['s_suppkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3785 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 18) & (supplier['s_acctbal'] <= 7381)][['s_suppkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3786 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3787 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3788 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3789 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3790 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3791 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 30) | (supplier['s_acctbal'] <= 11442)][['s_suppkey','s_name','s_address','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3792 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3793 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_suppkey','s_name','s_address','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3794 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3795 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3796 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 19) | (supplier['s_acctbal'] < 11581)][['s_suppkey','s_address','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3797 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3798 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3799 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3800 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_suppkey','s_phone','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3801 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3802 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 16) & (supplier['s_acctbal'] < 3227)][['s_suppkey','s_address']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3803 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3804 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3805 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3806 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3807 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3808 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3809 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3810 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3811 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3812 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3813 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3814 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3815 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3816 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3817 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3818 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3819 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3820 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3821 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3822 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3823 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3824 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3825 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3826 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3827 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3828 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3829 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3830 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3831 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3832 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3833 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3834 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3835 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3836 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3837 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3838 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3839 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3840 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3841 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3842 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3843 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3844 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3845 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3846 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3847 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3848 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3849 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3850 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3851 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3852 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3853 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3854 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3855 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3856 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3857 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3858 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3859 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3860 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3861 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3862 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3863 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3864 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3865 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3866 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3867 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3868 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3869 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3870 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3871 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3872 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3873 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3874 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3875 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3876 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3877 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3878 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3879 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3880 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3881 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3882 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3883 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3884 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3885 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3886 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3887 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3888 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3889 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3890 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3891 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3892 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3893 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3894 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3895 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3896 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3897 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3898 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3899 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3900 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3901 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3902 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3903 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3904 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3905 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3906 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3907 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3908 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3909 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3910 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3911 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3912 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3913 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3914 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3915 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3916 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3917 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3918 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3919 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3920 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3921 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3922 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3923 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3924 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3925 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3926 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3927 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3928 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3929 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3930 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3931 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3932 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3933 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3934 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3935 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3936 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3937 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3938 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3939 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3940 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3941 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3942 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3943 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3944 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3945 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3946 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3947 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3948 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3949 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3950 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3951 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3952 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3953 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3954 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3955 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3956 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3957 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3958 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3959 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3960 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3961 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3962 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3963 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3964 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3965 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3966 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3967 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3968 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3969 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3970 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3971 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3972 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3973 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3974 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3975 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3976 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3977 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3978 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3979 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3980 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3981 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3982 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3983 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3984 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3985 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3986 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3987 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3988 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3989 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3990 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3991 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3992 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3993 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3994 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3995 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3996 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3997 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3998 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df3999 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4000 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4001 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4002 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4003 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4004 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4005 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4006 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4007 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4008 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4009 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4010 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4011 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4012 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4013 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4014 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4015 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4016 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4017 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4018 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4019 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4020 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4021 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4022 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4023 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4024 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4025 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4026 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4027 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4028 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4029 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4030 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4031 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4032 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4033 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4034 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4035 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4036 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4037 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4038 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4039 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4040 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4041 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4042 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4043 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4044 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4045 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4046 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4047 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4048 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4049 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4050 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4051 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4052 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4053 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4054 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4055 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4056 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4057 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4058 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4059 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4060 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4061 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4062 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4063 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4064 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4065 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4066 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4067 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4068 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4069 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4070 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4071 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4072 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4073 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4074 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4075 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4076 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4077 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4078 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4079 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4080 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4081 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4082 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4083 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4084 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4085 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4086 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4087 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4088 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4089 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4090 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4091 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4092 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4093 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4094 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4095 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4096 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4097 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4098 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4099 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4100 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4101 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4102 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4103 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4104 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4105 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4106 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4107 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4108 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4109 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4110 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4111 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4112 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4113 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4114 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4115 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4116 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4117 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4118 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4119 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4120 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4121 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4122 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4123 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4124 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4125 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4126 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4127 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4128 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4129 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4130 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4131 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4132 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4133 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4134 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4135 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4136 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4137 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4138 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4139 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4140 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4141 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4142 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4143 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4144 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4145 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4146 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4147 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4148 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4149 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4150 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4151 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4152 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4153 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4154 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4155 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4156 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4157 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4158 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4159 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4160 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4161 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4162 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4163 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4164 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4165 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4166 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4167 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4168 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4169 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4170 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4171 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4172 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4173 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4174 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4175 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4176 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4177 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4178 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4179 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4180 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4181 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4182 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4183 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4184 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4185 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4186 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4187 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4188 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4189 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4190 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4191 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 11) & (supplier['s_acctbal'] <= 6894)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4192 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4193 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4194 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4195 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4196 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4197 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4198 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4199 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4200 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4201 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4202 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4203 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4204 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4205 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4206 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4207 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4208 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 17) & (supplier['s_acctbal'] <= 8511)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4209 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4210 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4211 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4212 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4213 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4214 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4215 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4216 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4217 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4218 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)].merge(partsupp[partsupp['ps_supplycost'] >= 863].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='ps_suppkey', right_on='s_suppkey'),left_on='l_suppkey', right_on='s_suppkey'),left_on='n_nationkey', right_on='s_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4219 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_name']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4220 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4221 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4222 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4223 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4224 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4225 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4226 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4227 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 26][['n_nationkey','n_name','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4228 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 1332],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4229 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4230 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 273],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4231 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] > 335],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4232 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4233 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 853],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4234 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] < 1279],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4235 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4236 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 658],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4237 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] < 1220],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4238 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] > 570],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4239 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 26][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4240 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 1052],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4241 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4242 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4243 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4244 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4245 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4246 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4247 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 285],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4248 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4249 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 6][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4250 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] > 395],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4251 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4252 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4253 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4254 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4255 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] < 1528],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4256 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 1201],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4257 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4258 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] < 1528],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4259 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] < 862],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4260 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] > 351],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4261 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_name']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4262 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] > 351],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4263 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] > 0][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4264 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] <= 1332],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4265 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4266 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4267 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4268 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 727],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4269 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 377],left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4270 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1003],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4271 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1063],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4272 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1059],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4273 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4274 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] > 132],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4275 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1175],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4276 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] >= 251],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4277 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1161],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4278 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1003],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4279 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1209],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4280 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1025],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4281 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] >= 90],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4282 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1209],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4283 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] > 291],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4284 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1134],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4285 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1025],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4286 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4287 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1159],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4288 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1175],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4289 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1115],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4290 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] >= 934],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4291 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] < 1105],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4292 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(partsupp[partsupp['ps_supplycost'] >= 149].merge(part[part['p_retailprice'] <= 1040],left_on='ps_partkey', right_on='p_partkey'),left_on='s_suppkey', right_on='ps_suppkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4293 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4294 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4295 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4296 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4297 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4298 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4299 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4300 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4301 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4302 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 26][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4303 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4304 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4305 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4306 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 26][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4307 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4308 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4309 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4310 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4311 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4312 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4313 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 6][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4314 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4315 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4316 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4317 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4318 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4319 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4320 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4321 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4322 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4323 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4324 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4325 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4326 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4327 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4328 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4329 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4330 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4331 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4332 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 26][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4333 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4334 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4335 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4336 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 26][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4337 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4338 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4339 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4340 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4341 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4342 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4343 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 6][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4344 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4345 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 2][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4346 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 3][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4347 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4348 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 4][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4349 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4350 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4351 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4352 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 3][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4353 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4354 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 21) | (supplier['s_acctbal'] == 5674)][['s_name','s_address','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4355 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 9],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4356 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4357 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 7],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4358 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4359 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_address','s_nationkey']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4360 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 215) | (supplier['s_acctbal'] < 5418)][['s_name','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4361 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_nationkey','s_phone','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4362 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_address','s_nationkey','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4363 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 4],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4364 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4365 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 21) | (supplier['s_acctbal'] == 11563)][['s_nationkey','s_phone','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4366 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4367 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4368 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 4],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4369 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4370 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4371 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4372 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4373 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 13) | (supplier['s_acctbal'] > 4399)][['s_address','s_nationkey','s_phone','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4374 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4375 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4376 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4377 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4378 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 21) | (supplier['s_acctbal'] == 11563)][['s_name','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4379 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 4],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4380 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4381 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_name','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4382 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_name','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4383 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 9],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4384 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4385 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 4],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4386 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4387 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4388 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 24) | (supplier['s_acctbal'] > 8902)][['s_address','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4389 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4390 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] == 21) | (supplier['s_acctbal'] == 5674)][['s_name','s_address','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4391 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 15549)][['s_name','s_nationkey','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4392 = lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 212) | (supplier['s_acctbal'] <= 4085)][['s_name','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='l_suppkey', right_on='s_suppkey') 
df4393 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey') 
df4394 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df4395 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df4396 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df4397 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df4398 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df4399 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df4400 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] <= 26][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df4401 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df4402 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df4403 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df4404 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] < 26][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df4405 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df4406 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df4407 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df4408 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df4409 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey') 
df4410 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] <= 6][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df4411 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df4412 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df4413 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey') 
df4414 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] > 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df4415 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey') 
df4416 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey') 
df4417 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4418 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4419 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4420 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4421 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4422 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 9],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4423 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4424 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4425 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4426 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 7],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4427 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4428 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4429 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4430 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4431 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4432 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4433 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_address','s_nationkey']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4434 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 215) | (supplier['s_acctbal'] < 5418)][['s_name','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4435 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_nationkey','s_phone','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4436 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_address','s_nationkey','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4437 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4438 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4439 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4440 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 4],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4441 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4442 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4443 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4444 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4445 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4446 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4447 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 3],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4448 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4449 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 3],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4450 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4451 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4452 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4453 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4454 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4455 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4456 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 4],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4457 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4458 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4459 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4460 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4461 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4462 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4463 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4464 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4465 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] > 3],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4466 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 13) | (supplier['s_acctbal'] > 4399)][['s_address','s_nationkey','s_phone','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4467 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4468 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4469 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4470 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4471 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4472 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4473 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4474 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4475 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4476 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4477 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4478 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4479 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4480 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4481 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_name','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4482 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_name','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4483 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4484 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4485 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4486 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 9],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4487 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4488 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 4],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4489 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4490 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4491 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4492 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 24) | (supplier['s_acctbal'] > 8902)][['s_address','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4493 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 3],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4494 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4495 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4496 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 15549)][['s_name','s_nationkey','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4497 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4498 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4499 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 212) | (supplier['s_acctbal'] <= 4085)][['s_name','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4500 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='n_nationkey', right_on='s_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4501 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_name']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4502 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4503 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4504 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4505 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4506 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4507 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4508 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 26][['n_nationkey','n_name','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4509 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4510 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4511 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4512 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 26][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4513 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4514 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4515 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4516 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4517 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4518 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] <= 6][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4519 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4520 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4521 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4522 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] > 0][['n_nationkey','n_name','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4523 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_regionkey']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4524 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey','n_comment']],left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4525 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4526 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4527 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4528 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4529 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4530 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4531 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4532 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4533 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 26][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4534 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4535 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4536 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4537 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 26][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4538 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4539 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4540 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4541 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4542 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4543 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] <= 6][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4544 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4545 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4546 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4547 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4548 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4549 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] < 19254) & (customer['c_custkey'] < 169)][['c_custkey','c_address','c_nationkey','c_phone','c_mktsegment','c_comment']].merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4550 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4551 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4552 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4553 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4554 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4555 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4556 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4557 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4558 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 26][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4559 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4560 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4561 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4562 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 26][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4563 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4564 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4565 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4566 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4567 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] < 7][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4568 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] <= 6][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4569 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 3][['n_nationkey','n_name','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4570 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4571 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 2][['n_nationkey','n_name']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4572 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 0][['n_nationkey','n_name','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4573 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] >= 1][['n_nationkey','n_regionkey']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4574 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(customer[(customer['c_acctbal'] > 8530) | (customer['c_custkey'] > 89)][['c_custkey','c_name','c_nationkey','c_phone']].groupby(by=['c_name']).agg('min',numeric_only=True).merge(nation[nation['n_regionkey'] > 2][['n_nationkey','n_regionkey','n_comment']],left_on='c_nationkey', right_on='n_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4575 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4576 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 7287)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4577 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4578 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 5) | (supplier['s_acctbal'] > 2662)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4579 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 15906)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4580 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 9],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4581 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 5) & (supplier['s_acctbal'] > 2662)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4582 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 32) & (supplier['s_acctbal'] < 11951)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4583 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4584 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 7],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4585 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 10) | (supplier['s_acctbal'] > 5823)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4586 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 23) | (supplier['s_acctbal'] >= 9085)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4587 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 19) | (supplier['s_acctbal'] >= 6754)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4588 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_suppkey','s_address','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4589 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4590 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 214) & (supplier['s_acctbal'] < 7297)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4591 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_address','s_nationkey']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4592 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 215) | (supplier['s_acctbal'] < 5418)][['s_name','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4593 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 20) & (supplier['s_acctbal'] >= 5703)][['s_nationkey','s_phone','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4594 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_address','s_nationkey','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4595 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4596 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 29) & (supplier['s_acctbal'] < 11251)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4597 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4598 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 4],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4599 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 18) | (supplier['s_acctbal'] < 8381)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4600 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4601 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 208) | (supplier['s_acctbal'] <= 5481)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4602 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 10405)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4603 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4604 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4605 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 3],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4606 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 921)][['s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4607 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 3],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4608 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 10) & (supplier['s_acctbal'] >= 5458)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4609 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4610 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 12166)][['s_suppkey','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4611 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4612 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4613 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 36) & (supplier['s_acctbal'] <= 12475)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4614 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 4],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4615 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4616 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) & (supplier['s_acctbal'] >= 2154)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4617 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4618 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4619 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4620 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 32) & (supplier['s_acctbal'] <= 11880)][['s_suppkey','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4621 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 15906)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4622 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) | (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4623 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] > 3],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4624 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 13) | (supplier['s_acctbal'] > 4399)][['s_address','s_nationkey','s_phone','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4625 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4626 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 5) | (supplier['s_acctbal'] <= 5357)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4627 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 2],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4628 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4629 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 26) | (supplier['s_acctbal'] > 5433)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4630 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 0) | (supplier['s_acctbal'] >= 2154)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4631 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4632 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 39) & (supplier['s_acctbal'] < 12543)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4633 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 34) & (supplier['s_acctbal'] <= 12577)][['s_suppkey','s_nationkey','s_phone','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4634 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 7) | (supplier['s_acctbal'] >= 3456)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4635 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 11) | (supplier['s_acctbal'] > 4930)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4636 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_suppkey','s_nationkey']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4637 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 9) | (supplier['s_acctbal'] <= 3142)][['s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4638 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 15) | (supplier['s_acctbal'] >= 5834)][['s_suppkey','s_address','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4639 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_name','s_nationkey','s_acctbal']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4640 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 3) | (supplier['s_acctbal'] > 1468)][['s_name','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4641 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 26) & (supplier['s_acctbal'] <= 8672)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4642 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 38) & (supplier['s_acctbal'] < 18407)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4643 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 21) & (supplier['s_acctbal'] < 11194)][['s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4644 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 9],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4645 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4646 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 4],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4647 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] <= 8],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4648 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 206) | (supplier['s_acctbal'] > 4412)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4649 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 6],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4650 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] > 24) | (supplier['s_acctbal'] > 8902)][['s_address','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4651 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] >= 3],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4652 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(region[region['r_regionkey'] < 5],left_on='n_regionkey', right_on='r_regionkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4653 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 24) | (supplier['s_acctbal'] < 10294)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4654 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 35) | (supplier['s_acctbal'] < 15549)][['s_name','s_nationkey','s_acctbal','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4655 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] >= 7) & (supplier['s_acctbal'] >= 4098)][['s_suppkey','s_nationkey','s_phone']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4656 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 7) | (supplier['s_acctbal'] < 7207)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4657 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] <= 212) | (supplier['s_acctbal'] <= 4085)][['s_name','s_nationkey','s_phone','s_comment']],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4658 = customer[(customer['c_acctbal'] > 8894) & (customer['c_custkey'] > 85)][['c_custkey','c_name','c_nationkey','c_acctbal','c_mktsegment']].merge(supplier[(supplier['s_nationkey'] >= 20) | (supplier['s_acctbal'] >= 4757)].merge(nation[nation['n_regionkey'] >= 0][['n_nationkey','n_name','n_regionkey','n_comment']].merge(supplier[(supplier['s_nationkey'] < 38) | (supplier['s_acctbal'] < 18407)],left_on='n_nationkey', right_on='s_nationkey'),left_on='s_nationkey', right_on='n_nationkey'),left_on='c_nationkey', right_on='n_nationkey') 
df4659 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df4660 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df4661 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df4662 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4663 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] <= 497048.47) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_orderdate']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4664 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df4665 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_custkey','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df4666 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] >= 175118.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority']].groupby(by=['o_shippriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4667 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] <= 281428.61) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4668 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df4669 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4670 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] <= 267744.16) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df4671 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df4672 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df4673 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 92507.06) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df4674 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] <= 182691.78) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df4675 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_orderpriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4676 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df4677 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_totalprice','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df4678 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_comment']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4679 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] == 394066.64) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4680 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df4681 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df4682 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df4683 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] == 409119.08) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderdate']],left_on='l_orderkey', right_on='o_orderkey') 
df4684 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 299260.59) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df4685 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] < 155982.45) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df4686 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4687 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4688 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df4689 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] >= 190341.58) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderdate','o_clerk','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df4690 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] == 269278.52) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_totalprice','o_orderpriority','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4691 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey') 
df4692 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] < 308518.61) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df4693 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df4694 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderdate','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4695 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice','o_clerk','o_comment']].groupby(by=['o_custkey']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4696 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df4697 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] <= 133060.14) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4698 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderdate','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4699 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] >= 171953.74) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df4700 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey') 
df4701 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] >= 36395.09) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('max',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey') 
df4702 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df4703 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk']],left_on='l_orderkey', right_on='o_orderkey') 
df4704 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey') 
df4705 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4706 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4707 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4708 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6543) | (lineitem['l_quantity'] <= 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4709 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 6645) | (lineitem['l_quantity'] >= 39) & (lineitem['l_discount'] >= 1.02)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4710 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4379) | (lineitem['l_quantity'] >= 20)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4711 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) & (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4712 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4713 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 6231) & (lineitem['l_quantity'] < 223)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4714 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4715 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_quantity','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4716 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_quantity','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4717 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7950) & (lineitem['l_quantity'] <= 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4718 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 2366) | (lineitem['l_quantity'] >= 209)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4719 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 7553) & (lineitem['l_quantity'] >= 29) | (lineitem['l_discount'] >= 0.16)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4720 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_partkey','l_tax','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4721 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14355) | (lineitem['l_quantity'] < 53) & (lineitem['l_discount'] < 2.04)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4722 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4723 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4724 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_extendedprice','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4725 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 6217) | (lineitem['l_quantity'] <= 46)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4726 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8840) & (lineitem['l_quantity'] < 56)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4727 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_tax','l_shipdate','l_commitdate','l_receiptdate']].groupby(by=['l_commitdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4728 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 3298) & (lineitem['l_quantity'] >= 20) & (lineitem['l_discount'] >= 0.09)][['l_orderkey','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4729 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4730 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4731 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4732 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5578) & (lineitem['l_quantity'] > 21)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4733 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10453) & (lineitem['l_quantity'] < 32)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4734 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_partkey','l_linenumber','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_quantity']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4735 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_tax','l_linestatus','l_shipdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4736 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4737 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4738 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4739 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 5114) | (lineitem['l_quantity'] < 228) | (lineitem['l_discount'] < 201.61)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4740 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8657) & (lineitem['l_quantity'] <= 29) & (lineitem['l_discount'] <= 1.14)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4741 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5348) | (lineitem['l_quantity'] > 43)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4742 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5053) & (lineitem['l_quantity'] >= 40)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4743 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) | (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4744 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 8216) & (lineitem['l_quantity'] <= 24)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4745 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) & (lineitem['l_quantity'] < 35) | (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4746 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) | (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4747 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_shipmode','l_comment']].groupby(by=['l_shipmode']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4748 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4749 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4750 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4751 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_tax','l_linestatus','l_receiptdate']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4752 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 8881) & (lineitem['l_quantity'] >= 46)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4753 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 14680) | (lineitem['l_quantity'] < 69)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4754 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) & (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_linenumber','l_discount','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_comment']].groupby(by=['l_shipdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4755 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 16632) | (lineitem['l_quantity'] < 75) | (lineitem['l_discount'] < 2.18)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4756 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_partkey','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4757 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_extendedprice','l_discount','l_linestatus','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4758 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 6816) & (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 1.14)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_shipdate','l_shipmode']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4759 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4760 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8259) & (lineitem['l_quantity'] < 57)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4761 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4762 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4763 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4764 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) & (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4765 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) & (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4766 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3878) | (lineitem['l_quantity'] > 38)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4767 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 8614) | (lineitem['l_quantity'] < 49) & (lineitem['l_discount'] < 1.56)][['l_orderkey','l_partkey','l_linenumber','l_extendedprice','l_tax','l_linestatus']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4768 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 4989) & (lineitem['l_quantity'] >= 36)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4769 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 5297) & (lineitem['l_quantity'] >= 14) | (lineitem['l_discount'] >= 0.1)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_returnflag','l_linestatus','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4770 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) & (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_linenumber','l_quantity','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4771 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4772 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_partkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4773 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 3557) | (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4774 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4775 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 5884) & (lineitem['l_quantity'] <= 220)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4776 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 4151) | (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_discount','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4777 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 7547) & (lineitem['l_quantity'] < 48)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4778 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4779 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_returnflag','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4780 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4781 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4782 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5342) & (lineitem['l_quantity'] > 37)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4783 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12140) & (lineitem['l_quantity'] <= 65)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4784 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4785 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 10302) | (lineitem['l_quantity'] < 40) | (lineitem['l_discount'] < 1.69)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipinstruct']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4786 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4787 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) & (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_returnflag','l_shipdate','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4788 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 3813) & (lineitem['l_quantity'] <= 228) | (lineitem['l_discount'] <= 201.06)][['l_orderkey','l_partkey','l_suppkey','l_extendedprice','l_discount','l_shipdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4789 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] > 5139) | (lineitem['l_quantity'] > 35) | (lineitem['l_discount'] > 1.13)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4790 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4791 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 13982) | (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4792 = lineitem[(lineitem['l_suppkey'] >= 3214) & (lineitem['l_quantity'] >= 27)].merge(orders[(orders['o_totalprice'] > 199008.97) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority']].merge(lineitem[(lineitem['l_suppkey'] < 9774) | (lineitem['l_quantity'] < 43) | (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey'),left_on='l_orderkey', right_on='o_orderkey') 
df4793 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 5297) & (lineitem['l_quantity'] >= 14) | (lineitem['l_discount'] >= 0.1)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_discount','l_returnflag','l_linestatus','l_shipinstruct']].groupby(by=['l_linestatus']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4794 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 6231) & (lineitem['l_quantity'] < 223)],left_on='o_orderkey', right_on='l_orderkey') 
df4795 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey') 
df4796 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_quantity','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df4797 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_quantity','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey') 
df4798 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 7950) & (lineitem['l_quantity'] <= 48)],left_on='o_orderkey', right_on='l_orderkey') 
df4799 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 2366) | (lineitem['l_quantity'] >= 209)],left_on='o_orderkey', right_on='l_orderkey') 
df4800 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 7553) & (lineitem['l_quantity'] >= 29) | (lineitem['l_discount'] >= 0.16)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df4801 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_partkey','l_tax','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df4802 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 14355) | (lineitem['l_quantity'] < 53) & (lineitem['l_discount'] < 2.04)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df4803 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey') 
df4804 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4805 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_extendedprice','l_shipdate','l_commitdate','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df4806 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 6217) | (lineitem['l_quantity'] <= 46)],left_on='o_orderkey', right_on='l_orderkey') 
df4807 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 8840) & (lineitem['l_quantity'] < 56)],left_on='o_orderkey', right_on='l_orderkey') 
df4808 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_tax','l_shipdate','l_commitdate','l_receiptdate']].groupby(by=['l_commitdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4809 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 3298) & (lineitem['l_quantity'] >= 20) & (lineitem['l_discount'] >= 0.09)][['l_orderkey','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey') 
df4810 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_shipdate','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey') 
df4811 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 1648) | (lineitem['l_quantity'] >= 3) | (lineitem['l_discount'] >= 0.88)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_receiptdate','l_shipinstruct']].groupby(by=['l_returnflag']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4812 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 17791) | (lineitem['l_quantity'] < 80) | (lineitem['l_discount'] < 2.15)][['l_orderkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_tax','l_linestatus','l_receiptdate']].groupby(by=['l_linestatus']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4813 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) | (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey') 
df4814 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey') 
df4815 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 5578) & (lineitem['l_quantity'] > 21)],left_on='o_orderkey', right_on='l_orderkey') 
df4816 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 10453) & (lineitem['l_quantity'] < 32)],left_on='o_orderkey', right_on='l_orderkey') 
df4817 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_partkey','l_linenumber','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_quantity']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4818 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_tax','l_linestatus','l_shipdate']],left_on='o_orderkey', right_on='l_orderkey') 
df4819 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4820 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 10179) & (lineitem['l_quantity'] <= 43) | (lineitem['l_discount'] <= 1.15)][['l_orderkey','l_linenumber','l_extendedprice','l_tax','l_returnflag','l_shipdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df4821 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey') 
df4822 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5114) | (lineitem['l_quantity'] < 228) | (lineitem['l_discount'] < 201.61)][['l_orderkey','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4823 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 8657) & (lineitem['l_quantity'] <= 29) & (lineitem['l_discount'] <= 1.14)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_commitdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4824 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 5348) | (lineitem['l_quantity'] > 43)],left_on='o_orderkey', right_on='l_orderkey') 
df4825 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 5053) & (lineitem['l_quantity'] >= 40)],left_on='o_orderkey', right_on='l_orderkey') 
df4826 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) | (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_commitdate','l_receiptdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df4827 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 8216) & (lineitem['l_quantity'] <= 24)],left_on='o_orderkey', right_on='l_orderkey') 
df4828 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] == 9096) | (lineitem['l_quantity'] == 50) | (lineitem['l_discount'] == 3.51)][['l_orderkey','l_quantity','l_discount','l_returnflag','l_shipdate','l_commitdate','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_shipinstruct']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4829 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 4151) & (lineitem['l_quantity'] < 35) | (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey') 
df4830 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) | (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_tax','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']].groupby(by=['l_shipinstruct']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4831 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) | (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df4832 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_tax','l_shipmode','l_comment']].groupby(by=['l_shipmode']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4833 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_quantity','l_linestatus','l_commitdate','l_receiptdate','l_shipinstruct','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df4834 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 5866) & (lineitem['l_quantity'] <= 14)],left_on='o_orderkey', right_on='l_orderkey') 
df4835 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 5299) & (lineitem['l_quantity'] > 34) | (lineitem['l_discount'] > 0.74)][['l_orderkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey') 
df4836 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_tax','l_linestatus','l_receiptdate']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4837 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 8881) & (lineitem['l_quantity'] >= 46)],left_on='o_orderkey', right_on='l_orderkey') 
df4838 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 14680) | (lineitem['l_quantity'] < 69)],left_on='o_orderkey', right_on='l_orderkey') 
df4839 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) & (lineitem['l_discount'] > 1.44)][['l_orderkey','l_partkey','l_linenumber','l_discount','l_returnflag','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_comment']].groupby(by=['l_shipdate']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4840 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 16632) | (lineitem['l_quantity'] < 75) | (lineitem['l_discount'] < 2.18)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey') 
df4841 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 8797) | (lineitem['l_quantity'] > 33) | (lineitem['l_discount'] > 0.3)][['l_orderkey','l_partkey','l_tax','l_commitdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df4842 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_suppkey','l_extendedprice','l_discount','l_linestatus','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df4843 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 6816) & (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 1.14)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_tax','l_linestatus','l_shipdate','l_shipmode']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4844 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 1648) | (lineitem['l_quantity'] >= 3) | (lineitem['l_discount'] >= 0.88)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_tax','l_linestatus','l_shipdate','l_shipinstruct','l_comment']].groupby(by=['l_linestatus']).agg('max',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4845 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey') 
df4846 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 8259) & (lineitem['l_quantity'] < 57)],left_on='o_orderkey', right_on='l_orderkey') 
df4847 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_quantity']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4848 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) & (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4849 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4850 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 3557) & (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey') 
df4851 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 1618) & (lineitem['l_quantity'] >= 12)],left_on='o_orderkey', right_on='l_orderkey') 
df4852 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 3878) | (lineitem['l_quantity'] > 38)],left_on='o_orderkey', right_on='l_orderkey') 
df4853 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 8614) | (lineitem['l_quantity'] < 49) & (lineitem['l_discount'] < 1.56)][['l_orderkey','l_partkey','l_linenumber','l_extendedprice','l_tax','l_linestatus']],left_on='o_orderkey', right_on='l_orderkey') 
df4854 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 4989) & (lineitem['l_quantity'] >= 36)],left_on='o_orderkey', right_on='l_orderkey') 
df4855 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 5297) & (lineitem['l_quantity'] >= 14) | (lineitem['l_discount'] >= 0.1)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_returnflag','l_linestatus','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4856 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 14592) & (lineitem['l_quantity'] <= 66) & (lineitem['l_discount'] <= 1.4)][['l_orderkey','l_linenumber','l_quantity','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey') 
df4857 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 7378) | (lineitem['l_quantity'] < 28)],left_on='o_orderkey', right_on='l_orderkey') 
df4858 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 4461) & (lineitem['l_quantity'] <= 22) | (lineitem['l_discount'] <= 1.88)][['l_orderkey','l_partkey','l_suppkey','l_quantity','l_extendedprice','l_discount','l_returnflag','l_commitdate']].groupby(by=['l_partkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4859 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 3557) | (lineitem['l_quantity'] > 14)],left_on='o_orderkey', right_on='l_orderkey') 
df4860 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey') 
df4861 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 5884) & (lineitem['l_quantity'] <= 220)],left_on='o_orderkey', right_on='l_orderkey') 
df4862 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) | (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_shipmode']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4863 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 4151) | (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.59)][['l_orderkey','l_suppkey','l_discount','l_tax','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey') 
df4864 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 7547) & (lineitem['l_quantity'] < 48)],left_on='o_orderkey', right_on='l_orderkey') 
df4865 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] >= 9053) | (lineitem['l_quantity'] >= 39) | (lineitem['l_discount'] >= 0.42)][['l_orderkey','l_partkey','l_linenumber','l_returnflag','l_linestatus','l_commitdate','l_receiptdate']],left_on='o_orderkey', right_on='l_orderkey') 
df4866 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] == 6338) | (lineitem['l_quantity'] == 41) | (lineitem['l_discount'] == 3.09)][['l_orderkey','l_returnflag','l_receiptdate','l_shipinstruct','l_shipmode','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df4867 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 16150) & (lineitem['l_quantity'] <= 67) & (lineitem['l_discount'] <= 1.73)][['l_orderkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_extendedprice']).agg('mean',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4868 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 7986) | (lineitem['l_quantity'] > 28) | (lineitem['l_discount'] > 0.94)][['l_orderkey','l_linenumber','l_quantity','l_discount','l_tax','l_returnflag','l_linestatus','l_commitdate','l_receiptdate','l_comment']].groupby(by=['l_receiptdate']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4869 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 5342) & (lineitem['l_quantity'] > 37)],left_on='o_orderkey', right_on='l_orderkey') 
df4870 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 12140) & (lineitem['l_quantity'] <= 65)],left_on='o_orderkey', right_on='l_orderkey') 
df4871 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 12464) | (lineitem['l_quantity'] <= 63)],left_on='o_orderkey', right_on='l_orderkey') 
df4872 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 10302) | (lineitem['l_quantity'] < 40) | (lineitem['l_discount'] < 1.69)][['l_orderkey','l_partkey','l_suppkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_commitdate','l_shipinstruct']].groupby(by=['l_suppkey']).agg('min',numeric_only=True),left_on='o_orderkey', right_on='l_orderkey') 
df4873 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 11151) | (lineitem['l_quantity'] <= 41) | (lineitem['l_discount'] <= 2.14)][['l_orderkey','l_linenumber','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey') 
df4874 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 3826) & (lineitem['l_quantity'] <= 24) & (lineitem['l_discount'] <= 1.75)][['l_orderkey','l_linenumber','l_returnflag','l_shipdate','l_commitdate','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df4875 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 3813) & (lineitem['l_quantity'] <= 228) | (lineitem['l_discount'] <= 201.06)][['l_orderkey','l_partkey','l_suppkey','l_extendedprice','l_discount','l_shipdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey') 
df4876 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 5139) | (lineitem['l_quantity'] > 35) | (lineitem['l_discount'] > 1.13)][['l_orderkey','l_suppkey','l_linenumber','l_linestatus','l_shipdate','l_commitdate','l_shipinstruct','l_shipmode']],left_on='o_orderkey', right_on='l_orderkey') 
df4877 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 7595) | (lineitem['l_quantity'] <= 40) | (lineitem['l_discount'] <= 1.27)][['l_orderkey','l_linenumber','l_quantity','l_extendedprice','l_discount','l_returnflag','l_linestatus','l_comment']],left_on='o_orderkey', right_on='l_orderkey') 
df4878 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 13982) | (lineitem['l_quantity'] < 74)],left_on='o_orderkey', right_on='l_orderkey') 
df4879 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 9774) | (lineitem['l_quantity'] < 43) | (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_suppkey','l_discount','l_returnflag','l_commitdate']],left_on='o_orderkey', right_on='l_orderkey') 
df4880 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4881 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4882 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4883 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4884 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 497048.47) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_orderdate']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4885 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4886 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_custkey','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4887 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 175118.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority']].groupby(by=['o_shippriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4888 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 281428.61) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4889 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4890 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4891 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 267744.16) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4892 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4893 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4894 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 92507.06) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4895 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 182691.78) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4896 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_orderpriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4897 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4898 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_totalprice','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4899 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_comment']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4900 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 394066.64) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4901 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4902 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4903 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4904 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 409119.08) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderdate']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4905 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 299260.59) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4906 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 155982.45) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4907 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4908 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4909 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4910 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 190341.58) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderdate','o_clerk','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4911 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 269278.52) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_totalprice','o_orderpriority','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4912 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4913 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 308518.61) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4914 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4915 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderdate','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4916 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice','o_clerk','o_comment']].groupby(by=['o_custkey']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4917 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4918 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 133060.14) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4919 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderdate','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4920 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 171953.74) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4921 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4922 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 36395.09) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('max',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4923 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4924 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4925 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] < 5995) & (lineitem['l_quantity'] < 35) & (lineitem['l_discount'] < 2.21)][['l_orderkey','l_partkey','l_quantity','l_extendedprice','l_linestatus','l_shipdate','l_commitdate','l_receiptdate','l_shipmode']].groupby(by=['l_shipdate']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4926 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4927 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4928 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4929 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4930 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 497048.47) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_orderdate']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4931 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4932 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_custkey','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4933 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 175118.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority']].groupby(by=['o_shippriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4934 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 281428.61) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4935 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4936 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4937 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 267744.16) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4938 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4939 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4940 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 92507.06) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4941 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 182691.78) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4942 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_orderpriority']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4943 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4944 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_totalprice','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4945 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_comment']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4946 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 394066.64) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_totalprice','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4947 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4948 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4949 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 139994.74) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4950 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 409119.08) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderdate']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4951 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] > 299260.59) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4952 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 155982.45) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4953 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_shippriority','o_comment']].groupby(by=['o_orderstatus']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4954 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4955 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4956 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 190341.58) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderdate','o_clerk','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4957 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 269278.52) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_totalprice','o_orderpriority','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4958 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4959 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 308518.61) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4960 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4961 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderdate','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4962 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice','o_clerk','o_comment']].groupby(by=['o_custkey']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4963 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4964 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 133060.14) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4965 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 318115.08) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderdate','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4966 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 171953.74) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4967 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4968 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 36395.09) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_shippriority','o_comment']].groupby(by=['o_comment']).agg('max',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4969 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4970 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_clerk']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4971 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] <= 9516) & (lineitem['l_quantity'] <= 67) | (lineitem['l_discount'] <= 2.0)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_returnflag','l_shipdate','l_shipinstruct','l_shipmode','l_comment']].groupby(by=['l_suppkey']).agg('min',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4972 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4973 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4974 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4975 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4976 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 497048.47) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_orderpriority','o_clerk','o_shippriority']].groupby(by=['o_orderdate']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4977 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4978 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] < 158356.05) | (orders['o_shippriority'] < 200)][['o_orderkey','o_custkey','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4979 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 281428.61) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4980 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderdate','o_clerk']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4981 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 267744.16) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4982 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4983 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] < 414506.99) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderdate','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4984 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 92507.06) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4985 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 182691.78) & (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderpriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4986 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_totalprice','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4987 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 159903.03) | (orders['o_shippriority'] > 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_comment']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4988 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_orderdate','o_orderpriority','o_clerk','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4989 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 284113.65) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_custkey','o_orderstatus','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4990 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] == 409119.08) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_orderstatus','o_totalprice','o_orderdate']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4991 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] > 299260.59) | (orders['o_shippriority'] > 0)][['o_orderkey','o_orderstatus','o_orderdate','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4992 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] < 253373.04) | (orders['o_shippriority'] < 0)][['o_orderkey','o_custkey','o_orderstatus','o_orderpriority','o_clerk']].groupby(by=['o_custkey']).agg('mean',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4993 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] <= 252528.8) | (orders['o_shippriority'] <= 0)][['o_orderkey','o_totalprice','o_orderdate','o_clerk','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4994 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 190341.58) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderdate','o_clerk','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4995 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] == 269278.52) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_totalprice','o_orderpriority','o_clerk']].groupby(by=['o_clerk']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4996 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] == 418951.41) | (orders['o_shippriority'] == 0)][['o_orderkey','o_custkey','o_shippriority']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4997 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] < 308518.61) | (orders['o_shippriority'] < 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_shippriority','o_comment']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4998 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 88702.62) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_clerk']],left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df4999 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_totalprice','o_orderdate','o_orderpriority','o_comment']].groupby(by=['o_comment']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey') 
df5000 = orders[(orders['o_totalprice'] >= 263404.98) | (orders['o_shippriority'] >= 0)][['o_orderkey','o_orderstatus','o_orderpriority','o_clerk','o_comment']].merge(lineitem[(lineitem['l_suppkey'] > 2244) | (lineitem['l_quantity'] > 16) | (lineitem['l_discount'] > 1.44)][['l_orderkey','l_suppkey','l_linenumber','l_quantity','l_discount','l_tax','l_shipdate','l_receiptdate','l_shipmode','l_comment']].groupby(by=['l_linenumber']).agg('max',numeric_only=True).merge(orders[(orders['o_totalprice'] >= 166467.26) & (orders['o_shippriority'] >= 0)][['o_orderkey','o_custkey','o_totalprice','o_clerk','o_comment']].groupby(by=['o_custkey']).agg('min',numeric_only=True),left_on='l_orderkey', right_on='o_orderkey'),left_on='o_orderkey', right_on='l_orderkey')
# Out:
# /Users/lidailun/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1214: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(
